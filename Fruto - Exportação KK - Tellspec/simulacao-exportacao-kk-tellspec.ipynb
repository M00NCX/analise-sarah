# %% [markdown]
# # Análise Espectroscópica
#
# Este notebook segue as melhores práticas da literatura para análise espectroscópica robusta, incluindo:
# - Cross Validation
# - Remoção de outliers espectrais (PCA, T²/Q)
# - Remoção de outliers dos atributos (boxplot + seaborn)
# - Teste de todos os filtros (dependentes e independentes de y)
# - Modelagem com PLSR, PCR, RFR, SVMR (hiperparâmetros da literatura)
# - Plotagens robustas e salvamento de métricas

# %% [markdown]
# ## 1. Imports

# %%
# Imports necessários
import os
import time
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from scipy.signal import savgol_filter
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, GridSearchCV, cross_val_predict, cross_val_score
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_squared_error
from matplotlib.mlab import detrend
import pywt
from sklearn.pipeline import Pipeline

# Cria diretórios para organizar todas as imagens salvas
print("Criando diretórios para salvar os gráficos...")
os.makedirs('graficos_outliers_pca', exist_ok=True)
os.makedirs('graficos_outliers_boxplot', exist_ok=True)
os.makedirs('modelos_salvos', exist_ok=True)
os.makedirs('graficos_modelos', exist_ok=True) 
os.makedirs('graficos_mlpr', exist_ok=True)

warnings.filterwarnings('ignore')

# Configurações de plot
plt.style.use('default')
sns.set_palette('husl')
plt.rcParams['figure.figsize'] = (12, 8)
# Out:
# Criando diretórios para salvar os gráficos...

# %% [markdown]
# ## 2. Carregamento dos Dados

# %% [markdown]
# O primeiro passo em qualquer projeto de ciência de dados é carregar e entender os dados. Nesta seção, realizamos as seguintes ações:
# - **Carregamento:** Utilizamos a biblioteca `pandas` para ler o arquivo `Simulacao_Exportacao_Keitt_e_Kent_Tellspec.xlsx`, que contém os dados espectrais e os valores de referência (atributos físico-químicos).
# - **Separação de Dados:** A função `load_data` inteligentemente separa o arquivo em duas partes:
#     - `metadata`: Um DataFrame contendo as informações de referência (ex: Firmness, Dry Mass, TSS, TA, AA), que serão nossas variáveis-alvo (y).
#     - `wavelengths`: Um DataFrame contendo a resposta espectral (absorbância ou reflectância) em cada comprimento de onda, que serão nossas variáveis preditoras (X).
# - **Definição de Variáveis:** Convertemos os dados espectrais para um array NumPy (`X`) para otimizar os cálculos e definimos a lista de `atributos` que desejamos modelar.

# %%
# Função para carregar dados
def load_data(filepath):
    """Carrega dados espectrais e separa metadados de espectros."""
    df = pd.read_excel(filepath, engine='openpyxl')
    
    # Identificar colunas que são comprimentos de onda (numéricas)
    numeric_cols = []
    for col in df.columns:
        try:
            float(col)
            numeric_cols.append(col)
        except ValueError:
            continue
    
    # Separar metadados e comprimentos de onda
    metadata = df.drop(columns=numeric_cols)
    wavelengths = df[numeric_cols]
    
    return metadata, wavelengths

# Carregar dados
filepath = '../Data/raw/Fruto/Simulacao_Exportacao_Keitt_e_Kent_Tellspec.xlsx'
metadata, wavelengths = load_data(filepath)
X = wavelengths.values
wavelength_values = wavelengths.columns.astype(float)

# VARIÁVEIS DA SARAH
atributos = ['Firmness (N)', 'Dry Mass (%)', 'TSS (Brix)', 'TA (g/mL)', 'AA (mg/100g)']

print(f'Dados carregados: {X.shape[0]} amostras, {X.shape[1]} comprimentos de onda')
print(f'Faixa espectral: {wavelength_values.min():.1f} - {wavelength_values.max():.1f} nm')
print(f'Atributos disponíveis: {list(metadata.columns)}')
print(f'Atributos a analisar: {atributos}')

# remoção de NaN antes de passar pelo pré-processamento e conferência

dados_completos = {}
for atributo in atributos:
    y = metadata[atributo].values
    original_indices = np.arange(len(y))
    
    # Remove apenas valores NaN
    mask = ~np.isnan(y)
    X_clean = X[mask]
    y_clean = y[mask]
    original_indices_clean = original_indices[mask]
    
    dados_completos[atributo] = {
        'X': X_clean,
        'y': y_clean,
        'indices_orig': original_indices_clean
    }
    
    print(f'{atributo}: {X_clean.shape[0]} amostras válidas')

print(f'\nPreparação dos dados concluída para {len(atributos)} atributos!')
# Out:
# Dados carregados: 60 amostras, 248 comprimentos de onda
# Faixa espectral: 900.6 - 1700.4 nm
# Atributos disponíveis: ['Samples', 'Stage', 'Variety', 'Firmness (N)', 'Dry Mass (%)', 'TSS (Brix)', 'TA (g/mL)', 'AA (mg/100g)', 'Weight (g)', 'Width (mm)', 'Length (mm)']
# Atributos a analisar: ['Firmness (N)', 'Dry Mass (%)', 'TSS (Brix)', 'TA (g/mL)', 'AA (mg/100g)']
# Firmness (N): 60 amostras válidas
# Dry Mass (%): 60 amostras válidas
# TSS (Brix): 60 amostras válidas
# TA (g/mL): 60 amostras válidas
# AA (mg/100g): 60 amostras válidas
#
# Preparação dos dados concluída para 5 atributos!

# %% [markdown]
# ## 3. Filtros de Pré-processamento (Independentes e Dependentes de y)

# %% [markdown]
# Os dados espectrais brutos contêm diversas fontes de variação indesejada que podem mascarar a informação química relevante. Essas variações podem ser causadas por espalhamento de luz (efeitos físicos da amostra), mudanças na linha de base (drift do instrumento) e ruído. O pré-processing visa minimizar esses efeitos para que o modelo foque na correlação entre o espectro e o atributo de interesse.
#
# Neste notebook, testamos uma ampla gama de filtros, divididos em duas categorias:
#
# ### Filtros Independentes de y
#
# São aplicados apenas aos espectros (`X`) e não utilizam a informação da variável alvo (`y`).
#
# -   **`Raw`**: Utiliza os dados espectrais brutos, sem nenhum tratamento. Serve como uma linha de base para comparar a eficácia dos outros filtros.
# -   **`MSC` (Multiplicative Scatter Correction)**: Corrige o espalhamento de luz (aditivo e multiplicativo) causado por variações no tamanho de partícula e compactação da amostra. Ele ajusta cada espectro para se parecer mais com um espectro "ideal" (geralmente a média de todos os espectros).
# -   **`SNV` (Standard Normal Variate)**: Alternativa ao MSC que também corrige o espalhamento de luz. A diferença é que o SNV padroniza cada espectro individualmente (subtrai a média e divide pelo desvio padrão daquele espectro), sem usar um espectro de referência.
# -   **`SG_D1` e `SG_D2` (Savitzky-Golay Derivatives)**: Calcula a primeira ou a segunda derivada do espectro. Derivadas são excelentes para remover desvios de linha de base (efeitos aditivos) e para resolver picos espectrais sobrepostos, realçando a informação de bandas de absorção específicas.
# -   **`Detrend`**: Remove tendências lineares ou polinomiais da linha de base do espectro. É muito eficaz para corrigir "inclinações" no espectro causadas por drift do instrumento.
# -   **`Normalize`**: Realiza uma normalização Min-Max, escalonando a intensidade de cada espectro para um intervalo fixo (geralmente [0, 1]). Ajuda a corrigir variações de intensidade causadas por diferenças na distância da amostra ou na potência da fonte de luz.
# -   **`EMSC` (Extended Multiplicative Signal Correction)**: Uma versão avançada do MSC. Além de corrigir os efeitos de espalhamento, o EMSC pode incluir termos polinomiais para modelar e remover efeitos de linha de base mais complexos e não-lineares.
# -   **`Continuum Removal`**: Técnica que normaliza os espectros para que as bandas de absorção possam ser comparadas em termos de sua profundidade, e não de sua intensidade absoluta. Ele ajusta um "envelope" (casco convexo) sobre o espectro e divide o espectro original por este envelope, realçando as características de absorção.
# -   **`Wavelet_Denoising`**: Utiliza a Transformada Wavelet para decompor o espectro em diferentes níveis de frequência. A técnica permite remover o ruído (geralmente presente em altas frequências) de forma muito eficaz, preservando as principais características do sinal espectral.
#
# ### Filtros Dependentes de y e Combinações
#
# Estes filtros utilizam a variável alvo (`y`) para otimizar a remoção de variação não correlacionada em `X`, ou são combinações sequenciais de múltiplos filtros para um tratamento mais completo.
#
# -   **`OSC_1` e `OSC_2` (Orthogonal Signal Correction)**: Filtro que remove componentes (1 ou 2, neste caso) dos espectros `X` que são ortogonais (não correlacionados) à variável alvo `y`. O objetivo é limpar `X` da variação que não ajuda na predição, potencialmente melhorando o modelo subsequente. Esta técnica é frequentemente referida como um pré-processamento **OPLS** (Orthogonal Projections to Latent Structures).
# -   **`MSC_SG_OSC`**: Uma **cadeia de pré-processamentos** aplicada na seguinte ordem:
#     1.  `MSC` para corrigir o espalhamento.
#     2.  `Savitzky-Golay (1ª derivada)` para corrigir a linha de base.
#     3.  `OSC (1 componente)` para remover variação não correlacionada com `y`.
# -   **`OPLS1_SNV_SG_D1` e `OPLS2_SNV_SG_D1`**: Outra cadeia de processamento:
#     1.  `SNV` para correção de espalhamento.
#     2.  `Savitzky-Golay (1ª derivada)`.
#     3.  `OPLS/OSC` para remover 1 ou 2 componentes ortogonais a `y`.
# -   **`SNV_Detrend_SG_D1`**: Uma combinação de filtros independentes de `y`, mas que, por sua complexidade, é testada junto às outras cadeias:
#     1.  `SNV`.
#     2.  `Detrend` para remoção de tendência.
#     3.  `Savitzky-Golay (1ª derivada)`.

# %%
# Implementação dos filtros de pré-processamento
# Filtros independentes de y

def msc(X):
    """Multiplicative Scatter Correction."""
    X = np.asarray(X)
    mean_spectrum = np.mean(X, axis=0)
    corrected_spectra = np.zeros_like(X)
    for i in range(X.shape[0]):
        slope, intercept = np.polyfit(mean_spectrum, X[i, :], 1)
        corrected_spectra[i, :] = (X[i, :] - intercept) / slope
    return corrected_spectra

def snv(X):
    """Standard Normal Variate."""
    X = np.asarray(X)
    return (X - np.mean(X, axis=1, keepdims=True)) / np.std(X, axis=1, keepdims=True)

def savitzky_golay(X, window_size=11, poly_order=2, deriv_order=1):
    """Savitzky-Golay filter."""
    return savgol_filter(X, window_length=window_size, polyorder=poly_order, deriv=deriv_order, axis=1)

def detrend_filter(X):
    """Detrending filter."""
    return detrend(X, axis=1)

def normalize(X):
    """Normalização Min-Max."""
    return (X - np.min(X, axis=1, keepdims=True)) / (np.max(X, axis=1, keepdims=True) - np.min(X, axis=1, keepdims=True))

def emsc(X, reference=None):
    """Extended Multiplicative Signal Correction."""
    X = np.asarray(X)
    if reference is None:
        reference = np.mean(X, axis=0)  # Usa o espectro médio como referência
    
    X_corr = np.zeros_like(X)
    for i in range(X.shape[0]):
        # Modelo: X[i] ≈ a + b*reference
        model = np.vstack([np.ones_like(reference), reference]).T
        params, _, _, _ = np.linalg.lstsq(model, X[i, :], rcond=None)
        a, b = params[0], params[1]
        X_corr[i,:] = (X[i, :] - a) / b
    return X_corr

def continuum_removal(X, wavelengths):
    """Continuum Removal."""
    X = np.asarray(X)
    X_cr = np.zeros_like(X)
    for i in range(X.shape[0]):
        spectrum = X[i, :]
        # Encontra os pontos do casco convexo superior
        q_u = [0]
        for k in range(1, len(wavelengths) - 1):
            s_k = (spectrum[len(wavelengths)-1] - spectrum[0]) / (wavelengths[-1] - wavelengths[0])
            s_q = (spectrum[k] - spectrum[q_u[-1]]) / (wavelengths[k] - wavelengths[q_u[-1]])
            if s_q > s_k:
                q_u.append(k)
        q_u.append(len(wavelengths)-1)
        
        # Interpolação linear entre os pontos do casco
        continuum = np.interp(wavelengths, wavelengths[q_u], spectrum[q_u])
        X_cr[i, :] = spectrum / continuum
    return X_cr

def wavelet_denoising(X, wavelet='db4', level=4):
    """Wavelet Transform para Denoising."""
    X = np.asarray(X)
    original_length = X.shape[1]
    denoised_list = []

    for i in range(X.shape[0]):
        # 1. Decomposição Wavelet
        coeffs = pywt.wavedec(X[i, :], wavelet, level=level)

        # 2. Cálculo do limiar (threshold)
        sigma = np.median(np.abs(coeffs[-1])) / 0.6745
        threshold = sigma * np.sqrt(2 * np.log(original_length))

        # 3. Aplicação do filtro (soft thresholding) nos coeficientes de detalhe
        coeffs[1:] = [pywt.threshold(c, value=threshold, mode='soft') for c in coeffs[1:]]

        # 4. Reconstrução do sinal
        reconstructed_signal = pywt.waverec(coeffs, wavelet)

        # 5. Ajuste do tamanho
        denoised_list.append(reconstructed_signal[:original_length])

    return np.asarray(denoised_list)

# Filtros dependentes de y (Orthogonal Signal Correction)
class OrthogonalCorrection:
    """Orthogonal Signal Correction (OSC)."""
    def __init__(self, n_components=1):
        self.n_components = n_components
    
    def fit_transform(self, X, y):
        X, y = np.asarray(X), np.asarray(y).ravel()
        self.w_ortho_ = []
        self.p_ortho_ = []
        self.X_corr_ = X.copy()
        
        for _ in range(self.n_components):
            pls = PLSRegression(n_components=1)
            pls.fit(self.X_corr_, y)
            t = pls.x_scores_
            w = pls.x_weights_
            p = pls.x_loadings_
            
            # Componente Ortogonal
            w_ortho = p - (np.dot(w.T, p) / np.dot(w.T, w)) * w
            t_ortho = np.dot(self.X_corr_, w_ortho)
            p_ortho = np.dot(t_ortho.T, self.X_corr_) / np.dot(t_ortho.T, t_ortho)
            
            # Remover variação ortogonal
            self.X_corr_ -= np.dot(t_ortho, p_ortho)
            self.w_ortho_.append(w_ortho)
            self.p_ortho_.append(p_ortho)
        
        return self.X_corr_
    
    def transform(self, X):
        X_res = np.asarray(X).copy()
        for i in range(self.n_components):
            t_ortho = np.dot(X_res, self.w_ortho_[i])
            X_res -= np.dot(t_ortho, self.p_ortho_[i])
        return X_res

# Dicionário de filtros independentes de y
filtros_independentes = {
    'Raw': lambda X: X,
    'MSC': msc,
    'SNV': snv,
    'SG_D1': lambda X: savitzky_golay(X, window_size=11, poly_order=2, deriv_order=1),
    'SG_D2': lambda X: savitzky_golay(X, window_size=11, poly_order=2, deriv_order=2),
    'Detrend': detrend_filter,
    'Normalize': normalize,
    'EMSC': emsc,
    'Continuum_Removal': lambda X: continuum_removal(X, wavelength_values),
    'Wavelet_Denoising': wavelet_denoising
}

# Dicionário de filtros dependentes de y
filtros_dependentes = {
    'OSC_1': lambda X, y: OrthogonalCorrection(n_components=1).fit_transform(X, y),
    'OSC_2': lambda X, y: OrthogonalCorrection(n_components=2).fit_transform(X, y),
    'MSC_SG_OSC': lambda X, y: OrthogonalCorrection(n_components=1).fit_transform(
        savitzky_golay(msc(X), window_size=11, poly_order=2, deriv_order=1), y),
    'OPLS1_SNV_SG_D1': lambda X, y: OrthogonalCorrection(n_components=1).fit_transform(
        savitzky_golay(snv(X), window_size=11, poly_order=2, deriv_order=1), y),
    'OPLS2_SNV_SG_D1': lambda X, y: OrthogonalCorrection(n_components=2).fit_transform(
        savitzky_golay(snv(X), window_size=11, poly_order=2, deriv_order=1), y),
    'SNV_Detrend_SG_D1': lambda X, y: savitzky_golay(detrend_filter(snv(X)), window_size=11, poly_order=2, deriv_order=1)
}

print(f'Filtros independentes de y: {list(filtros_independentes.keys())}')
print(f'Filtros dependentes de y: {list(filtros_dependentes.keys())}')
print(f'Total de filtros: {len(filtros_independentes) + len(filtros_dependentes)}')
# Out:
# Filtros independentes de y: ['Raw', 'MSC', 'SNV', 'SG_D1', 'SG_D2', 'Detrend', 'Normalize', 'EMSC', 'Continuum_Removal', 'Wavelet_Denoising']
# Filtros dependentes de y: ['OSC_1', 'OSC_2', 'MSC_SG_OSC', 'OPLS1_SNV_SG_D1', 'OPLS2_SNV_SG_D1', 'SNV_Detrend_SG_D1']
# Total de filtros: 16

# %% [markdown]
# ## 4. Remoção de Outliers Espectrais (PCA, T²/Q)

# %% [markdown]
# Outliers espectrais são amostras cujo espectro é muito diferente do resto da população, podendo ser causados por erros de medição, contaminação ou características únicas da amostra. Eles podem prejudicar significativamente a capacidade de generalização do modelo.
# - **Método PCA (T²/Q):** Usamos a Análise de Componentes Principais (PCA) para identificar esses outliers.
#     - **Estatística T² (Hotelling's T²):** Mede a variação de uma amostra *dentro* do modelo PCA. Valores altos indicam que a amostra é um outlier na combinação das variáveis principais.
#     - **Estatística Q (Resíduos):** Mede a variação da amostra *fora* do modelo PCA (o que o modelo não conseguiu capturar). Valores altos indicam que a estrutura do espectro da amostra é anormal.
# - **Lógica:** Uma amostra é considerada outlier se seu valor de T² ou Q ultrapassa um limite de confiança (geralmente 3 desvios padrão da média).
# - **Importante:** A remoção de outliers é feita **apenas no conjunto de calibração**. O conjunto de validação deve permanecer intacto para simular dados "reais" que o modelo encontrará no futuro.

# %%
def pca_outlier_removal(X, n_components=10, threshold=3):
    """Remove outliers usando PCA com estatísticas T² e Q."""
    # Padronizar dados
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Aplicar PCA
    pca = PCA(n_components=n_components)
    X_pca = pca.fit_transform(X_scaled)
    
    # Calcular estatística T² (Hotelling's T²)
    T2 = np.sum((X_pca / np.std(X_pca, axis=0)) ** 2, axis=1)
    
    # Calcular estatística Q (resíduos)
    X_reconstructed = pca.inverse_transform(X_pca)
    Q = np.sum((X_scaled - X_reconstructed) ** 2, axis=1)
    
    # Definir limites (média + threshold * desvio padrão)
    T2_limit = np.mean(T2) + threshold * np.std(T2)
    Q_limit = np.mean(Q) + threshold * np.std(Q)
    
    # Identificar outliers
    outliers_mask = (T2 > T2_limit) | (Q > Q_limit)
    
    # Retornamos a máscara de quem NÃO é outlier e o modelo PCA treinado
    return ~outliers_mask, pca, T2, Q, T2_limit, Q_limit

dados_pca = {}

#para todo o conjunto de dado e não separado em cal e val
for atributo in atributos:
    X_full = dados_completos[atributo]['X']
    y_full = dados_completos[atributo]['y']
    indices_orig_full = dados_completos[atributo]['indices_orig']
    
    # Chama a função de remoção de outliers espectrais
    keep_mask, pca_model, T2, Q, T2_limit, Q_limit = pca_outlier_removal(X_full)
    
    # Identifica e informa os outliers removidos
    outliers_indices = indices_orig_full[~keep_mask]
    print(f'{atributo}: {len(outliers_indices)} outliers espectrais removidos.')
    if len(outliers_indices) > 0:
        print(f'  Índices Originais Removidos: {outliers_indices}')
    
    # Filtra os dados
    X_clean = X_full[keep_mask]
    y_clean = y_full[keep_mask]
    indices_orig_clean = indices_orig_full[keep_mask]
    
    dados_pca[atributo] = {
        'X': X_clean,
        'y': y_clean,
        'indices_orig': indices_orig_clean,
        'pca_model': pca_model,
        'T2': T2,
        'Q': Q,
        'T2_limit': T2_limit,
        'Q_limit': Q_limit,
        'keep_mask': keep_mask
    }
    
    print(f'  Dataset final: {X_clean.shape[0]} amostras')
    print()
# Out:
# Firmness (N): 2 outliers espectrais removidos.
#   Índices Originais Removidos: [45 50]
#   Dataset final: 58 amostras
#
# Dry Mass (%): 2 outliers espectrais removidos.
#   Índices Originais Removidos: [45 50]
#   Dataset final: 58 amostras
#
# TSS (Brix): 2 outliers espectrais removidos.
#   Índices Originais Removidos: [45 50]
#   Dataset final: 58 amostras
#
# TA (g/mL): 2 outliers espectrais removidos.
#   Índices Originais Removidos: [45 50]
#   Dataset final: 58 amostras
#
# AA (mg/100g): 2 outliers espectrais removidos.
#   Índices Originais Removidos: [45 50]
#   Dataset final: 58 amostras

# %% [markdown]
# ### 4.1 Gráficos de Outliers T² e Q

# %%
# Plotagem dos gráficos de outliers PCA
for atributo in atributos:
    d = dados_pca[atributo]
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    
    # Gráfico 1: Variância explicada cumulativa
    # Acessa o modelo PCA com a chave correta 'pca_model'

    cumulative_variance = np.cumsum(d['pca_model'].explained_variance_ratio_)
    axes[0].plot(range(1, len(cumulative_variance) + 1), cumulative_variance, 'o-', linewidth=2, markersize=6)
    axes[0].set_xlabel('Número de Componentes Principais')
    axes[0].set_ylabel('Variância Explicada Cumulativa')
    axes[0].set_title(f'Variância Explicada - {atributo}')
    axes[0].grid(True, alpha=0.3)
    axes[0].axhline(y=0.95, color='r', linestyle='--', alpha=0.7, label='95%')
    axes[0].legend()
    
    # Gráfico 2: T² vs Q (detecção de outliers)
    # Acessa as variáveis T2, Q, T2_limit, Q_limit e keep_mask com as chaves corretas
    scatter = axes[1].scatter(d['T2'], d['Q'], c=d['keep_mask'], cmap='coolwarm', 
                              edgecolor='k', alpha=0.7, s=50)
    axes[1].axhline(d['Q_limit'], color='r', linestyle='--', linewidth=2, label=f'Q Limit: {d["Q_limit"]:.2f}')
    axes[1].axvline(d['T2_limit'], color='g', linestyle='--', linewidth=2, label=f'T² Limit: {d["T2_limit"]:.2f}')
    axes[1].set_xlabel("Hotelling's T²")
    axes[1].set_ylabel('Q Residual')
    axes[1].set_title(f'Detecção de Outliers - {atributo}')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    
    # Adicionar legenda de cores
    legend1 = axes[1].legend(*scatter.legend_elements(), title="Status")
    axes[1].add_artist(legend1)
    
    plt.tight_layout()
    
    # Salvar gráfico
    nome_arquivo = f'graficos_outliers_pca/pca_outliers_{atributo.replace(" ", "_").replace("(", "").replace(")", "").replace("/", "_")}.png'
    plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f'Gráficos de outliers PCA para {atributo} salvos em: {nome_arquivo}')
    print()
# Out:
# Gráficos de outliers PCA para Firmness (N) salvos em: graficos_outliers_pca/pca_outliers_Firmness_N.png
# Gráficos de outliers PCA para Dry Mass (%) salvos em: graficos_outliers_pca/pca_outliers_Dry_Mass_%.png
# Gráficos de outliers PCA para TSS (Brix) salvos em: graficos_outliers_pca/pca_outliers_TSS_Brix.png
# Gráficos de outliers PCA para TA (g/mL) salvos em: graficos_outliers_pca/pca_outliers_TA_g_mL.png
# Gráficos de outliers PCA para AA (mg/100g) salvos em: graficos_outliers_pca/pca_outliers_AA_mg_100g.png

# %% [markdown]
# ## 5. Remoção de Outliers dos Atributos (Boxplot + Seaborn)

# %% [markdown]
# Além dos outliers espectrais (em X), podemos ter outliers nos valores de referência (em y). Por exemplo, um valor de pH ou SST que é analiticamente improvável ou resultado de um erro de anotação.
# - **Método (IQR):** O método do Intervalo Interquartil (IQR) é uma forma estatística robusta de identificar esses pontos.
#     - `IQR = Q3 (percentil 75) - Q1 (percentil 25)`
#     - Um valor é considerado outlier se estiver abaixo de `Q1 - 1.5 * IQR` ou acima de `Q3 + 1.5 * IQR`.
# - **Visualização:** O `boxplot` é a ferramenta visual perfeita para essa análise, pois ele desenha os "bigodes" exatamente nesses limites de 1.5 * IQR, mostrando os outliers como pontos individuais.
# - **Ação:** Novamente, a remoção é feita apenas no conjunto de calibração.

# %%
# Remover outliers dos atributos usando boxplot e IQR

dados_final = {}

for atributo in atributos:
    # Pega os dados já limpos de outliers espectrais
    d = dados_pca[atributo]
    X_clean = d['X']
    y_clean = d['y']
    indices_orig_clean = d['indices_orig']
    
    # Boxplot
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=y_clean)
    sns.stripplot(x=y_clean, color='red', alpha=0.6)
    plt.title(f'Boxplot com Dispersão - {atributo}')
    
    nome_arquivo = f'graficos_outliers_boxplot/boxplot_outliers_{atributo.replace(" ", "_").replace("(", "").replace(")", "").replace("/", "_")}.png'
    plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
    plt.show()

    # Lógica de remoção de outliers dos atributos
    Q1 = np.percentile(y_clean, 25)
    Q3 = np.percentile(y_clean, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    keep_mask_attr = (y_clean >= lower_bound) & (y_clean <= upper_bound)
    
    # Identifica e informa os outliers removidos
    outliers_attr_indices = indices_orig_clean[~keep_mask_attr]
    print(f'{atributo}: {len(outliers_attr_indices)} outliers de atributo removidos.')
    if len(outliers_attr_indices) > 0:
        print(f'  Índices Originais Removidos: {outliers_attr_indices}')
    
    # Armazena os dados finais e limpos para modelagem
    dados_final[atributo] = {
        'X': X_clean[keep_mask_attr],
        'y': y_clean[keep_mask_attr]
    }
    
    print(f'  Dataset final para modelagem: {dados_final[atributo]["X"].shape[0]} amostras')
    print()

print("Remoção de outliers concluída!")
# Out:
# Firmness (N): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 58 amostras
# Dry Mass (%): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 58 amostras
# TSS (Brix): 4 outliers de atributo removidos.
#   Índices Originais Removidos: [10 11 12 41]
#   Dataset final para modelagem: 54 amostras
# TA (g/mL): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 58 amostras
# AA (mg/100g): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 58 amostras
#
# Remoção de outliers concluída!

# %%
# --- Função para o Gráfico de CALIBRAÇÃO (Ref vs Predito vs CV) ---
def save_calibration_plot(y_cal, y_pred_cal, y_pred_cv, atributo, filtro, modelo, file_path):
    """
    Gera e salva um gráfico comparando predições de treino e de validação cruzada
    no conjunto de calibração.
    """
    try:
        # Garante que o diretório exista
        os.makedirs(os.path.dirname(file_path), exist_ok=True)

        # Métricas para Predição no Treino Completo
        slope_pred, offset_pred = np.polyfit(y_cal, y_pred_cal, 1)
        rmse_pred = np.sqrt(mean_squared_error(y_cal, y_pred_cal))
        r2_pred = r2_score(y_cal, y_pred_cal)

        # Métricas para Predição da Validação Cruzada
        slope_cv, offset_cv = np.polyfit(y_cal, y_pred_cv, 1)
        rmse_cv = np.sqrt(mean_squared_error(y_cal, y_pred_cv))
        r2_cv = r2_score(y_cal, y_pred_cv)

        plt.figure(figsize=(10, 8))
        plt.scatter(y_cal, y_pred_cal, color='blue', marker='o', alpha=0.6, label=f'Predição no Treino (R²={r2_pred:.3f})')
        plt.scatter(y_cal, y_pred_cv, color='red', marker='x', alpha=0.7, label=f'Predição CV (R²={r2_cv:.3f})')
        
        # Linha ideal 1:1
        min_val = min(min(y_cal), min(y_pred_cal), min(y_pred_cv))
        max_val = max(max(y_cal), max(y_pred_cal), max(y_pred_cv))
        plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='Linha Ideal (1:1)')

        plt.xlabel("Valores Reais (Calibração)")
        plt.ylabel("Valores Preditos")
        plt.title(f'Desempenho na Calibração: {atributo} | {modelo} | {filtro}')
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.legend(loc='lower right')
        
        # Adiciona texto com métricas
        stats_text = (
            f'Treino - RMSE: {rmse_pred:.3f}, Slope: {slope_pred:.3f}, Offset: {offset_pred:.3f}\n'
            f'CV     - RMSE: {rmse_cv:.3f}, Slope: {slope_cv:.3f}, Offset: {offset_cv:.3f}'
        )
        plt.text(0.05, 0.95, stats_text, transform=plt.gca().transAxes, fontsize=10,
                 verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5))

        plt.savefig(file_path, format='png', dpi=200, bbox_inches='tight')
        plt.close()

    except Exception as e:
        print(f"Erro ao gerar gráfico de calibração para {modelo} com {filtro}: {e}")
        plt.close()


# --- Função para o Gráfico de VALIDAÇÃO (Predito vs Real) ---
def save_validation_plot(y_val, y_pred_val, atributo, filtro, modelo, file_path):
    """
    Gera e salva o gráfico de predições no conjunto de validação (teste).
    """
    try:
        # Garante que o diretório exista
        os.makedirs(os.path.dirname(file_path), exist_ok=True)
        
        # Métricas
        r2 = r2_score(y_val, y_pred_val)
        rmse = np.sqrt(mean_squared_error(y_val, y_pred_val))
        slope, offset = np.polyfit(y_val, y_pred_val, 1)

        plt.figure(figsize=(8, 8))
        plt.scatter(y_val, y_pred_val, alpha=0.7, edgecolors='k', label='Dados de Validação')
        
        # Linha ideal 1:1
        min_val = min(min(y_val), min(y_pred_val))
        max_val = max(max(y_val), max(y_pred_val))
        plt.plot([min_val, max_val], [min_val, max_val], 'r--', lw=2, label='Linha Ideal (1:1)')

        plt.xlabel('Valores Reais (Validação)')
        plt.ylabel('Valores Preditos')
        plt.title(f'Desempenho na Validação: {atributo} | {modelo} | {filtro}')
        plt.grid(True, linestyle='--', alpha=0.6)
        
        stats_text = f'R² = {r2:.4f}\nRMSE = {rmse:.4f}\nSlope = {slope:.4f}'
        plt.text(0.05, 0.95, stats_text, transform=plt.gca().transAxes, fontsize=12,
                 verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='lightblue', alpha=0.5))
        
        plt.legend()
        plt.savefig(file_path, format='png', dpi=200, bbox_inches='tight')
        plt.close()

    except Exception as e:
        print(f"Erro ao gerar gráfico de validação para {modelo} com {filtro}: {e}")
        plt.close()

# %% [markdown]
# ## 6. Avaliação dos Filtros e Seleção dos Melhores Modelos com Validação Cruzada

# %% [markdown]
# Nesta etapa crucial, construímos e avaliamos os modelos de regressão. Em vez de testar cada modelo separadamente, criamos um fluxo automatizado e exaustivo para garantir que encontremos a melhor performance possível.
# - **Estratégia:**
#     1. **Iteração por Atributo:** Um loop externo passa por cada variável alvo (AT, PH, etc.).
#     2. **Iteração por Modelo:** Para cada atributo, testamos uma lista de modelos quimiométricos:
#         - `PLSR`: Padrão da área, lida bem com multicolinearidade.
#         - `PCR`: Alternativa que primeiro reduz a dimensionalidade.
#         - `RFR` (Random Forest): Modelo não-linear, robusto e poderoso.
#         - `SVMR` (Support Vector Machine): Eficaz em espaços de alta dimensão.
#     3. **Iteração por Filtro:** Para cada modelo, aplicamos **todos os 16 filtros** de pré-processamento definidos na seção anterior.
#     4. **Otimização (GridSearchCV):** Para cada combinação `(atributo, modelo, filtro)`, usamos `GridSearchCV` com validação cruzada (10-fold) para encontrar os melhores hiperparâmetros do modelo (ex: número de componentes para PLS, parâmetros C e gamma para SVM).
# - **Avaliação:** O desempenho de cada combinação é medido pelo R² da validação cruzada. O melhor modelo é então treinado com todos os dados de calibração e sua performance final é avaliada no conjunto de validação, que foi mantido separado durante todo o processo.
# - **Saídas:** Ao final, teremos os resultados de centenas de modelos, permitindo uma comparação justa e a seleção do campeão para cada atributo. Todos os gráficos de predição e as métricas são salvos automaticamente.

# %%
def save_calibration_plot_cv(y_true, y_pred_cv, atributo, filtro, modelo, file_path):
 
    try:
        # Garante que o diretório exista
        os.makedirs(os.path.dirname(file_path), exist_ok=True)

        # Métricas para Predição da Validação Cruzada
        slope_cv, offset_cv = np.polyfit(y_true, y_pred_cv, 1)
        rmse_cv = np.sqrt(mean_squared_error(y_true, y_pred_cv))
        r2_cv = r2_score(y_true, y_pred_cv)

        plt.figure(figsize=(10, 8))
        plt.scatter(y_true, y_pred_cv, color='blue', marker='o', alpha=0.7, label=f'Cross-Validation (R²={r2_cv:.3f})')
        
        # Linha ideal 1:1
        min_val = min(min(y_true), min(y_pred_cv))
        max_val = max(max(y_true), max(y_pred_cv))
        plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='Linha Ideal (1:1)')

        plt.xlabel("Valores Reais")
        plt.ylabel("Valores Preditos (CV)")
        plt.title(f'Cross-Validation: {atributo} | {modelo} | {filtro}')
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.legend(loc='lower right')
        
        # Adiciona texto com métricas
        stats_text = f'CV - R²: {r2_cv:.3f}, RMSE: {rmse_cv:.3f}, Slope: {slope_cv:.3f}, Offset: {offset_cv:.3f}'
        plt.text(0.05, 0.95, stats_text, transform=plt.gca().transAxes, fontsize=10,
                 verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5))

        plt.savefig(file_path, format='png', dpi=200, bbox_inches='tight')
        plt.close()

    except Exception as e:
        print(f"Erro ao gerar gráfico de CV para {modelo} com {filtro}: {e}")
        plt.close()

# %% [markdown]
# ### 6.1 Modelos e Grids de Parâmetros

# %%
import re


modelos = {
    'PLSR': {
        'estimador': PLSRegression(),
        'params': {'n_components': [5, 10, 15, 20]}
    },
    'PCR': {
        'estimador': Pipeline([('pca', PCA()), ('regressor', LinearRegression())]),
        'params': {'pca__n_components': [5, 10, 15, 20]}
    },
        'SVMR': {
        'estimador': SVR(),
        'params': {
            'C': [0.1, 1, 10, 100],
            'gamma': ['scale', 'auto', 0.001, 0.01, 0.1],
            'kernel': ['rbf', 'linear'],
            'epsilon': [0.1, 0.2, 0.5, 1.0]
        }
    },
     'RFR': {
        'estimador': RandomForestRegressor(random_state=42),
        'params': {
            'n_estimators': [100, 150, 200, 250, 300],
            'max_depth': [10, 20, 30, None],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 4],
            'warm_start': [True, False],
            'bootstrap': [True, False]
        }
     }

}

# Combina todos os filtros
todos_filtros = {**filtros_independentes, **filtros_dependentes}

# Lista para armazenar todos os resultados
lista_resultados_finais = []

#AQUI COMEÇA O CROSS VALIDATION -- PRINCIPAIS ALTERAÇÕES DO CÓDIGO DE ANDRESSA

cv_folds = 10  # Número de folds para cross-validation
kf = KFold(n_splits=cv_folds, shuffle=True, random_state=42)

for atributo in atributos: 
    print(f'\n{"="*30}')
    print(f'INICIANDO MODELAGEM PARA: {atributo}')
    print(f'{"="*30}')

    melhor_r2_atributo = -999  # Inicia com um valor muito baixo
    melhor_combinacao_info = {}  # Dicionário para guardar as infos do melhor
    
    # Dicionário para armazenar as 5 melhores combinações por modelo
    melhores_por_modelo = {nome: [] for nome in modelos.keys()}

    dados = dados_final[atributo]
    X_full, y_full = dados['X'], dados['y']

    for nome_modelo, info_modelo in modelos.items():
        print(f'\n--- Modelo: {nome_modelo} ---')
        
        combinacoes_deste_modelo = [] # Lista temporária para este modelo

        for nome_filtro, funcao_filtro in todos_filtros.items():
            start_time = time.time()
            print(f'  Testando filtro: {nome_filtro}...', end='')

            if nome_filtro in filtros_independentes:
                X_filtered = funcao_filtro(X_full)
                tipo_filtro = 'independente'
            else:  # Filtro dependente de Y
                X_filtered = funcao_filtro(X_full, y_full)
                tipo_filtro = 'dependente'
            
            grid = GridSearchCV(
                info_modelo['estimador'], 
                info_modelo['params'], 
                cv=kf,  # Usa o mesmo KFold para consistência
                scoring='r2', 
                n_jobs=-1
            )
            grid.fit(X_filtered, y_full)
            
            melhor_modelo = grid.best_estimator_
            
            cv_scores = cross_val_score(melhor_modelo, X_filtered, y_full, cv=kf, scoring='r2')
            cv_r2_mean = cv_scores.mean()
            cv_r2_std = cv_scores.std()
            
            # Predições de cross-validation para plotagem
            y_pred_cv = cross_val_predict(melhor_modelo, X_filtered, y_full, cv=kf)
            cv_rmse = np.sqrt(mean_squared_error(y_full, y_pred_cv))
            
            end_time = time.time()
            print(f' CV R²: {cv_r2_mean:.4f} (±{cv_r2_std:.4f}) | Concluído em {end_time - start_time:.2f}s')

            # Salvar o resultado da combinação atual
            resultados_atuais = {
                'Atributo': atributo,
                'Modelo': nome_modelo,
                'Filtro': nome_filtro,
                'Tipo_Filtro': tipo_filtro,
                'CV_R2_Mean': cv_r2_mean,
                'CV_R2_Std': cv_r2_std,
                'CV_RMSE': cv_rmse,
                'Grid_Best_Score': grid.best_score_,
                'Melhores_Params': str(grid.best_params_),
                'Tempo_s': end_time - start_time,
                'objeto_modelo': melhor_modelo 
            }
            
            lista_resultados_finais.append(resultados_atuais)
            combinacoes_deste_modelo.append(resultados_atuais)

            # Lógica para salvar o melhor modelo geral
            if cv_r2_mean > melhor_r2_atributo:
                melhor_r2_atributo = cv_r2_mean
                melhor_combinacao_info = {
                    'objeto_modelo': melhor_modelo,
                    'nome_modelo': nome_modelo,
                    'nome_filtro': nome_filtro,
                    'parametros': grid.best_params_
                }
            
            path_cv = f'graficos_modelos/cross_validation/{atributo}_{nome_modelo}_{nome_filtro}.png'
            os.makedirs('graficos_modelos/cross_validation', exist_ok=True)
            save_calibration_plot_cv(y_full, y_pred_cv, atributo, nome_filtro, nome_modelo, path_cv)

        # Ordenar e salvar as 5 melhores para este modelo
        combinacoes_deste_modelo.sort(key=lambda x: x['CV_R2_Mean'], reverse=True)
        melhores_por_modelo[nome_modelo] = combinacoes_deste_modelo[:5]
        atributo_limpo = re.sub(r"[ \/\[\]\(\)]", "_", atributo)
    if melhor_combinacao_info:  # Garante que encontrou pelo menos um modelo
        melhor_obj = melhor_combinacao_info['objeto_modelo']
        nome_arquivo_modelo = f"modelos_salvos/melhor_modelo_{atributo_limpo}.joblib"
        
        joblib.dump(melhor_obj, nome_arquivo_modelo)
        
        print(f"\n 🏆 MELHOR COMBINAÇÃO GERAL PARA '{atributo}' FOI SALVA!")
        print(f"   - Arquivo: {nome_arquivo_modelo}")
        print(f"   - Modelo: {melhor_combinacao_info['nome_modelo']}")
        print(f"   - Filtro: {melhor_combinacao_info['nome_filtro']}")
        print(f"   - Melhor R² CV: {melhor_r2_atributo:.4f}")
        print(f"   - Melhores Parâmetros: {melhor_combinacao_info['parametros']}")
    
    # Salvar os 5 melhores modelos para cada tipo
    print(f"\n--- Salvando os 5 melhores modelos para {atributo} ---")
    for nome_modelo, lista_combinacoes in melhores_por_modelo.items():
        for i, combinacao in enumerate(lista_combinacoes):
            nome_arquivo = f"modelos_salvos_top5/top_{i+1}_{atributo_limpo}_{combinacao['Modelo']}_{combinacao['Filtro']}.joblib"
            os.makedirs('modelos_salvos_top5', exist_ok=True)
            joblib.dump(combinacao['objeto_modelo'], nome_arquivo)
            print(f"  - Top {i+1} do modelo {nome_modelo} salvo em: {nome_arquivo}")

print('\n\n ✅ Modelagem exaustiva com Cross-Validation!')

df_completo = pd.DataFrame(lista_resultados_finais)
df_completo_ordenado = df_completo.sort_values(by=['Atributo', 'CV_R2_Mean'], ascending=[True, False])
df_completo_ordenado.to_excel('analise_completa_resultados_cv.xlsx', index=False)
print('  ✅Resultados salvos em "analise_completa_resultados_cv.xlsx"')

print("\n--- Melhores Resultados por Atributo (Cross-Validation) ---")
melhores_resultados = df_completo_ordenado.groupby('Atributo').first().reset_index()

# Arredondar colunas numéricas para melhor visualização
colunas_numericas_para_arredondar = ['CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE', 'Grid_Best_Score']
melhores_resultados[colunas_numericas_para_arredondar] = melhores_resultados[colunas_numericas_para_arredondar].round(4)

# Selecionar e exibir as colunas mais importantes
colunas_para_exibir = ['Atributo', 'Modelo', 'Filtro', 'CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE', 'Melhores_Params']
print(melhores_resultados[colunas_para_exibir].to_string(index=False))
# Out:
# ==============================
# INICIANDO MODELAGEM PARA: Firmness (N)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.8400 (±0.1001) | Concluído em 1.49s
#   Testando filtro: MSC... CV R²: 0.6674 (±0.1739) | Concluído em 0.04s
#   Testando filtro: SNV... CV R²: 0.6614 (±0.1705) | Concluído em 0.04s
#   Testando filtro: SG_D1... CV R²: 0.7895 (±0.1176) | Concluído em 0.05s
#   Testando filtro: SG_D2... CV R²: 0.6848 (±0.2039) | Concluído em 0.04s
#   Testando filtro: Detrend... CV R²: 0.7134 (±0.1162) | Concluído em 0.04s
#   Testando filtro: Normalize... CV R²: 0.6596 (±0.2213) | Concluído em 0.04s
#   Testando filtro: EMSC... CV R²: 0.6674 (±0.1739) | Concluído em 0.04s
#   Testando filtro: Continuum_Removal... CV R²: 0.7269 (±0.1283) | Concluído em 0.07s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.8401 (±0.1006) | Concluído em 0.04s
#   Testando filtro: OSC_1... CV R²: 0.8554 (±0.0959) | Concluído em 0.04s
#   Testando filtro: OSC_2... CV R²: 0.1508 (±0.6308) | Concluído em 0.04s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.7680 (±0.1234) | Concluído em 0.05s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.7661 (±0.1234) | Concluído em 0.05s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.7495 (±0.1144) | Concluído em 0.04s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.7203 (±0.1433) | Concluído em 0.05s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.8333 (±0.1104) | Concluído em 0.18s
#   Testando filtro: MSC... CV R²: 0.7248 (±0.1206) | Concluído em 0.13s
#   Testando filtro: SNV... CV R²: 0.7288 (±0.1213) | Concluído em 0.12s
#   Testando filtro: SG_D1... CV R²: 0.7543 (±0.1455) | Concluído em 0.13s
#   Testando filtro: SG_D2... CV R²: 0.6686 (±0.1813) | Concluído em 0.12s
#   Testando filtro: Detrend... CV R²: 0.7356 (±0.1465) | Concluído em 0.13s
#   Testando filtro: Normalize... CV R²: 0.7105 (±0.1485) | Concluído em 0.13s
#   Testando filtro: EMSC... CV R²: 0.7248 (±0.1206) | Concluído em 0.13s
#   Testando filtro: Continuum_Removal... CV R²: 0.7634 (±0.1234) | Concluído em 0.14s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.8336 (±0.1126) | Concluído em 0.13s
#   Testando filtro: OSC_1... CV R²: 0.8390 (±0.1003) | Concluído em 0.12s
#   Testando filtro: OSC_2... CV R²: 0.3547 (±0.4506) | Concluído em 0.12s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.7272 (±0.1300) | Concluído em 0.13s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.7276 (±0.1296) | Concluído em 0.13s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.7576 (±0.0861) | Concluído em 0.13s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.7331 (±0.1481) | Concluído em 0.13s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.6659 (±0.2001) | Concluído em 0.23s
#   Testando filtro: MSC... CV R²: -0.6147 (±0.8050) | Concluído em 0.23s
#   Testando filtro: SNV... CV R²: 0.2541 (±0.2053) | Concluído em 0.23s
#   Testando filtro: SG_D1... CV R²: -1.2554 (±1.3155) | Concluído em 0.23s
#   Testando filtro: SG_D2... CV R²: -1.1747 (±1.2992) | Concluído em 0.23s
#   Testando filtro: Detrend... CV R²: -0.5463 (±0.7165) | Concluído em 0.22s
#   Testando filtro: Normalize... CV R²: -0.2150 (±0.4168) | Concluído em 0.23s
#   Testando filtro: EMSC... CV R²: -0.6147 (±0.8050) | Concluído em 0.24s
#   Testando filtro: Continuum_Removal... CV R²: 0.6683 (±0.1917) | Concluído em 0.24s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.6662 (±0.1995) | Concluído em 0.23s
#   Testando filtro: OSC_1... CV R²: 0.8987 (±0.0968) | Concluído em 0.24s
#   Testando filtro: OSC_2... CV R²: 0.3924 (±0.4924) | Concluído em 0.23s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.3697 (±0.2604) | Concluído em 0.23s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.3664 (±0.2738) | Concluído em 0.24s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.5597 (±0.2151) | Concluído em 0.23s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -1.2940 (±1.4694) | Concluído em 0.23s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.8162 (±0.2728) | Concluído em 137.82s
#   Testando filtro: MSC... CV R²: 0.4126 (±0.2918) | Concluído em 186.59s
#   Testando filtro: SNV... CV R²: 0.3884 (±0.3078) | Concluído em 188.21s
#   Testando filtro: SG_D1... CV R²: 0.4101 (±0.3824) | Concluído em 171.62s
#   Testando filtro: SG_D2... CV R²: 0.4998 (±0.4051) | Concluído em 174.45s
#   Testando filtro: Detrend... CV R²: -0.0823 (±0.3309) | Concluído em 164.25s
#   Testando filtro: Normalize... CV R²: 0.5205 (±0.3375) | Concluído em 163.76s
#   Testando filtro: EMSC... CV R²: 0.4126 (±0.2918) | Concluído em 186.26s
#   Testando filtro: Continuum_Removal... CV R²: 0.9304 (±0.0389) | Concluído em 130.64s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.8111 (±0.2925) | Concluído em 141.69s
#   Testando filtro: OSC_1... CV R²: 0.9329 (±0.0471) | Concluído em 150.65s
#   Testando filtro: OSC_2... CV R²: 0.3070 (±0.5625) | Concluído em 156.96s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.3696 (±0.2945) | Concluído em 175.23s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.3285 (±0.3131) | Concluído em 175.99s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.4834 (±0.3565) | Concluído em 178.13s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.6904 (±0.4994) | Concluído em 168.44s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Firmness (N)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Firmness__N_.joblib
#    - Modelo: RFR
#    - Filtro: OSC_1
#    - Melhor R² CV: 0.9329
#    - Melhores Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'warm_start': True}
#
# --- Salvando os 5 melhores modelos para Firmness (N) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Firmness__N__PLSR_OSC_1.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Firmness__N__PLSR_Wavelet_Denoising.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Firmness__N__PLSR_Raw.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Firmness__N__PLSR_SG_D1.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Firmness__N__PLSR_MSC_SG_OSC.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Firmness__N__PCR_OSC_1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Firmness__N__PCR_Wavelet_Denoising.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Firmness__N__PCR_Raw.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Firmness__N__PCR_Continuum_Removal.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Firmness__N__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Firmness__N__SVMR_OSC_1.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Firmness__N__SVMR_Continuum_Removal.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Firmness__N__SVMR_Wavelet_Denoising.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Firmness__N__SVMR_Raw.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Firmness__N__SVMR_OPLS2_SNV_SG_D1.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Firmness__N__RFR_OSC_1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Firmness__N__RFR_Continuum_Removal.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Firmness__N__RFR_Raw.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Firmness__N__RFR_Wavelet_Denoising.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Firmness__N__RFR_SNV_Detrend_SG_D1.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: Dry Mass (%)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.1390 (±0.5914) | Concluído em 0.04s
#   Testando filtro: MSC... CV R²: 0.0358 (±0.7687) | Concluído em 0.04s
#   Testando filtro: SNV... CV R²: 0.0335 (±0.7814) | Concluído em 0.04s
#   Testando filtro: SG_D1... CV R²: -0.2147 (±0.8848) | Concluído em 0.04s
#   Testando filtro: SG_D2... CV R²: -0.5454 (±0.6759) | Concluído em 0.04s
#   Testando filtro: Detrend... CV R²: 0.1409 (±0.6020) | Concluído em 0.04s
#   Testando filtro: Normalize... CV R²: 0.0310 (±0.6184) | Concluído em 0.04s
#   Testando filtro: EMSC... CV R²: 0.0358 (±0.7687) | Concluído em 0.04s
#   Testando filtro: Continuum_Removal... CV R²: -0.5911 (±1.0902) | Concluído em 0.06s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.1335 (±0.5940) | Concluído em 0.04s
#   Testando filtro: OSC_1... CV R²: 0.0968 (±0.7853) | Concluído em 0.04s
#   Testando filtro: OSC_2... CV R²: 0.1199 (±0.6668) | Concluído em 0.04s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.2267 (±0.7527) | Concluído em 0.04s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.1978 (±0.7539) | Concluído em 0.04s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.3276 (±0.9522) | Concluído em 0.04s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.1930 (±0.7938) | Concluído em 0.04s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.1049 (±0.4785) | Concluído em 0.13s
#   Testando filtro: MSC... CV R²: 0.2282 (±0.4552) | Concluído em 0.12s
#   Testando filtro: SNV... CV R²: 0.2264 (±0.4684) | Concluído em 0.12s
#   Testando filtro: SG_D1... CV R²: 0.1992 (±0.4131) | Concluído em 0.13s
#   Testando filtro: SG_D2... CV R²: 0.2820 (±0.4280) | Concluído em 0.12s
#   Testando filtro: Detrend... CV R²: 0.2422 (±0.3935) | Concluído em 0.12s
#   Testando filtro: Normalize... CV R²: 0.1879 (±0.5088) | Concluído em 0.13s
#   Testando filtro: EMSC... CV R²: 0.2282 (±0.4552) | Concluído em 0.13s
#   Testando filtro: Continuum_Removal... CV R²: 0.0577 (±0.3426) | Concluído em 0.14s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.1050 (±0.4787) | Concluído em 0.12s
#   Testando filtro: OSC_1... CV R²: 0.2729 (±0.4798) | Concluído em 0.12s
#   Testando filtro: OSC_2... CV R²: 0.2576 (±0.4973) | Concluído em 0.12s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.2300 (±0.4398) | Concluído em 0.13s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2352 (±0.4363) | Concluído em 0.12s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.2132 (±0.4937) | Concluído em 0.13s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.1601 (±0.4964) | Concluído em 0.13s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.2160 (±0.4079) | Concluído em 0.23s
#   Testando filtro: MSC... CV R²: -0.1070 (±0.4203) | Concluído em 0.24s
#   Testando filtro: SNV... CV R²: 0.2316 (±0.4262) | Concluído em 0.23s
#   Testando filtro: SG_D1... CV R²: 0.2225 (±0.4155) | Concluído em 0.24s
#   Testando filtro: SG_D2... CV R²: 0.2725 (±0.3754) | Concluído em 0.23s
#   Testando filtro: Detrend... CV R²: 0.2337 (±0.3909) | Concluído em 0.23s
#   Testando filtro: Normalize... CV R²: 0.0091 (±0.3956) | Concluído em 0.23s
#   Testando filtro: EMSC... CV R²: -0.1070 (±0.4203) | Concluído em 0.23s
#   Testando filtro: Continuum_Removal... CV R²: -0.3235 (±0.4211) | Concluído em 0.25s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.2143 (±0.4091) | Concluído em 0.25s
#   Testando filtro: OSC_1... CV R²: -0.1239 (±0.4309) | Concluído em 0.40s
#   Testando filtro: OSC_2... CV R²: 0.2753 (±0.6176) | Concluído em 0.24s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.3038 (±0.4401) | Concluído em 0.24s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2733 (±0.4724) | Concluído em 0.23s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.2404 (±0.4045) | Concluído em 0.23s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.0046 (±0.3694) | Concluído em 0.24s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.0142 (±0.2703) | Concluído em 149.53s
#   Testando filtro: MSC... CV R²: 0.2804 (±0.3650) | Concluído em 161.36s
#   Testando filtro: SNV... CV R²: 0.2893 (±0.3586) | Concluído em 164.83s
#   Testando filtro: SG_D1... CV R²: 0.1614 (±0.4604) | Concluído em 162.43s
#   Testando filtro: SG_D2... CV R²: 0.2014 (±0.5361) | Concluído em 160.45s
#   Testando filtro: Detrend... CV R²: 0.1303 (±0.4506) | Concluído em 160.81s
#   Testando filtro: Normalize... CV R²: 0.2351 (±0.4005) | Concluído em 163.16s
#   Testando filtro: EMSC... CV R²: 0.2804 (±0.3650) | Concluído em 161.57s
#   Testando filtro: Continuum_Removal... CV R²: -0.1047 (±0.5325) | Concluído em 132.08s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.0362 (±0.4624) | Concluído em 150.94s
#   Testando filtro: OSC_1... CV R²: -0.3449 (±0.6451) | Concluído em 139.31s
#   Testando filtro: OSC_2... CV R²: -0.3588 (±0.7947) | Concluído em 170.11s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.0118 (±0.5031) | Concluído em 166.84s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.0284 (±0.3544) | Concluído em 166.06s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.2235 (±0.4777) | Concluído em 160.05s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.1950 (±0.3949) | Concluído em 165.30s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Dry Mass (%)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Dry_Mass__%_.joblib
#    - Modelo: SVMR
#    - Filtro: MSC_SG_OSC
#    - Melhor R² CV: 0.3038
#    - Melhores Parâmetros: {'C': 100, 'epsilon': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
#
# --- Salvando os 5 melhores modelos para Dry Mass (%) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Dry_Mass__%__PLSR_Detrend.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Dry_Mass__%__PLSR_Raw.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Dry_Mass__%__PLSR_Wavelet_Denoising.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Dry_Mass__%__PLSR_OSC_2.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Dry_Mass__%__PLSR_OSC_1.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Dry_Mass__%__PCR_SG_D2.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Dry_Mass__%__PCR_OSC_1.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Dry_Mass__%__PCR_OSC_2.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Dry_Mass__%__PCR_Detrend.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Dry_Mass__%__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Dry_Mass__%__SVMR_MSC_SG_OSC.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Dry_Mass__%__SVMR_OSC_2.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Dry_Mass__%__SVMR_OPLS1_SNV_SG_D1.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Dry_Mass__%__SVMR_SG_D2.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Dry_Mass__%__SVMR_OPLS2_SNV_SG_D1.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Dry_Mass__%__RFR_SNV.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Dry_Mass__%__RFR_MSC.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Dry_Mass__%__RFR_EMSC.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Dry_Mass__%__RFR_Normalize.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Dry_Mass__%__RFR_OPLS2_SNV_SG_D1.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: TSS (Brix)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: -0.3693 (±0.9292) | Concluído em 0.04s
#   Testando filtro: MSC... CV R²: -0.1534 (±0.8412) | Concluído em 0.04s
#   Testando filtro: SNV... CV R²: -0.1308 (±0.7874) | Concluído em 0.04s
#   Testando filtro: SG_D1... CV R²: -0.3532 (±0.9990) | Concluído em 0.04s
#   Testando filtro: SG_D2... CV R²: -0.7748 (±1.0839) | Concluído em 0.04s
#   Testando filtro: Detrend... CV R²: -0.1484 (±0.9726) | Concluído em 0.04s
#   Testando filtro: Normalize... CV R²: 0.0095 (±0.6604) | Concluído em 0.04s
#   Testando filtro: EMSC... CV R²: -0.1534 (±0.8412) | Concluído em 0.04s
#   Testando filtro: Continuum_Removal... CV R²: -0.9544 (±1.5416) | Concluído em 0.05s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.3586 (±0.9354) | Concluído em 0.04s
#   Testando filtro: OSC_1... CV R²: -0.1095 (±0.7020) | Concluído em 0.04s
#   Testando filtro: OSC_2... CV R²: -0.3356 (±0.9506) | Concluído em 0.04s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.1638 (±0.8516) | Concluído em 0.04s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.1548 (±0.8304) | Concluído em 0.04s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.2886 (±0.9305) | Concluído em 0.04s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.2178 (±0.8905) | Concluído em 0.04s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: -0.1736 (±1.1392) | Concluído em 0.11s
#   Testando filtro: MSC... CV R²: 0.0112 (±0.7345) | Concluído em 0.12s
#   Testando filtro: SNV... CV R²: 0.0124 (±0.7378) | Concluído em 0.12s
#   Testando filtro: SG_D1... CV R²: -0.0828 (±0.9910) | Concluído em 0.12s
#   Testando filtro: SG_D2... CV R²: -0.0528 (±0.8848) | Concluído em 0.12s
#   Testando filtro: Detrend... CV R²: -0.1825 (±1.0893) | Concluído em 0.11s
#   Testando filtro: Normalize... CV R²: -0.0338 (±0.6507) | Concluído em 0.12s
#   Testando filtro: EMSC... CV R²: 0.0112 (±0.7345) | Concluído em 0.12s
#   Testando filtro: Continuum_Removal... CV R²: -0.6056 (±1.5064) | Concluído em 0.14s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.1743 (±1.1394) | Concluído em 0.13s
#   Testando filtro: OSC_1... CV R²: -0.1131 (±0.8185) | Concluído em 0.12s
#   Testando filtro: OSC_2... CV R²: -0.0001 (±0.6866) | Concluído em 0.12s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.0438 (±0.6883) | Concluído em 0.12s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.0488 (±0.6873) | Concluído em 0.11s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.1080 (±0.6475) | Concluído em 0.12s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.0577 (±0.7100) | Concluído em 0.12s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.0302 (±0.7783) | Concluído em 0.25s
#   Testando filtro: MSC... CV R²: -0.2218 (±0.7105) | Concluído em 0.25s
#   Testando filtro: SNV... CV R²: 0.0014 (±0.7526) | Concluído em 0.24s
#   Testando filtro: SG_D1... CV R²: 0.0164 (±0.7988) | Concluído em 0.25s
#   Testando filtro: SG_D2... CV R²: -0.0152 (±0.8429) | Concluído em 0.26s
#   Testando filtro: Detrend... CV R²: 0.0797 (±0.6668) | Concluído em 0.25s
#   Testando filtro: Normalize... CV R²: -0.2681 (±0.4621) | Concluído em 0.25s
#   Testando filtro: EMSC... CV R²: -0.2218 (±0.7105) | Concluído em 0.25s
#   Testando filtro: Continuum_Removal... CV R²: -0.2681 (±0.4621) | Concluído em 0.27s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.0304 (±0.7782) | Concluído em 0.26s
#   Testando filtro: OSC_1... CV R²: -0.0974 (±0.3286) | Concluído em 0.27s
#   Testando filtro: OSC_2... CV R²: 0.0102 (±0.7503) | Concluído em 0.26s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.0302 (±0.7495) | Concluído em 0.45s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.0722 (±0.7632) | Concluído em 0.26s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.0992 (±0.5582) | Concluído em 0.26s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.2063 (±0.8471) | Concluído em 0.25s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: -0.0516 (±0.6813) | Concluído em 146.44s
#   Testando filtro: MSC... CV R²: -0.0674 (±0.8427) | Concluído em 171.11s
#   Testando filtro: SNV... CV R²: -0.1211 (±0.9052) | Concluído em 172.64s
#   Testando filtro: SG_D1... CV R²: -0.1400 (±0.7424) | Concluído em 152.47s
#   Testando filtro: SG_D2... CV R²: 0.0330 (±0.6562) | Concluído em 145.65s
#   Testando filtro: Detrend... CV R²: -0.0780 (±1.1173) | Concluído em 153.68s
#   Testando filtro: Normalize... CV R²: -0.2755 (±0.8396) | Concluído em 149.72s
#   Testando filtro: EMSC... CV R²: -0.0674 (±0.8427) | Concluído em 170.69s
#   Testando filtro: Continuum_Removal... CV R²: -0.2888 (±0.9689) | Concluído em 129.03s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.0556 (±0.6819) | Concluído em 147.42s
#   Testando filtro: OSC_1... CV R²: -0.3442 (±0.3186) | Concluído em 146.24s
#   Testando filtro: OSC_2... CV R²: -0.1195 (±0.9568) | Concluído em 148.86s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.1461 (±0.6607) | Concluído em 153.86s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.0957 (±0.7447) | Concluído em 153.99s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.0055 (±0.5699) | Concluído em 153.68s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.0886 (±0.6147) | Concluído em 150.49s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'TSS (Brix)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_TSS__Brix_.joblib
#    - Modelo: PCR
#    - Filtro: OPLS2_SNV_SG_D1
#    - Melhor R² CV: 0.1080
#    - Melhores Parâmetros: {'pca__n_components': 5}
#
# --- Salvando os 5 melhores modelos para TSS (Brix) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_TSS__Brix__PLSR_Normalize.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_TSS__Brix__PLSR_OSC_1.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_TSS__Brix__PLSR_SNV.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_TSS__Brix__PLSR_Detrend.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_TSS__Brix__PLSR_MSC.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_TSS__Brix__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_TSS__Brix__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_TSS__Brix__PCR_MSC_SG_OSC.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_TSS__Brix__PCR_SNV.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_TSS__Brix__PCR_MSC.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_TSS__Brix__SVMR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_TSS__Brix__SVMR_Detrend.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_TSS__Brix__SVMR_Wavelet_Denoising.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_TSS__Brix__SVMR_Raw.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_TSS__Brix__SVMR_SG_D1.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_TSS__Brix__RFR_SG_D2.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_TSS__Brix__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_TSS__Brix__RFR_Raw.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_TSS__Brix__RFR_Wavelet_Denoising.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_TSS__Brix__RFR_MSC.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: TA (g/mL)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.6115 (±0.2222) | Concluído em 0.04s
#   Testando filtro: MSC... CV R²: 0.5245 (±0.2517) | Concluído em 0.04s
#   Testando filtro: SNV... CV R²: 0.4912 (±0.2889) | Concluído em 0.04s
#   Testando filtro: SG_D1... CV R²: 0.2957 (±0.2955) | Concluído em 0.04s
#   Testando filtro: SG_D2... CV R²: 0.3715 (±0.3016) | Concluído em 0.04s
#   Testando filtro: Detrend... CV R²: 0.5233 (±0.1833) | Concluído em 0.04s
#   Testando filtro: Normalize... CV R²: 0.3998 (±0.2812) | Concluído em 0.04s
#   Testando filtro: EMSC... CV R²: 0.5245 (±0.2517) | Concluído em 0.04s
#   Testando filtro: Continuum_Removal... CV R²: 0.3682 (±0.3118) | Concluído em 0.06s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.6107 (±0.2231) | Concluído em 0.04s
#   Testando filtro: OSC_1... CV R²: 0.6060 (±0.2226) | Concluído em 0.04s
#   Testando filtro: OSC_2... CV R²: -0.0316 (±0.6457) | Concluído em 0.04s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.4729 (±0.2167) | Concluído em 0.04s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.4613 (±0.2171) | Concluído em 0.04s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.4329 (±0.2842) | Concluído em 0.04s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.4787 (±0.2723) | Concluído em 0.04s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.5892 (±0.2359) | Concluído em 0.13s
#   Testando filtro: MSC... CV R²: 0.5289 (±0.1740) | Concluído em 0.13s
#   Testando filtro: SNV... CV R²: 0.5294 (±0.1739) | Concluído em 0.13s
#   Testando filtro: SG_D1... CV R²: 0.5543 (±0.2396) | Concluído em 0.13s
#   Testando filtro: SG_D2... CV R²: 0.4728 (±0.2205) | Concluído em 0.13s
#   Testando filtro: Detrend... CV R²: 0.5413 (±0.1450) | Concluído em 0.13s
#   Testando filtro: Normalize... CV R²: 0.5166 (±0.1492) | Concluído em 0.13s
#   Testando filtro: EMSC... CV R²: 0.5289 (±0.1740) | Concluído em 0.13s
#   Testando filtro: Continuum_Removal... CV R²: 0.5126 (±0.1993) | Concluído em 0.14s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.5795 (±0.2411) | Concluído em 0.13s
#   Testando filtro: OSC_1... CV R²: 0.5953 (±0.2192) | Concluído em 0.13s
#   Testando filtro: OSC_2... CV R²: 0.2294 (±0.3324) | Concluído em 0.13s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.5458 (±0.2489) | Concluído em 0.13s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.5452 (±0.2495) | Concluído em 0.13s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.5149 (±0.2414) | Concluído em 0.13s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.5461 (±0.2298) | Concluído em 0.13s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.5713 (±0.2523) | Concluído em 0.27s
#   Testando filtro: MSC... CV R²: 0.5005 (±0.1673) | Concluído em 0.51s
#   Testando filtro: SNV... CV R²: 0.5079 (±0.1991) | Concluído em 0.24s
#   Testando filtro: SG_D1... CV R²: 0.5551 (±0.1768) | Concluído em 0.25s
#   Testando filtro: SG_D2... CV R²: 0.3965 (±0.2281) | Concluído em 0.25s
#   Testando filtro: Detrend... CV R²: 0.5047 (±0.1855) | Concluído em 0.26s
#   Testando filtro: Normalize... CV R²: 0.5050 (±0.2144) | Concluído em 0.25s
#   Testando filtro: EMSC... CV R²: 0.5005 (±0.1673) | Concluído em 0.25s
#   Testando filtro: Continuum_Removal... CV R²: 0.5040 (±0.2238) | Concluído em 0.26s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.5717 (±0.2461) | Concluído em 0.29s
#   Testando filtro: OSC_1... CV R²: 0.5946 (±0.2399) | Concluído em 0.25s
#   Testando filtro: OSC_2... CV R²: 0.2870 (±0.2776) | Concluído em 0.25s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.4391 (±0.1967) | Concluído em 0.26s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.4426 (±0.1953) | Concluído em 0.25s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.4182 (±0.2177) | Concluído em 0.25s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.5268 (±0.2205) | Concluído em 0.24s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.4852 (±0.3446) | Concluído em 142.60s
#   Testando filtro: MSC... CV R²: 0.4353 (±0.2044) | Concluído em 159.66s
#   Testando filtro: SNV... CV R²: 0.4381 (±0.2085) | Concluído em 165.18s
#   Testando filtro: SG_D1... CV R²: 0.3807 (±0.3056) | Concluído em 160.42s
#   Testando filtro: SG_D2... CV R²: 0.3739 (±0.3535) | Concluído em 156.94s
#   Testando filtro: Detrend... CV R²: 0.0768 (±0.4070) | Concluído em 175.86s
#   Testando filtro: Normalize... CV R²: 0.4204 (±0.3025) | Concluído em 155.53s
#   Testando filtro: EMSC... CV R²: 0.4353 (±0.2044) | Concluído em 159.33s
#   Testando filtro: Continuum_Removal... CV R²: 0.5660 (±0.1791) | Concluído em 135.71s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.4846 (±0.3457) | Concluído em 143.83s
#   Testando filtro: OSC_1... CV R²: 0.5010 (±0.2645) | Concluído em 153.47s
#   Testando filtro: OSC_2... CV R²: 0.2589 (±0.3712) | Concluído em 149.36s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.4575 (±0.1791) | Concluído em 165.94s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.4594 (±0.1621) | Concluído em 157.69s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.5641 (±0.2388) | Concluído em 155.87s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.6333 (±0.2114) | Concluído em 163.64s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'TA (g/mL)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_TA__g_mL_.joblib
#    - Modelo: RFR
#    - Filtro: SNV_Detrend_SG_D1
#    - Melhor R² CV: 0.6333
#    - Melhores Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 250, 'warm_start': True}
#
# --- Salvando os 5 melhores modelos para TA (g/mL) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_TA__g_mL__PLSR_Raw.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_TA__g_mL__PLSR_Wavelet_Denoising.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_TA__g_mL__PLSR_OSC_1.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_TA__g_mL__PLSR_MSC.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_TA__g_mL__PLSR_EMSC.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_TA__g_mL__PCR_OSC_1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_TA__g_mL__PCR_Raw.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_TA__g_mL__PCR_Wavelet_Denoising.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_TA__g_mL__PCR_SG_D1.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_TA__g_mL__PCR_SNV_Detrend_SG_D1.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_TA__g_mL__SVMR_OSC_1.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_TA__g_mL__SVMR_Wavelet_Denoising.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_TA__g_mL__SVMR_Raw.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_TA__g_mL__SVMR_SG_D1.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_TA__g_mL__SVMR_SNV_Detrend_SG_D1.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_TA__g_mL__RFR_SNV_Detrend_SG_D1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_TA__g_mL__RFR_Continuum_Removal.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_TA__g_mL__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_TA__g_mL__RFR_OSC_1.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_TA__g_mL__RFR_Raw.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: AA (mg/100g)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: -0.4069 (±1.3468) | Concluído em 0.04s
#   Testando filtro: MSC... CV R²: -0.4478 (±1.1317) | Concluído em 0.04s
#   Testando filtro: SNV... CV R²: -0.5574 (±1.4119) | Concluído em 0.04s
#   Testando filtro: SG_D1... CV R²: -0.9975 (±2.0037) | Concluído em 0.04s
#   Testando filtro: SG_D2... CV R²: -0.9163 (±1.3648) | Concluído em 0.05s
#   Testando filtro: Detrend... CV R²: -0.4531 (±1.3226) | Concluído em 0.04s
#   Testando filtro: Normalize... CV R²: -0.7100 (±1.2221) | Concluído em 0.04s
#   Testando filtro: EMSC... CV R²: -0.4478 (±1.1317) | Concluído em 0.04s
#   Testando filtro: Continuum_Removal... CV R²: -1.2354 (±2.2086) | Concluído em 0.06s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.4053 (±1.3479) | Concluído em 0.04s
#   Testando filtro: OSC_1... CV R²: -0.8874 (±1.5362) | Concluído em 0.04s
#   Testando filtro: OSC_2... CV R²: -1.1456 (±1.6639) | Concluído em 0.04s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.7698 (±1.7863) | Concluído em 0.04s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.7315 (±1.7230) | Concluído em 0.04s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.7842 (±1.7317) | Concluído em 0.04s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.8433 (±1.2486) | Concluído em 0.05s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: -0.3663 (±1.2883) | Concluído em 0.13s
#   Testando filtro: MSC... CV R²: -0.2650 (±0.9248) | Concluído em 0.14s
#   Testando filtro: SNV... CV R²: -0.2642 (±0.9249) | Concluído em 0.13s
#   Testando filtro: SG_D1... CV R²: -0.4622 (±1.6711) | Concluído em 0.13s
#   Testando filtro: SG_D2... CV R²: -0.1893 (±1.0512) | Concluído em 0.13s
#   Testando filtro: Detrend... CV R²: -0.3563 (±1.2334) | Concluído em 0.13s
#   Testando filtro: Normalize... CV R²: -0.2819 (±0.7570) | Concluído em 0.13s
#   Testando filtro: EMSC... CV R²: -0.2650 (±0.9248) | Concluído em 0.13s
#   Testando filtro: Continuum_Removal... CV R²: -0.6004 (±1.5744) | Concluído em 0.15s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.3671 (±1.2907) | Concluído em 0.13s
#   Testando filtro: OSC_1... CV R²: -0.3097 (±1.1999) | Concluído em 0.13s
#   Testando filtro: OSC_2... CV R²: -0.3077 (±1.0532) | Concluído em 0.13s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.4900 (±1.7645) | Concluído em 0.14s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.4912 (±1.7652) | Concluído em 0.14s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.5001 (±1.7345) | Concluído em 0.14s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.4954 (±1.7111) | Concluído em 0.13s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: -0.0739 (±0.6907) | Concluído em 0.25s
#   Testando filtro: MSC... CV R²: -0.3158 (±0.3999) | Concluído em 0.26s
#   Testando filtro: SNV... CV R²: -0.2827 (±0.4337) | Concluído em 0.26s
#   Testando filtro: SG_D1... CV R²: -0.1242 (±0.4714) | Concluído em 0.26s
#   Testando filtro: SG_D2... CV R²: -0.1344 (±0.4159) | Concluído em 0.25s
#   Testando filtro: Detrend... CV R²: -0.1178 (±0.4584) | Concluído em 0.25s
#   Testando filtro: Normalize... CV R²: -0.2259 (±0.4125) | Concluído em 0.26s
#   Testando filtro: EMSC... CV R²: -0.3158 (±0.3999) | Concluído em 0.26s
#   Testando filtro: Continuum_Removal... CV R²: -0.3308 (±0.4208) | Concluído em 0.28s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.0740 (±0.6908) | Concluído em 0.25s
#   Testando filtro: OSC_1... CV R²: -0.1896 (±1.4472) | Concluído em 0.24s
#   Testando filtro: OSC_2... CV R²: -0.1975 (±0.7576) | Concluído em 0.25s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.3600 (±0.4379) | Concluído em 0.27s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.3552 (±0.4405) | Concluído em 0.26s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.3001 (±0.4841) | Concluído em 0.26s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.3051 (±0.4017) | Concluído em 0.26s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.1011 (±0.5798) | Concluído em 139.60s
#   Testando filtro: MSC... CV R²: -0.7476 (±1.8060) | Concluído em 173.97s
#   Testando filtro: SNV... CV R²: -0.7557 (±1.7916) | Concluído em 175.40s
#   Testando filtro: SG_D1... CV R²: -0.5665 (±1.6974) | Concluído em 164.93s
#   Testando filtro: SG_D2... CV R²: -0.3918 (±1.0726) | Concluído em 173.38s
#   Testando filtro: Detrend... CV R²: -0.2987 (±1.1451) | Concluído em 156.31s
#   Testando filtro: Normalize... CV R²: -0.4420 (±1.5217) | Concluído em 160.74s
#   Testando filtro: EMSC... CV R²: -0.7476 (±1.8060) | Concluído em 173.78s
#   Testando filtro: Continuum_Removal... CV R²: -0.0642 (±0.6911) | Concluído em 143.20s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.0937 (±0.5562) | Concluído em 137.68s
#   Testando filtro: OSC_1... CV R²: -0.2546 (±1.7851) | Concluído em 153.75s
#   Testando filtro: OSC_2... CV R²: -0.4732 (±1.2624) | Concluído em 164.29s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.5689 (±1.3433) | Concluído em 167.34s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.6113 (±1.4220) | Concluído em 189.73s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.5587 (±2.0961) | Concluído em 262.07s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.2932 (±1.2841) | Concluído em 174.49s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'AA (mg/100g)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_AA__mg_100g_.joblib
#    - Modelo: RFR
#    - Filtro: Raw
#    - Melhor R² CV: 0.1011
#    - Melhores Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200, 'warm_start': True}
#
# --- Salvando os 5 melhores modelos para AA (mg/100g) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_AA__mg_100g__PLSR_Wavelet_Denoising.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_AA__mg_100g__PLSR_Raw.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_AA__mg_100g__PLSR_EMSC.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_AA__mg_100g__PLSR_MSC.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_AA__mg_100g__PLSR_Detrend.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_AA__mg_100g__PCR_SG_D2.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_AA__mg_100g__PCR_SNV.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_AA__mg_100g__PCR_MSC.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_AA__mg_100g__PCR_EMSC.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_AA__mg_100g__PCR_Normalize.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_AA__mg_100g__SVMR_Raw.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_AA__mg_100g__SVMR_Wavelet_Denoising.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_AA__mg_100g__SVMR_Detrend.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_AA__mg_100g__SVMR_SG_D1.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_AA__mg_100g__SVMR_SG_D2.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_AA__mg_100g__RFR_Raw.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_AA__mg_100g__RFR_Wavelet_Denoising.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_AA__mg_100g__RFR_Continuum_Removal.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_AA__mg_100g__RFR_OSC_1.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_AA__mg_100g__RFR_SNV_Detrend_SG_D1.joblib
#
#
#  ✅ Modelagem exaustiva com Cross-Validation!
#   ✅Resultados salvos em "analise_completa_resultados_cv.xlsx"
#
# --- Melhores Resultados por Atributo (Cross-Validation) ---
#     Atributo Modelo            Filtro  CV_R2_Mean  CV_R2_Std  CV_RMSE                                                                                                               Melhores_Params
# AA (mg/100g)    RFR               Raw      0.1011     0.5798   4.4642  {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200, 'warm_start': True}
# Dry Mass (%)   SVMR        MSC_SG_OSC      0.3038     0.4401   1.0144                                                                 {'C': 100, 'epsilon': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# Firmness (N)    RFR             OSC_1      0.9329     0.0471  11.1592 {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'warm_start': True}
#    TA (g/mL)    RFR SNV_Detrend_SG_D1      0.6333     0.2114   0.0981  {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 250, 'warm_start': True}
#   TSS (Brix)    PCR   OPLS2_SNV_SG_D1      0.1080     0.6475   1.2125                                                                                                      {'pca__n_components': 5}

# %% [markdown]
# ## 7. Análise Comparativa dos Resultados

# %%
import pandas as pd
import numpy as np

# Carregar os resultados salvos para análise
df_analise = pd.read_excel('analise_completa_resultados_cv.xlsx')

idx = df_analise.groupby(['Atributo', 'Modelo'])['CV_R2_Mean'].transform(max) == df_analise['CV_R2_Mean']
df_melhores_por_modelo = df_analise[idx]

print("--- Tabela Comparativa dos Melhores Resultados por Modelo (Cross-Validation) ---")
print(df_melhores_por_modelo[['Atributo', 'Modelo', 'Filtro', 'CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE']].round(4))

print("\n--- Melhores Modelos Gerais por Atributo (baseado no R² de Cross-Validation) ---")
idx_geral = df_melhores_por_modelo.groupby(['Atributo'])['CV_R2_Mean'].transform(max) == df_melhores_por_modelo['CV_R2_Mean']
df_melhores_gerais = df_melhores_por_modelo[idx_geral]
print(df_melhores_gerais[['Atributo', 'Modelo', 'Filtro', 'CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE']].round(4))

# Análise estatística adicional
print("\n--- Análise Estatística dos Resultados ---")
print(f"Número total de combinações testadas: {len(df_analise)}")
print(f"Número de atributos analisados: {df_analise['Atributo'].nunique()}")
print(f"Número de modelos testados: {df_analise['Modelo'].nunique()}")
print(f"Número de filtros testados: {df_analise['Filtro'].nunique()}")

print(f"\nEstatísticas do R² de Cross-Validation:")
print(f"  Média geral: {df_analise['CV_R2_Mean'].mean():.4f}")
print(f"  Desvio padrão: {df_analise['CV_R2_Mean'].std():.4f}")
print(f"  Melhor resultado: {df_analise['CV_R2_Mean'].max():.4f}")
print(f"  Pior resultado: {df_analise['CV_R2_Mean'].min():.4f}")

# Análise por modelo
print(f"\n--- Desempenho Médio por Modelo ---")
desempenho_por_modelo = df_analise.groupby('Modelo')['CV_R2_Mean'].agg(['mean', 'std', 'max', 'min']).round(4)
print(desempenho_por_modelo)

# Análise por filtro
print(f"\n--- Top 10 Filtros com Melhor Desempenho Médio ---")
desempenho_por_filtro = df_analise.groupby('Filtro')['CV_R2_Mean'].agg(['mean', 'std', 'count']).round(4)
desempenho_por_filtro = desempenho_por_filtro.sort_values('mean', ascending=False)
print(desempenho_por_filtro.head(10))

print("\n✅ Análise de resultados concluída!")
# Out:
# --- Tabela Comparativa dos Melhores Resultados por Modelo (Cross-Validation) ---
#          Atributo Modelo             Filtro  CV_R2_Mean  CV_R2_Std  CV_RMSE
# 0    AA (mg/100g)    RFR                Raw      0.1011     0.5798   4.4642
# 3    AA (mg/100g)   SVMR                Raw     -0.0739     0.6907   4.9587
# 8    AA (mg/100g)    PCR              SG_D2     -0.1893     1.0512   4.9027
# 33   AA (mg/100g)   PLSR  Wavelet_Denoising     -0.4053     1.3479   5.1794
# 64   Dry Mass (%)   SVMR         MSC_SG_OSC      0.3038     0.4401   1.0144
# 65   Dry Mass (%)    RFR                SNV      0.2893     0.3586   1.0904
# 66   Dry Mass (%)    PCR              SG_D2      0.2820     0.4280   1.1033
# 95   Dry Mass (%)   PLSR            Detrend      0.1409     0.6020   1.1407
# 128  Firmness (N)    RFR              OSC_1      0.9329     0.0471  11.1592
# 130  Firmness (N)   SVMR              OSC_1      0.8987     0.0968  13.3112
# 131  Firmness (N)   PLSR              OSC_1      0.8554     0.0959  16.0150
# 134  Firmness (N)    PCR              OSC_1      0.8390     0.1003  16.6655
# 192     TA (g/mL)    RFR  SNV_Detrend_SG_D1      0.6333     0.2114   0.0981
# 193     TA (g/mL)   PLSR                Raw      0.6115     0.2222   0.0988
# 196     TA (g/mL)    PCR              OSC_1      0.5953     0.2192   0.1005
# 197     TA (g/mL)   SVMR              OSC_1      0.5946     0.2399   0.1010
# 256    TSS (Brix)    PCR    OPLS2_SNV_SG_D1      0.1080     0.6475   1.2125
# 257    TSS (Brix)   SVMR    OPLS2_SNV_SG_D1      0.0992     0.5582   1.2736
# 261    TSS (Brix)    RFR              SG_D2      0.0330     0.6562   1.3099
# 269    TSS (Brix)   PLSR          Normalize      0.0095     0.6604   1.3356
#
# --- Melhores Modelos Gerais por Atributo (baseado no R² de Cross-Validation) ---
#          Atributo Modelo             Filtro  CV_R2_Mean  CV_R2_Std  CV_RMSE
# 0    AA (mg/100g)    RFR                Raw      0.1011     0.5798   4.4642
# 64   Dry Mass (%)   SVMR         MSC_SG_OSC      0.3038     0.4401   1.0144
# 128  Firmness (N)    RFR              OSC_1      0.9329     0.0471  11.1592
# 192     TA (g/mL)    RFR  SNV_Detrend_SG_D1      0.6333     0.2114   0.0981
# 256    TSS (Brix)    PCR    OPLS2_SNV_SG_D1      0.1080     0.6475   1.2125
#
# --- Análise Estatística dos Resultados ---
# Número total de combinações testadas: 320
# Número de atributos analisados: 5
# Número de modelos testados: 4
# Número de filtros testados: 16
#
# Estatísticas do R² de Cross-Validation:
#   Média geral: 0.0884
#   Desvio padrão: 0.4594
#   Melhor resultado: 0.9329
#   Pior resultado: -1.2940
#
# --- Desempenho Médio por Modelo ---
#           mean     std     max     min
# Modelo
# PCR     0.1991  0.4144  0.8390 -0.6056
# PLSR    0.0059  0.5607  0.8554 -1.2354
# RFR     0.0993  0.4020  0.9329 -0.7557
# SVMR    0.0493  0.4284  0.8987 -1.2940
#
# --- Top 10 Filtros com Melhor Desempenho Médio ---
#                      mean     std  count
# Filtro
# Wavelet_Denoising  0.2288  0.4154     20
# Raw                0.2288  0.4173     20
# OSC_1              0.1709  0.5237     20
# SNV                0.1341  0.4006     20
# OPLS2_SNV_SG_D1    0.1305  0.4542     20
# MSC_SG_OSC         0.0992  0.4385     20
# OPLS1_SNV_SG_D1    0.0958  0.4340     20
# Normalize          0.0876  0.3995     20
# Detrend            0.0829  0.3769     20
# EMSC               0.0705  0.4331     20
#
# ✅ Análise de resultados concluída!

# %% [markdown]
# ## Testes

# %%
## Linha de teste
