# %% [markdown]
# # Análise Espectroscópica
#
# Este notebook segue as melhores práticas da literatura para análise espectroscópica robusta, incluindo:
# - Cross Validation
# - Remoção de outliers espectrais (PCA, T²/Q)
# - Remoção de outliers dos atributos (boxplot + seaborn)
# - Teste de todos os filtros (dependentes e independentes de y)
# - Modelagem com PLSR, PCR, RFR, SVMR (hiperparâmetros da literatura)
# - Plotagens robustas e salvamento de métricas

# %% [markdown]
# ## 1. Imports

# %%
# Imports necessários
import os
import time
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from scipy.signal import savgol_filter
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, GridSearchCV, cross_val_predict, cross_val_score
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_squared_error
from matplotlib.mlab import detrend
import pywt
from sklearn.pipeline import Pipeline

# Cria diretórios para organizar todas as imagens salvas
print("Criando diretórios para salvar os gráficos...")
os.makedirs('graficos_outliers_pca', exist_ok=True)
os.makedirs('graficos_outliers_boxplot', exist_ok=True)
os.makedirs('modelos_salvos', exist_ok=True)
os.makedirs('graficos_modelos', exist_ok=True) 
os.makedirs('graficos_mlpr', exist_ok=True)

warnings.filterwarnings('ignore')

# Configurações de plot
plt.style.use('default')
sns.set_palette('husl')
plt.rcParams['figure.figsize'] = (12, 8)
# Out:
# Criando diretórios para salvar os gráficos...

# %% [markdown]
# ## 2. Carregamento dos Dados

# %% [markdown]
# O primeiro passo em qualquer projeto de ciência de dados é carregar e entender os dados. Nesta seção, realizamos as seguintes ações:
# - **Carregamento:** Utilizamos a biblioteca `pandas` para ler o arquivo `Simulacao_Exportacao_Keitt_e_Kent_Tellspec.xlsx`, que contém os dados espectrais e os valores de referência (atributos físico-químicos).
# - **Separação de Dados:** A função `load_data` inteligentemente separa o arquivo em duas partes:
#     - `metadata`: Um DataFrame contendo as informações de referência (ex: Firmness, Dry Mass, TSS, TA, AA), que serão nossas variáveis-alvo (y).
#     - `wavelengths`: Um DataFrame contendo a resposta espectral (absorbância ou reflectância) em cada comprimento de onda, que serão nossas variáveis preditoras (X).
# - **Definição de Variáveis:** Convertemos os dados espectrais para um array NumPy (`X`) para otimizar os cálculos e definimos a lista de `atributos` que desejamos modelar.

# %%
# Função para carregar dados
def load_data(filepath):
    """Carrega dados espectrais e separa metadados de espectros."""
    df = pd.read_excel(filepath, engine='openpyxl')
    
    # Identificar colunas que são comprimentos de onda (numéricas)
    numeric_cols = []
    for col in df.columns:
        try:
            float(col)
            numeric_cols.append(col)
        except ValueError:
            continue
    
    # Separar metadados e comprimentos de onda
    metadata = df.drop(columns=numeric_cols)
    wavelengths = df[numeric_cols]
    
    return metadata, wavelengths

# Carregar dados
filepath = '../Data/raw/Folha/Avaliacao_fisiologica.xlsx'
metadata, wavelengths = load_data(filepath)
X = wavelengths.values
wavelength_values = wavelengths.columns.astype(float)

# VARIÁVEIS DA SARAH
atributos = ['Fotossintese (μmol CO2/m²/s)','Condutancia estomatica (mmol/m²/s¹)','Carbono Interno (ppm)','Transpiração (mol/m²/s¹)','Eficiencia uso de agua (g/MJ¹)','Eficiencia de carboxilacao (μmol CO2/m²/s)']

print(f'Dados carregados: {X.shape[0]} amostras, {X.shape[1]} comprimentos de onda')
print(f'Faixa espectral: {wavelength_values.min():.1f} - {wavelength_values.max():.1f} nm')
print(f'Atributos disponíveis: {list(metadata.columns)}')
print(f'Atributos a analisar: {atributos}')

# remoção de NaN antes de passar pelo pré-processamento e conferência

dados_completos = {}
for atributo in atributos:
    y = metadata[atributo].values
    original_indices = np.arange(len(y))
    
    # Remove apenas valores NaN
    mask = ~np.isnan(y)
    X_clean = X[mask]
    y_clean = y[mask]
    original_indices_clean = original_indices[mask]
    
    dados_completos[atributo] = {
        'X': X_clean,
        'y': y_clean,
        'indices_orig': original_indices_clean
    }
    
    print(f'{atributo}: {X_clean.shape[0]} amostras válidas')

print(f'\nPreparação dos dados concluída para {len(atributos)} atributos!')
# Out:
# Dados carregados: 36 amostras, 2151 comprimentos de onda
# Faixa espectral: 350.0 - 2500.0 nm
# Atributos disponíveis: ['Wavelength', 'Variedade', 'Fotossintese (μmol CO2/m²/s)', 'Condutancia estomatica (mmol/m²/s¹)', 'Carbono Interno (ppm)', 'Transpiração (mol/m²/s¹)', 'Eficiencia uso de agua (g/MJ¹)', 'Eficiencia de carboxilacao (μmol CO2/m²/s)']
# Atributos a analisar: ['Fotossintese (μmol CO2/m²/s)', 'Condutancia estomatica (mmol/m²/s¹)', 'Carbono Interno (ppm)', 'Transpiração (mol/m²/s¹)', 'Eficiencia uso de agua (g/MJ¹)', 'Eficiencia de carboxilacao (μmol CO2/m²/s)']
# Fotossintese (μmol CO2/m²/s): 36 amostras válidas
# Condutancia estomatica (mmol/m²/s¹): 36 amostras válidas
# Carbono Interno (ppm): 36 amostras válidas
# Transpiração (mol/m²/s¹): 36 amostras válidas
# Eficiencia uso de agua (g/MJ¹): 36 amostras válidas
# Eficiencia de carboxilacao (μmol CO2/m²/s): 36 amostras válidas
#
# Preparação dos dados concluída para 6 atributos!

# %% [markdown]
# ## 3. Filtros de Pré-processamento (Independentes e Dependentes de y)

# %% [markdown]
# Os dados espectrais brutos contêm diversas fontes de variação indesejada que podem mascarar a informação química relevante. Essas variações podem ser causadas por espalhamento de luz (efeitos físicos da amostra), mudanças na linha de base (drift do instrumento) e ruído. O pré-processing visa minimizar esses efeitos para que o modelo foque na correlação entre o espectro e o atributo de interesse.
#
# Neste notebook, testamos uma ampla gama de filtros, divididos em duas categorias:
#
# ### Filtros Independentes de y
#
# São aplicados apenas aos espectros (`X`) e não utilizam a informação da variável alvo (`y`).
#
# -   **`Raw`**: Utiliza os dados espectrais brutos, sem nenhum tratamento. Serve como uma linha de base para comparar a eficácia dos outros filtros.
# -   **`MSC` (Multiplicative Scatter Correction)**: Corrige o espalhamento de luz (aditivo e multiplicativo) causado por variações no tamanho de partícula e compactação da amostra. Ele ajusta cada espectro para se parecer mais com um espectro "ideal" (geralmente a média de todos os espectros).
# -   **`SNV` (Standard Normal Variate)**: Alternativa ao MSC que também corrige o espalhamento de luz. A diferença é que o SNV padroniza cada espectro individualmente (subtrai a média e divide pelo desvio padrão daquele espectro), sem usar um espectro de referência.
# -   **`SG_D1` e `SG_D2` (Savitzky-Golay Derivatives)**: Calcula a primeira ou a segunda derivada do espectro. Derivadas são excelentes para remover desvios de linha de base (efeitos aditivos) e para resolver picos espectrais sobrepostos, realçando a informação de bandas de absorção específicas.
# -   **`Detrend`**: Remove tendências lineares ou polinomiais da linha de base do espectro. É muito eficaz para corrigir "inclinações" no espectro causadas por drift do instrumento.
# -   **`Normalize`**: Realiza uma normalização Min-Max, escalonando a intensidade de cada espectro para um intervalo fixo (geralmente [0, 1]). Ajuda a corrigir variações de intensidade causadas por diferenças na distância da amostra ou na potência da fonte de luz.
# -   **`EMSC` (Extended Multiplicative Signal Correction)**: Uma versão avançada do MSC. Além de corrigir os efeitos de espalhamento, o EMSC pode incluir termos polinomiais para modelar e remover efeitos de linha de base mais complexos e não-lineares.
# -   **`Continuum Removal`**: Técnica que normaliza os espectros para que as bandas de absorção possam ser comparadas em termos de sua profundidade, e não de sua intensidade absoluta. Ele ajusta um "envelope" (casco convexo) sobre o espectro e divide o espectro original por este envelope, realçando as características de absorção.
# -   **`Wavelet_Denoising`**: Utiliza a Transformada Wavelet para decompor o espectro em diferentes níveis de frequência. A técnica permite remover o ruído (geralmente presente em altas frequências) de forma muito eficaz, preservando as principais características do sinal espectral.
#
# ### Filtros Dependentes de y e Combinações
#
# Estes filtros utilizam a variável alvo (`y`) para otimizar a remoção de variação não correlacionada em `X`, ou são combinações sequenciais de múltiplos filtros para um tratamento mais completo.
#
# -   **`OSC_1` e `OSC_2` (Orthogonal Signal Correction)**: Filtro que remove componentes (1 ou 2, neste caso) dos espectros `X` que são ortogonais (não correlacionados) à variável alvo `y`. O objetivo é limpar `X` da variação que não ajuda na predição, potencialmente melhorando o modelo subsequente. Esta técnica é frequentemente referida como um pré-processamento **OPLS** (Orthogonal Projections to Latent Structures).
# -   **`MSC_SG_OSC`**: Uma **cadeia de pré-processamentos** aplicada na seguinte ordem:
#     1.  `MSC` para corrigir o espalhamento.
#     2.  `Savitzky-Golay (1ª derivada)` para corrigir a linha de base.
#     3.  `OSC (1 componente)` para remover variação não correlacionada com `y`.
# -   **`OPLS1_SNV_SG_D1` e `OPLS2_SNV_SG_D1`**: Outra cadeia de processamento:
#     1.  `SNV` para correção de espalhamento.
#     2.  `Savitzky-Golay (1ª derivada)`.
#     3.  `OPLS/OSC` para remover 1 ou 2 componentes ortogonais a `y`.
# -   **`SNV_Detrend_SG_D1`**: Uma combinação de filtros independentes de `y`, mas que, por sua complexidade, é testada junto às outras cadeias:
#     1.  `SNV`.
#     2.  `Detrend` para remoção de tendência.
#     3.  `Savitzky-Golay (1ª derivada)`.

# %%
# Implementação dos filtros de pré-processamento
# Filtros independentes de y

def msc(X):
    """Multiplicative Scatter Correction."""
    X = np.asarray(X)
    mean_spectrum = np.mean(X, axis=0)
    corrected_spectra = np.zeros_like(X)
    for i in range(X.shape[0]):
        slope, intercept = np.polyfit(mean_spectrum, X[i, :], 1)
        corrected_spectra[i, :] = (X[i, :] - intercept) / slope
    return corrected_spectra

def snv(X):
    """Standard Normal Variate."""
    X = np.asarray(X)
    return (X - np.mean(X, axis=1, keepdims=True)) / np.std(X, axis=1, keepdims=True)

def savitzky_golay(X, window_size=11, poly_order=2, deriv_order=1):
    """Savitzky-Golay filter."""
    return savgol_filter(X, window_length=window_size, polyorder=poly_order, deriv=deriv_order, axis=1)

def detrend_filter(X):
    """Detrending filter."""
    return detrend(X, axis=1)

def normalize(X):
    """Normalização Min-Max."""
    return (X - np.min(X, axis=1, keepdims=True)) / (np.max(X, axis=1, keepdims=True) - np.min(X, axis=1, keepdims=True))

def emsc(X, reference=None):
    """Extended Multiplicative Signal Correction."""
    X = np.asarray(X)
    if reference is None:
        reference = np.mean(X, axis=0)  # Usa o espectro médio como referência
    
    X_corr = np.zeros_like(X)
    for i in range(X.shape[0]):
        # Modelo: X[i] ≈ a + b*reference
        model = np.vstack([np.ones_like(reference), reference]).T
        params, _, _, _ = np.linalg.lstsq(model, X[i, :], rcond=None)
        a, b = params[0], params[1]
        X_corr[i,:] = (X[i, :] - a) / b
    return X_corr

def continuum_removal(X, wavelengths):
    """Continuum Removal."""
    X = np.asarray(X)
    X_cr = np.zeros_like(X)
    for i in range(X.shape[0]):
        spectrum = X[i, :]
        # Encontra os pontos do casco convexo superior
        q_u = [0]
        for k in range(1, len(wavelengths) - 1):
            s_k = (spectrum[len(wavelengths)-1] - spectrum[0]) / (wavelengths[-1] - wavelengths[0])
            s_q = (spectrum[k] - spectrum[q_u[-1]]) / (wavelengths[k] - wavelengths[q_u[-1]])
            if s_q > s_k:
                q_u.append(k)
        q_u.append(len(wavelengths)-1)
        
        # Interpolação linear entre os pontos do casco
        continuum = np.interp(wavelengths, wavelengths[q_u], spectrum[q_u])
        X_cr[i, :] = spectrum / continuum
    return X_cr

def wavelet_denoising(X, wavelet='db4', level=4):
    """Wavelet Transform para Denoising."""
    X = np.asarray(X)
    original_length = X.shape[1]
    denoised_list = []

    for i in range(X.shape[0]):
        # 1. Decomposição Wavelet
        coeffs = pywt.wavedec(X[i, :], wavelet, level=level)

        # 2. Cálculo do limiar (threshold)
        sigma = np.median(np.abs(coeffs[-1])) / 0.6745
        threshold = sigma * np.sqrt(2 * np.log(original_length))

        # 3. Aplicação do filtro (soft thresholding) nos coeficientes de detalhe
        coeffs[1:] = [pywt.threshold(c, value=threshold, mode='soft') for c in coeffs[1:]]

        # 4. Reconstrução do sinal
        reconstructed_signal = pywt.waverec(coeffs, wavelet)

        # 5. Ajuste do tamanho
        denoised_list.append(reconstructed_signal[:original_length])

    return np.asarray(denoised_list)

# Filtros dependentes de y (Orthogonal Signal Correction)
class OrthogonalCorrection:
    """Orthogonal Signal Correction (OSC)."""
    def __init__(self, n_components=1):
        self.n_components = n_components
    
    def fit_transform(self, X, y):
        X, y = np.asarray(X), np.asarray(y).ravel()
        self.w_ortho_ = []
        self.p_ortho_ = []
        self.X_corr_ = X.copy()
        
        for _ in range(self.n_components):
            pls = PLSRegression(n_components=1)
            pls.fit(self.X_corr_, y)
            t = pls.x_scores_
            w = pls.x_weights_
            p = pls.x_loadings_
            
            # Componente Ortogonal
            w_ortho = p - (np.dot(w.T, p) / np.dot(w.T, w)) * w
            t_ortho = np.dot(self.X_corr_, w_ortho)
            p_ortho = np.dot(t_ortho.T, self.X_corr_) / np.dot(t_ortho.T, t_ortho)
            
            # Remover variação ortogonal
            self.X_corr_ -= np.dot(t_ortho, p_ortho)
            self.w_ortho_.append(w_ortho)
            self.p_ortho_.append(p_ortho)
        
        return self.X_corr_
    
    def transform(self, X):
        X_res = np.asarray(X).copy()
        for i in range(self.n_components):
            t_ortho = np.dot(X_res, self.w_ortho_[i])
            X_res -= np.dot(t_ortho, self.p_ortho_[i])
        return X_res

# Dicionário de filtros independentes de y
filtros_independentes = {
    'Raw': lambda X: X,
    'MSC': msc,
    'SNV': snv,
    'SG_D1': lambda X: savitzky_golay(X, window_size=11, poly_order=2, deriv_order=1),
    'SG_D2': lambda X: savitzky_golay(X, window_size=11, poly_order=2, deriv_order=2),
    'Detrend': detrend_filter,
    'Normalize': normalize,
    'EMSC': emsc,
    'Continuum_Removal': lambda X: continuum_removal(X, wavelength_values),
    'Wavelet_Denoising': wavelet_denoising
}

# Dicionário de filtros dependentes de y
filtros_dependentes = {
    'OSC_1': lambda X, y: OrthogonalCorrection(n_components=1).fit_transform(X, y),
    'OSC_2': lambda X, y: OrthogonalCorrection(n_components=2).fit_transform(X, y),
    'MSC_SG_OSC': lambda X, y: OrthogonalCorrection(n_components=1).fit_transform(
        savitzky_golay(msc(X), window_size=11, poly_order=2, deriv_order=1), y),
    'OPLS1_SNV_SG_D1': lambda X, y: OrthogonalCorrection(n_components=1).fit_transform(
        savitzky_golay(snv(X), window_size=11, poly_order=2, deriv_order=1), y),
    'OPLS2_SNV_SG_D1': lambda X, y: OrthogonalCorrection(n_components=2).fit_transform(
        savitzky_golay(snv(X), window_size=11, poly_order=2, deriv_order=1), y),
    'SNV_Detrend_SG_D1': lambda X, y: savitzky_golay(detrend_filter(snv(X)), window_size=11, poly_order=2, deriv_order=1)
}

print(f'Filtros independentes de y: {list(filtros_independentes.keys())}')
print(f'Filtros dependentes de y: {list(filtros_dependentes.keys())}')
print(f'Total de filtros: {len(filtros_independentes) + len(filtros_dependentes)}')
# Out:
# Filtros independentes de y: ['Raw', 'MSC', 'SNV', 'SG_D1', 'SG_D2', 'Detrend', 'Normalize', 'EMSC', 'Continuum_Removal', 'Wavelet_Denoising']
# Filtros dependentes de y: ['OSC_1', 'OSC_2', 'MSC_SG_OSC', 'OPLS1_SNV_SG_D1', 'OPLS2_SNV_SG_D1', 'SNV_Detrend_SG_D1']
# Total de filtros: 16

# %% [markdown]
# ## 4. Remoção de Outliers Espectrais (PCA, T²/Q)

# %% [markdown]
# Outliers espectrais são amostras cujo espectro é muito diferente do resto da população, podendo ser causados por erros de medição, contaminação ou características únicas da amostra. Eles podem prejudicar significativamente a capacidade de generalização do modelo.
# - **Método PCA (T²/Q):** Usamos a Análise de Componentes Principais (PCA) para identificar esses outliers.
#     - **Estatística T² (Hotelling's T²):** Mede a variação de uma amostra *dentro* do modelo PCA. Valores altos indicam que a amostra é um outlier na combinação das variáveis principais.
#     - **Estatística Q (Resíduos):** Mede a variação da amostra *fora* do modelo PCA (o que o modelo não conseguiu capturar). Valores altos indicam que a estrutura do espectro da amostra é anormal.
# - **Lógica:** Uma amostra é considerada outlier se seu valor de T² ou Q ultrapassa um limite de confiança (geralmente 3 desvios padrão da média).
# - **Importante:** A remoção de outliers é feita **apenas no conjunto de calibração**. O conjunto de validação deve permanecer intacto para simular dados "reais" que o modelo encontrará no futuro.

# %%
def pca_outlier_removal(X, n_components=10, threshold=3):
    """Remove outliers usando PCA com estatísticas T² e Q."""
    # Padronizar dados
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Aplicar PCA
    pca = PCA(n_components=n_components)
    X_pca = pca.fit_transform(X_scaled)
    
    # Calcular estatística T² (Hotelling's T²)
    T2 = np.sum((X_pca / np.std(X_pca, axis=0)) ** 2, axis=1)
    
    # Calcular estatística Q (resíduos)
    X_reconstructed = pca.inverse_transform(X_pca)
    Q = np.sum((X_scaled - X_reconstructed) ** 2, axis=1)
    
    # Definir limites (média + threshold * desvio padrão)
    T2_limit = np.mean(T2) + threshold * np.std(T2)
    Q_limit = np.mean(Q) + threshold * np.std(Q)
    
    # Identificar outliers
    outliers_mask = (T2 > T2_limit) | (Q > Q_limit)
    
    # Retornamos a máscara de quem NÃO é outlier e o modelo PCA treinado
    return ~outliers_mask, pca, T2, Q, T2_limit, Q_limit

dados_pca = {}

#para todo o conjunto de dado e não separado em cal e val
for atributo in atributos:
    X_full = dados_completos[atributo]['X']
    y_full = dados_completos[atributo]['y']
    indices_orig_full = dados_completos[atributo]['indices_orig']
    
    # Chama a função de remoção de outliers espectrais
    keep_mask, pca_model, T2, Q, T2_limit, Q_limit = pca_outlier_removal(X_full)
    
    # Identifica e informa os outliers removidos
    outliers_indices = indices_orig_full[~keep_mask]
    print(f'{atributo}: {len(outliers_indices)} outliers espectrais removidos.')
    if len(outliers_indices) > 0:
        print(f'  Índices Originais Removidos: {outliers_indices}')
    
    # Filtra os dados
    X_clean = X_full[keep_mask]
    y_clean = y_full[keep_mask]
    indices_orig_clean = indices_orig_full[keep_mask]
    
    dados_pca[atributo] = {
        'X': X_clean,
        'y': y_clean,
        'indices_orig': indices_orig_clean,
        'pca_model': pca_model,
        'T2': T2,
        'Q': Q,
        'T2_limit': T2_limit,
        'Q_limit': Q_limit,
        'keep_mask': keep_mask
    }
    
    print(f'  Dataset final: {X_clean.shape[0]} amostras')
    print()
# Out:
# Fotossintese (μmol CO2/m²/s): 0 outliers espectrais removidos.
#   Dataset final: 36 amostras
#
# Condutancia estomatica (mmol/m²/s¹): 0 outliers espectrais removidos.
#   Dataset final: 36 amostras
#
# Carbono Interno (ppm): 0 outliers espectrais removidos.
#   Dataset final: 36 amostras
#
# Transpiração (mol/m²/s¹): 0 outliers espectrais removidos.
#   Dataset final: 36 amostras
#
# Eficiencia uso de agua (g/MJ¹): 0 outliers espectrais removidos.
#   Dataset final: 36 amostras
#
# Eficiencia de carboxilacao (μmol CO2/m²/s): 0 outliers espectrais removidos.
#   Dataset final: 36 amostras

# %% [markdown]
# ### 4.1 Gráficos de Outliers T² e Q

# %%
# Plotagem dos gráficos de outliers PCA
for atributo in atributos:
    d = dados_pca[atributo]
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    
    # Gráfico 1: Variância explicada cumulativa
    # Acessa o modelo PCA com a chave correta 'pca_model'

    cumulative_variance = np.cumsum(d['pca_model'].explained_variance_ratio_)
    axes[0].plot(range(1, len(cumulative_variance) + 1), cumulative_variance, 'o-', linewidth=2, markersize=6)
    axes[0].set_xlabel('Número de Componentes Principais')
    axes[0].set_ylabel('Variância Explicada Cumulativa')
    axes[0].set_title(f'Variância Explicada - {atributo}')
    axes[0].grid(True, alpha=0.3)
    axes[0].axhline(y=0.95, color='r', linestyle='--', alpha=0.7, label='95%')
    axes[0].legend()
    
    # Gráfico 2: T² vs Q (detecção de outliers)
    # Acessa as variáveis T2, Q, T2_limit, Q_limit e keep_mask com as chaves corretas
    scatter = axes[1].scatter(d['T2'], d['Q'], c=d['keep_mask'], cmap='coolwarm', 
                              edgecolor='k', alpha=0.7, s=50)
    axes[1].axhline(d['Q_limit'], color='r', linestyle='--', linewidth=2, label=f'Q Limit: {d["Q_limit"]:.2f}')
    axes[1].axvline(d['T2_limit'], color='g', linestyle='--', linewidth=2, label=f'T² Limit: {d["T2_limit"]:.2f}')
    axes[1].set_xlabel("Hotelling's T²")
    axes[1].set_ylabel('Q Residual')
    axes[1].set_title(f'Detecção de Outliers - {atributo}')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    
    # Adicionar legenda de cores
    legend1 = axes[1].legend(*scatter.legend_elements(), title="Status")
    axes[1].add_artist(legend1)
    
    plt.tight_layout()
    
    # Salvar gráfico
    nome_arquivo = f'graficos_outliers_pca/pca_outliers_{atributo.replace(" ", "_").replace("(", "").replace(")", "").replace("/", "_")}.png'
    plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f'Gráficos de outliers PCA para {atributo} salvos em: {nome_arquivo}')
    print()
# Out:
# Gráficos de outliers PCA para Fotossintese (μmol CO2/m²/s) salvos em: graficos_outliers_pca/pca_outliers_Fotossintese_μmol_CO2_m²_s.png
# Gráficos de outliers PCA para Condutancia estomatica (mmol/m²/s¹) salvos em: graficos_outliers_pca/pca_outliers_Condutancia_estomatica_mmol_m²_s¹.png
# Gráficos de outliers PCA para Carbono Interno (ppm) salvos em: graficos_outliers_pca/pca_outliers_Carbono_Interno_ppm.png
# Gráficos de outliers PCA para Transpiração (mol/m²/s¹) salvos em: graficos_outliers_pca/pca_outliers_Transpiração_mol_m²_s¹.png
# Gráficos de outliers PCA para Eficiencia uso de agua (g/MJ¹) salvos em: graficos_outliers_pca/pca_outliers_Eficiencia_uso_de_agua_g_MJ¹.png
# Gráficos de outliers PCA para Eficiencia de carboxilacao (μmol CO2/m²/s) salvos em: graficos_outliers_pca/pca_outliers_Eficiencia_de_carboxilacao_μmol_CO2_m²_s.png

# %% [markdown]
# ## 5. Remoção de Outliers dos Atributos (Boxplot + Seaborn)

# %% [markdown]
# Além dos outliers espectrais (em X), podemos ter outliers nos valores de referência (em y). Por exemplo, um valor de pH ou SST que é analiticamente improvável ou resultado de um erro de anotação.
# - **Método (IQR):** O método do Intervalo Interquartil (IQR) é uma forma estatística robusta de identificar esses pontos.
#     - `IQR = Q3 (percentil 75) - Q1 (percentil 25)`
#     - Um valor é considerado outlier se estiver abaixo de `Q1 - 1.5 * IQR` ou acima de `Q3 + 1.5 * IQR`.
# - **Visualização:** O `boxplot` é a ferramenta visual perfeita para essa análise, pois ele desenha os "bigodes" exatamente nesses limites de 1.5 * IQR, mostrando os outliers como pontos individuais.
# - **Ação:** Novamente, a remoção é feita apenas no conjunto de calibração.

# %%
# Remover outliers dos atributos usando boxplot e IQR

dados_final = {}

for atributo in atributos:
    # Pega os dados já limpos de outliers espectrais
    d = dados_pca[atributo]
    X_clean = d['X']
    y_clean = d['y']
    indices_orig_clean = d['indices_orig']
    
    # Boxplot
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=y_clean)
    sns.stripplot(x=y_clean, color='red', alpha=0.6)
    plt.title(f'Boxplot com Dispersão - {atributo}')
    
    nome_arquivo = f'graficos_outliers_boxplot/boxplot_outliers_{atributo.replace(" ", "_").replace("(", "").replace(")", "").replace("/", "_")}.png'
    plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
    plt.show()

    # Lógica de remoção de outliers dos atributos
    Q1 = np.percentile(y_clean, 25)
    Q3 = np.percentile(y_clean, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    keep_mask_attr = (y_clean >= lower_bound) & (y_clean <= upper_bound)
    
    # Identifica e informa os outliers removidos
    outliers_attr_indices = indices_orig_clean[~keep_mask_attr]
    print(f'{atributo}: {len(outliers_attr_indices)} outliers de atributo removidos.')
    if len(outliers_attr_indices) > 0:
        print(f'  Índices Originais Removidos: {outliers_attr_indices}')
    
    # Armazena os dados finais e limpos para modelagem
    dados_final[atributo] = {
        'X': X_clean[keep_mask_attr],
        'y': y_clean[keep_mask_attr]
    }
    
    print(f'  Dataset final para modelagem: {dados_final[atributo]["X"].shape[0]} amostras')
    print()

print("Remoção de outliers concluída!")
# Out:
# Fotossintese (μmol CO2/m²/s): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 36 amostras
# Condutancia estomatica (mmol/m²/s¹): 2 outliers de atributo removidos.
#   Índices Originais Removidos: [23 25]
#   Dataset final para modelagem: 34 amostras
# Carbono Interno (ppm): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 36 amostras
# Transpiração (mol/m²/s¹): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 36 amostras
# Eficiencia uso de agua (g/MJ¹): 1 outliers de atributo removidos.
#   Índices Originais Removidos: [12]
#   Dataset final para modelagem: 35 amostras
# Eficiencia de carboxilacao (μmol CO2/m²/s): 2 outliers de atributo removidos.
#   Índices Originais Removidos: [17 22]
#   Dataset final para modelagem: 34 amostras
#
# Remoção de outliers concluída!

# %%
# --- Função para o Gráfico de CALIBRAÇÃO (Ref vs Predito vs CV) ---
def save_calibration_plot(y_cal, y_pred_cal, y_pred_cv, atributo, filtro, modelo, file_path):
    """
    Gera e salva um gráfico comparando predições de treino e de validação cruzada
    no conjunto de calibração.
    """
    try:
        # Garante que o diretório exista
        os.makedirs(os.path.dirname(file_path), exist_ok=True)

        # Métricas para Predição no Treino Completo
        slope_pred, offset_pred = np.polyfit(y_cal, y_pred_cal, 1)
        rmse_pred = np.sqrt(mean_squared_error(y_cal, y_pred_cal))
        r2_pred = r2_score(y_cal, y_pred_cal)

        # Métricas para Predição da Validação Cruzada
        slope_cv, offset_cv = np.polyfit(y_cal, y_pred_cv, 1)
        rmse_cv = np.sqrt(mean_squared_error(y_cal, y_pred_cv))
        r2_cv = r2_score(y_cal, y_pred_cv)

        plt.figure(figsize=(10, 8))
        plt.scatter(y_cal, y_pred_cal, color='blue', marker='o', alpha=0.6, label=f'Predição no Treino (R²={r2_pred:.3f})')
        plt.scatter(y_cal, y_pred_cv, color='red', marker='x', alpha=0.7, label=f'Predição CV (R²={r2_cv:.3f})')
        
        # Linha ideal 1:1
        min_val = min(min(y_cal), min(y_pred_cal), min(y_pred_cv))
        max_val = max(max(y_cal), max(y_pred_cal), max(y_pred_cv))
        plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='Linha Ideal (1:1)')

        plt.xlabel("Valores Reais (Calibração)")
        plt.ylabel("Valores Preditos")
        plt.title(f'Desempenho na Calibração: {atributo} | {modelo} | {filtro}')
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.legend(loc='lower right')
        
        # Adiciona texto com métricas
        stats_text = (
            f'Treino - RMSE: {rmse_pred:.3f}, Slope: {slope_pred:.3f}, Offset: {offset_pred:.3f}\n'
            f'CV     - RMSE: {rmse_cv:.3f}, Slope: {slope_cv:.3f}, Offset: {offset_cv:.3f}'
        )
        plt.text(0.05, 0.95, stats_text, transform=plt.gca().transAxes, fontsize=10,
                 verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5))

        plt.savefig(file_path, format='png', dpi=200, bbox_inches='tight')
        plt.close()

    except Exception as e:
        print(f"Erro ao gerar gráfico de calibração para {modelo} com {filtro}: {e}")
        plt.close()


# --- Função para o Gráfico de VALIDAÇÃO (Predito vs Real) ---
def save_validation_plot(y_val, y_pred_val, atributo, filtro, modelo, file_path):
    """
    Gera e salva o gráfico de predições no conjunto de validação (teste).
    """
    try:
        # Garante que o diretório exista
        os.makedirs(os.path.dirname(file_path), exist_ok=True)
        
        # Métricas
        r2 = r2_score(y_val, y_pred_val)
        rmse = np.sqrt(mean_squared_error(y_val, y_pred_val))
        slope, offset = np.polyfit(y_val, y_pred_val, 1)

        plt.figure(figsize=(8, 8))
        plt.scatter(y_val, y_pred_val, alpha=0.7, edgecolors='k', label='Dados de Validação')
        
        # Linha ideal 1:1
        min_val = min(min(y_val), min(y_pred_val))
        max_val = max(max(y_val), max(y_pred_val))
        plt.plot([min_val, max_val], [min_val, max_val], 'r--', lw=2, label='Linha Ideal (1:1)')

        plt.xlabel('Valores Reais (Validação)')
        plt.ylabel('Valores Preditos')
        plt.title(f'Desempenho na Validação: {atributo} | {modelo} | {filtro}')
        plt.grid(True, linestyle='--', alpha=0.6)
        
        stats_text = f'R² = {r2:.4f}\nRMSE = {rmse:.4f}\nSlope = {slope:.4f}'
        plt.text(0.05, 0.95, stats_text, transform=plt.gca().transAxes, fontsize=12,
                 verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='lightblue', alpha=0.5))
        
        plt.legend()
        plt.savefig(file_path, format='png', dpi=200, bbox_inches='tight')
        plt.close()

    except Exception as e:
        print(f"Erro ao gerar gráfico de validação para {modelo} com {filtro}: {e}")
        plt.close()

# %% [markdown]
# ## 6. Avaliação dos Filtros e Seleção dos Melhores Modelos com Validação Cruzada

# %% [markdown]
# Nesta etapa crucial, construímos e avaliamos os modelos de regressão. Em vez de testar cada modelo separadamente, criamos um fluxo automatizado e exaustivo para garantir que encontremos a melhor performance possível.
# - **Estratégia:**
#     1. **Iteração por Atributo:** Um loop externo passa por cada variável alvo (AT, PH, etc.).
#     2. **Iteração por Modelo:** Para cada atributo, testamos uma lista de modelos quimiométricos:
#         - `PLSR`: Padrão da área, lida bem com multicolinearidade.
#         - `PCR`: Alternativa que primeiro reduz a dimensionalidade.
#         - `RFR` (Random Forest): Modelo não-linear, robusto e poderoso.
#         - `SVMR` (Support Vector Machine): Eficaz em espaços de alta dimensão.
#     3. **Iteração por Filtro:** Para cada modelo, aplicamos **todos os 16 filtros** de pré-processamento definidos na seção anterior.
#     4. **Otimização (GridSearchCV):** Para cada combinação `(atributo, modelo, filtro)`, usamos `GridSearchCV` com validação cruzada (10-fold) para encontrar os melhores hiperparâmetros do modelo (ex: número de componentes para PLS, parâmetros C e gamma para SVM).
# - **Avaliação:** O desempenho de cada combinação é medido pelo R² da validação cruzada. O melhor modelo é então treinado com todos os dados de calibração e sua performance final é avaliada no conjunto de validação, que foi mantido separado durante todo o processo.
# - **Saídas:** Ao final, teremos os resultados de centenas de modelos, permitindo uma comparação justa e a seleção do campeão para cada atributo. Todos os gráficos de predição e as métricas são salvos automaticamente.

# %%
def save_calibration_plot_cv(y_true, y_pred_cv, atributo, filtro, modelo, file_path):
 
    try:
        # Garante que o diretório exista
        os.makedirs(os.path.dirname(file_path), exist_ok=True)

        # Métricas para Predição da Validação Cruzada
        slope_cv, offset_cv = np.polyfit(y_true, y_pred_cv, 1)
        rmse_cv = np.sqrt(mean_squared_error(y_true, y_pred_cv))
        r2_cv = r2_score(y_true, y_pred_cv)

        plt.figure(figsize=(10, 8))
        plt.scatter(y_true, y_pred_cv, color='blue', marker='o', alpha=0.7, label=f'Cross-Validation (R²={r2_cv:.3f})')
        
        # Linha ideal 1:1
        min_val = min(min(y_true), min(y_pred_cv))
        max_val = max(max(y_true), max(y_pred_cv))
        plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='Linha Ideal (1:1)')

        plt.xlabel("Valores Reais")
        plt.ylabel("Valores Preditos (CV)")
        plt.title(f'Cross-Validation: {atributo} | {modelo} | {filtro}')
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.legend(loc='lower right')
        
        # Adiciona texto com métricas
        stats_text = f'CV - R²: {r2_cv:.3f}, RMSE: {rmse_cv:.3f}, Slope: {slope_cv:.3f}, Offset: {offset_cv:.3f}'
        plt.text(0.05, 0.95, stats_text, transform=plt.gca().transAxes, fontsize=10,
                 verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5))

        plt.savefig(file_path, format='png', dpi=200, bbox_inches='tight')
        plt.close()

    except Exception as e:
        print(f"Erro ao gerar gráfico de CV para {modelo} com {filtro}: {e}")
        plt.close()

# %% [markdown]
# ### 6.1 Modelos e Grids de Parâmetros

# %%
import re


modelos = {
    'PLSR': {
        'estimador': PLSRegression(),
        'params': {'n_components': [5, 10, 15, 20]}
    },
    'PCR': {
        'estimador': Pipeline([('pca', PCA()), ('regressor', LinearRegression())]),
        'params': {'pca__n_components': [5, 10, 15, 20]}
    },
        'SVMR': {
        'estimador': SVR(),
        'params': {
            'C': [0.1, 1, 10, 100],
            'gamma': ['scale', 'auto', 0.001, 0.01, 0.1],
            'kernel': ['rbf', 'linear'],
            'epsilon': [0.1, 0.2, 0.5, 1.0]
        }
    },
     'RFR': {
        'estimador': RandomForestRegressor(random_state=42),
        'params': {
            'n_estimators': [100, 150, 200, 250, 300],
            'max_depth': [10, 20, 30, None],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 4],
            'warm_start': [True, False],
            'bootstrap': [True, False]
        }
     }

}

# Combina todos os filtros
todos_filtros = {**filtros_independentes, **filtros_dependentes}

# Lista para armazenar todos os resultados
lista_resultados_finais = []

#AQUI COMEÇA O CROSS VALIDATION -- PRINCIPAIS ALTERAÇÕES DO CÓDIGO DE ANDRESSA

cv_folds = 10  # Número de folds para cross-validation
kf = KFold(n_splits=cv_folds, shuffle=True, random_state=42)

for atributo in atributos: 
    print(f'\n{"="*30}')
    print(f'INICIANDO MODELAGEM PARA: {atributo}')
    print(f'{"="*30}')

    melhor_r2_atributo = -999  # Inicia com um valor muito baixo
    melhor_combinacao_info = {}  # Dicionário para guardar as infos do melhor
    
    # Dicionário para armazenar as 5 melhores combinações por modelo
    melhores_por_modelo = {nome: [] for nome in modelos.keys()}

    dados = dados_final[atributo]
    X_full, y_full = dados['X'], dados['y']

    for nome_modelo, info_modelo in modelos.items():
        print(f'\n--- Modelo: {nome_modelo} ---')
        
        combinacoes_deste_modelo = [] # Lista temporária para este modelo

        for nome_filtro, funcao_filtro in todos_filtros.items():
            start_time = time.time()
            print(f'  Testando filtro: {nome_filtro}...', end='')

            if nome_filtro in filtros_independentes:
                X_filtered = funcao_filtro(X_full)
                tipo_filtro = 'independente'
            else:  # Filtro dependente de Y
                X_filtered = funcao_filtro(X_full, y_full)
                tipo_filtro = 'dependente'
            
            grid = GridSearchCV(
                info_modelo['estimador'], 
                info_modelo['params'], 
                cv=kf,  # Usa o mesmo KFold para consistência
                scoring='r2', 
                n_jobs=-1
            )
            grid.fit(X_filtered, y_full)
            
            melhor_modelo = grid.best_estimator_
            
            cv_scores = cross_val_score(melhor_modelo, X_filtered, y_full, cv=kf, scoring='r2')
            cv_r2_mean = cv_scores.mean()
            cv_r2_std = cv_scores.std()
            
            # Predições de cross-validation para plotagem
            y_pred_cv = cross_val_predict(melhor_modelo, X_filtered, y_full, cv=kf)
            cv_rmse = np.sqrt(mean_squared_error(y_full, y_pred_cv))
            
            end_time = time.time()
            print(f' CV R²: {cv_r2_mean:.4f} (±{cv_r2_std:.4f}) | Concluído em {end_time - start_time:.2f}s')

            # Salvar o resultado da combinação atual
            resultados_atuais = {
                'Atributo': atributo,
                'Modelo': nome_modelo,
                'Filtro': nome_filtro,
                'Tipo_Filtro': tipo_filtro,
                'CV_R2_Mean': cv_r2_mean,
                'CV_R2_Std': cv_r2_std,
                'CV_RMSE': cv_rmse,
                'Grid_Best_Score': grid.best_score_,
                'Melhores_Params': str(grid.best_params_),
                'Tempo_s': end_time - start_time,
                'objeto_modelo': melhor_modelo 
            }
            
            lista_resultados_finais.append(resultados_atuais)
            combinacoes_deste_modelo.append(resultados_atuais)

            # Lógica para salvar o melhor modelo geral
            if cv_r2_mean > melhor_r2_atributo:
                melhor_r2_atributo = cv_r2_mean
                melhor_combinacao_info = {
                    'objeto_modelo': melhor_modelo,
                    'nome_modelo': nome_modelo,
                    'nome_filtro': nome_filtro,
                    'parametros': grid.best_params_
                }
            
            path_cv = f'graficos_modelos/cross_validation/{atributo}_{nome_modelo}_{nome_filtro}.png'
            os.makedirs('graficos_modelos/cross_validation', exist_ok=True)
            save_calibration_plot_cv(y_full, y_pred_cv, atributo, nome_filtro, nome_modelo, path_cv)

        # Ordenar e salvar as 5 melhores para este modelo
        combinacoes_deste_modelo.sort(key=lambda x: x['CV_R2_Mean'], reverse=True)
        melhores_por_modelo[nome_modelo] = combinacoes_deste_modelo[:5]
        atributo_limpo = re.sub(r"[ \/\[\]\(\)]", "_", atributo)
    if melhor_combinacao_info:  # Garante que encontrou pelo menos um modelo
        melhor_obj = melhor_combinacao_info['objeto_modelo']
        nome_arquivo_modelo = f"modelos_salvos/melhor_modelo_{atributo_limpo}.joblib"
        
        joblib.dump(melhor_obj, nome_arquivo_modelo)
        
        print(f"\n 🏆 MELHOR COMBINAÇÃO GERAL PARA '{atributo}' FOI SALVA!")
        print(f"   - Arquivo: {nome_arquivo_modelo}")
        print(f"   - Modelo: {melhor_combinacao_info['nome_modelo']}")
        print(f"   - Filtro: {melhor_combinacao_info['nome_filtro']}")
        print(f"   - Melhor R² CV: {melhor_r2_atributo:.4f}")
        print(f"   - Melhores Parâmetros: {melhor_combinacao_info['parametros']}")
    
    # Salvar os 5 melhores modelos para cada tipo
    print(f"\n--- Salvando os 5 melhores modelos para {atributo} ---")
    for nome_modelo, lista_combinacoes in melhores_por_modelo.items():
        for i, combinacao in enumerate(lista_combinacoes):
            nome_arquivo = f"modelos_salvos_top5/top_{i+1}_{atributo_limpo}_{combinacao['Modelo']}_{combinacao['Filtro']}.joblib"
            os.makedirs('modelos_salvos_top5', exist_ok=True)
            joblib.dump(combinacao['objeto_modelo'], nome_arquivo)
            print(f"  - Top {i+1} do modelo {nome_modelo} salvo em: {nome_arquivo}")

print('\n\n ✅ Modelagem exaustiva com Cross-Validation!')

df_completo = pd.DataFrame(lista_resultados_finais)
df_completo_ordenado = df_completo.sort_values(by=['Atributo', 'CV_R2_Mean'], ascending=[True, False])
df_completo_ordenado.to_excel('analise_completa_resultados_cv.xlsx', index=False)
print('  ✅Resultados salvos em "analise_completa_resultados_cv.xlsx"')

print("\n--- Melhores Resultados por Atributo (Cross-Validation) ---")
melhores_resultados = df_completo_ordenado.groupby('Atributo').first().reset_index()

# Arredondar colunas numéricas para melhor visualização
colunas_numericas_para_arredondar = ['CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE', 'Grid_Best_Score']
melhores_resultados[colunas_numericas_para_arredondar] = melhores_resultados[colunas_numericas_para_arredondar].round(4)

# Selecionar e exibir as colunas mais importantes
colunas_para_exibir = ['Atributo', 'Modelo', 'Filtro', 'CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE', 'Melhores_Params']
print(melhores_resultados[colunas_para_exibir].to_string(index=False))
# Out:
# ==============================
# INICIANDO MODELAGEM PARA: Fotossintese (μmol CO2/m²/s)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: -2.8805 (±3.8807) | Concluído em 1.60s
#   Testando filtro: MSC... CV R²: -5.0628 (±8.1229) | Concluído em 0.06s
#   Testando filtro: SNV... CV R²: -5.8687 (±9.6453) | Concluído em 0.06s
#   Testando filtro: SG_D1... CV R²: -3.2580 (±5.0760) | Concluído em 0.07s
#   Testando filtro: SG_D2... CV R²: -0.8189 (±1.3392) | Concluído em 0.06s
#   Testando filtro: Detrend... CV R²: -4.7241 (±7.3065) | Concluído em 0.07s
#   Testando filtro: Normalize... CV R²: -5.5293 (±9.5765) | Concluído em 0.06s
#   Testando filtro: EMSC... CV R²: -5.0628 (±8.1229) | Concluído em 0.06s
#   Testando filtro: Continuum_Removal... CV R²: -2.2244 (±3.4210) | Concluído em 0.14s
#   Testando filtro: Wavelet_Denoising... CV R²: -2.8783 (±3.8755) | Concluído em 0.08s
#   Testando filtro: OSC_1... CV R²: -3.3001 (±5.0367) | Concluído em 0.06s
#   Testando filtro: OSC_2... CV R²: -2.6718 (±4.5174) | Concluído em 0.06s
#   Testando filtro: MSC_SG_OSC... CV R²: -3.9034 (±5.6258) | Concluído em 0.06s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -3.9928 (±5.7288) | Concluído em 0.06s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -2.8735 (±4.0072) | Concluído em 0.06s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -3.4192 (±5.4978) | Concluído em 0.09s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: -1.1679 (±1.1222) | Concluído em 0.15s
#   Testando filtro: MSC... CV R²: -1.2810 (±1.4813) | Concluído em 0.10s
#   Testando filtro: SNV... CV R²: -1.2697 (±1.4522) | Concluído em 0.10s
#   Testando filtro: SG_D1... CV R²: -0.5857 (±1.0832) | Concluído em 0.09s
#   Testando filtro: SG_D2... CV R²: -0.6860 (±1.5981) | Concluído em 0.09s
#   Testando filtro: Detrend... CV R²: -1.3601 (±1.8807) | Concluído em 0.09s
#   Testando filtro: Normalize... CV R²: -1.8883 (±3.4644) | Concluído em 0.10s
#   Testando filtro: EMSC... CV R²: -1.2810 (±1.4813) | Concluído em 0.09s
#   Testando filtro: Continuum_Removal... CV R²: -0.6014 (±0.9238) | Concluído em 0.18s
#   Testando filtro: Wavelet_Denoising... CV R²: -1.1680 (±1.1223) | Concluído em 0.10s
#   Testando filtro: OSC_1... CV R²: -1.3251 (±1.9573) | Concluído em 0.10s
#   Testando filtro: OSC_2... CV R²: -1.3344 (±1.9588) | Concluído em 0.09s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.6285 (±1.0705) | Concluído em 0.10s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.6234 (±1.0623) | Concluído em 0.10s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.7674 (±1.5865) | Concluído em 0.10s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.5437 (±1.1097) | Concluído em 0.10s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: -0.5609 (±0.9115) | Concluído em 0.33s
#   Testando filtro: MSC... CV R²: -0.4306 (±0.5850) | Concluído em 0.33s
#   Testando filtro: SNV... CV R²: -0.4481 (±0.5738) | Concluído em 0.34s
#   Testando filtro: SG_D1... CV R²: -0.2086 (±0.3703) | Concluído em 0.32s
#   Testando filtro: SG_D2... CV R²: -0.3696 (±0.6024) | Concluído em 0.32s
#   Testando filtro: Detrend... CV R²: -0.4571 (±0.6224) | Concluído em 0.32s
#   Testando filtro: Normalize... CV R²: -0.4741 (±0.5869) | Concluído em 0.33s
#   Testando filtro: EMSC... CV R²: -0.4306 (±0.5850) | Concluído em 0.32s
#   Testando filtro: Continuum_Removal... CV R²: -0.2839 (±0.5416) | Concluído em 0.53s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.5609 (±0.9115) | Concluído em 0.34s
#   Testando filtro: OSC_1... CV R²: -0.4002 (±0.6494) | Concluído em 0.33s
#   Testando filtro: OSC_2... CV R²: -0.3990 (±0.5684) | Concluído em 0.33s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.3752 (±0.6166) | Concluído em 0.32s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.3378 (±0.6719) | Concluído em 0.36s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.2666 (±0.7218) | Concluído em 0.32s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.2191 (±0.3961) | Concluído em 0.31s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: -1.1919 (±1.6902) | Concluído em 574.17s
#   Testando filtro: MSC... CV R²: -1.3319 (±1.7862) | Concluído em 561.33s
#   Testando filtro: SNV... CV R²: -1.2521 (±1.7740) | Concluído em 565.93s
#   Testando filtro: SG_D1... CV R²: -1.1699 (±1.1552) | Concluído em 558.09s
#   Testando filtro: SG_D2... CV R²: -0.4417 (±0.5758) | Concluído em 547.77s
#   Testando filtro: Detrend... CV R²: -1.0593 (±1.4006) | Concluído em 601.51s
#   Testando filtro: Normalize... CV R²: -1.3547 (±2.1482) | Concluído em 612.08s
#   Testando filtro: EMSC... CV R²: -1.3319 (±1.7862) | Concluído em 562.00s
#   Testando filtro: Continuum_Removal... CV R²: -0.2661 (±0.4299) | Concluído em 585.97s
#   Testando filtro: Wavelet_Denoising... CV R²: -1.1926 (±1.7051) | Concluído em 586.89s
#   Testando filtro: OSC_1... CV R²: -1.0870 (±1.3574) | Concluído em 605.24s
#   Testando filtro: OSC_2... CV R²: -0.4741 (±0.9193) | Concluído em 577.41s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.9590 (±1.3487) | Concluído em 595.49s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.9332 (±1.2687) | Concluído em 586.01s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.5120 (±1.5733) | Concluído em 542.09s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.9360 (±0.8007) | Concluído em 558.71s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Fotossintese (μmol CO2/m²/s)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Fotossintese__μmol_CO2_m²_s_.joblib
#    - Modelo: SVMR
#    - Filtro: SG_D1
#    - Melhor R² CV: -0.2086
#    - Melhores Parâmetros: {'C': 100, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#
# --- Salvando os 5 melhores modelos para Fotossintese (μmol CO2/m²/s) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Fotossintese__μmol_CO2_m²_s__PLSR_SG_D2.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Fotossintese__μmol_CO2_m²_s__PLSR_Continuum_Removal.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Fotossintese__μmol_CO2_m²_s__PLSR_OSC_2.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Fotossintese__μmol_CO2_m²_s__PLSR_OPLS2_SNV_SG_D1.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Fotossintese__μmol_CO2_m²_s__PLSR_Wavelet_Denoising.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Fotossintese__μmol_CO2_m²_s__PCR_SNV_Detrend_SG_D1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Fotossintese__μmol_CO2_m²_s__PCR_SG_D1.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Fotossintese__μmol_CO2_m²_s__PCR_Continuum_Removal.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Fotossintese__μmol_CO2_m²_s__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Fotossintese__μmol_CO2_m²_s__PCR_MSC_SG_OSC.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Fotossintese__μmol_CO2_m²_s__SVMR_SG_D1.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Fotossintese__μmol_CO2_m²_s__SVMR_SNV_Detrend_SG_D1.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Fotossintese__μmol_CO2_m²_s__SVMR_OPLS2_SNV_SG_D1.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Fotossintese__μmol_CO2_m²_s__SVMR_Continuum_Removal.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Fotossintese__μmol_CO2_m²_s__SVMR_OPLS1_SNV_SG_D1.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Fotossintese__μmol_CO2_m²_s__RFR_Continuum_Removal.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Fotossintese__μmol_CO2_m²_s__RFR_SG_D2.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Fotossintese__μmol_CO2_m²_s__RFR_OSC_2.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Fotossintese__μmol_CO2_m²_s__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Fotossintese__μmol_CO2_m²_s__RFR_OPLS1_SNV_SG_D1.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: Condutancia estomatica (mmol/m²/s¹)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: -2.5999 (±3.9042) | Concluído em 0.06s
#   Testando filtro: MSC... CV R²: -4.7744 (±7.0477) | Concluído em 0.06s
#   Testando filtro: SNV... CV R²: -5.0807 (±6.9245) | Concluído em 0.06s
#   Testando filtro: SG_D1... CV R²: -4.9709 (±8.4531) | Concluído em 0.06s
#   Testando filtro: SG_D2... CV R²: -2.6660 (±4.8399) | Concluído em 0.06s
#   Testando filtro: Detrend... CV R²: -5.2824 (±8.3025) | Concluído em 0.06s
#   Testando filtro: Normalize... CV R²: -3.5394 (±5.6560) | Concluído em 0.06s
#   Testando filtro: EMSC... CV R²: -4.7744 (±7.0477) | Concluído em 0.06s
#   Testando filtro: Continuum_Removal... CV R²: -2.2731 (±2.8517) | Concluído em 0.13s
#   Testando filtro: Wavelet_Denoising... CV R²: -2.6009 (±3.9060) | Concluído em 0.06s
#   Testando filtro: OSC_1... CV R²: -3.7517 (±5.9040) | Concluído em 0.06s
#   Testando filtro: OSC_2... CV R²: -3.7057 (±5.9248) | Concluído em 0.06s
#   Testando filtro: MSC_SG_OSC... CV R²: -2.2377 (±3.6475) | Concluído em 0.06s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -2.2137 (±3.6244) | Concluído em 0.06s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -3.0330 (±5.4005) | Concluído em 0.06s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -3.3116 (±5.7984) | Concluído em 0.06s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: -3.7163 (±5.3697) | Concluído em 0.12s
#   Testando filtro: MSC... CV R²: -2.3536 (±3.1611) | Concluído em 0.10s
#   Testando filtro: SNV... CV R²: -2.3534 (±3.1607) | Concluído em 0.09s
#   Testando filtro: SG_D1... CV R²: -2.4177 (±4.5461) | Concluído em 0.09s
#   Testando filtro: SG_D2... CV R²: -2.1933 (±3.7233) | Concluído em 0.10s
#   Testando filtro: Detrend... CV R²: -3.3678 (±5.5365) | Concluído em 0.11s
#   Testando filtro: Normalize... CV R²: -2.4448 (±3.7802) | Concluído em 0.10s
#   Testando filtro: EMSC... CV R²: -2.3536 (±3.1611) | Concluído em 0.09s
#   Testando filtro: Continuum_Removal... CV R²: -2.2912 (±3.7476) | Concluído em 0.16s
#   Testando filtro: Wavelet_Denoising... CV R²: -3.7200 (±5.3689) | Concluído em 0.12s
#   Testando filtro: OSC_1... CV R²: -2.3437 (±3.1955) | Concluído em 0.09s
#   Testando filtro: OSC_2... CV R²: -2.0397 (±2.9697) | Concluído em 0.10s
#   Testando filtro: MSC_SG_OSC... CV R²: -1.8467 (±2.5516) | Concluído em 0.11s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -1.8542 (±2.5687) | Concluído em 0.11s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -1.8049 (±3.0335) | Concluído em 0.09s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -2.4139 (±3.8079) | Concluído em 0.11s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: -1.7711 (±2.8887) | Concluído em 0.32s
#   Testando filtro: MSC... CV R²: -1.7667 (±3.0863) | Concluído em 0.29s
#   Testando filtro: SNV... CV R²: -1.7736 (±3.0419) | Concluído em 0.28s
#   Testando filtro: SG_D1... CV R²: -1.9145 (±3.9012) | Concluído em 0.30s
#   Testando filtro: SG_D2... CV R²: -1.9145 (±3.9012) | Concluído em 0.30s
#   Testando filtro: Detrend... CV R²: -1.8466 (±3.0755) | Concluído em 0.29s
#   Testando filtro: Normalize... CV R²: -1.8640 (±3.1064) | Concluído em 0.29s
#   Testando filtro: EMSC... CV R²: -1.7667 (±3.0863) | Concluído em 0.29s
#   Testando filtro: Continuum_Removal... CV R²: -1.6739 (±2.8693) | Concluído em 0.36s
#   Testando filtro: Wavelet_Denoising... CV R²: -1.7731 (±2.8974) | Concluído em 0.29s
#   Testando filtro: OSC_1... CV R²: -1.6277 (±2.7230) | Concluído em 0.29s
#   Testando filtro: OSC_2... CV R²: -1.8890 (±3.1939) | Concluído em 0.29s
#   Testando filtro: MSC_SG_OSC... CV R²: -1.7920 (±3.4496) | Concluído em 0.30s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -1.7927 (±3.4503) | Concluído em 0.29s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -1.7498 (±3.3732) | Concluído em 0.29s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -1.9145 (±3.9012) | Concluído em 0.28s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: -2.2857 (±3.8126) | Concluído em 530.98s
#   Testando filtro: MSC... CV R²: -2.7218 (±6.1336) | Concluído em 531.41s
#   Testando filtro: SNV... CV R²: -2.5346 (±4.9286) | Concluído em 514.89s
#   Testando filtro: SG_D1... CV R²: -3.1910 (±5.6553) | Concluído em 520.09s
#   Testando filtro: SG_D2... CV R²: -2.7810 (±5.0535) | Concluído em 512.73s
#   Testando filtro: Detrend... CV R²: -3.2420 (±6.3942) | Concluído em 525.09s
#   Testando filtro: Normalize... CV R²: -3.2059 (±5.1396) | Concluído em 514.56s
#   Testando filtro: EMSC... CV R²: -2.7218 (±6.1336) | Concluído em 534.94s
#   Testando filtro: Continuum_Removal... CV R²: -2.4923 (±5.0965) | Concluído em 476.92s
#   Testando filtro: Wavelet_Denoising... CV R²: -2.2740 (±3.8007) | Concluído em 529.91s
#   Testando filtro: OSC_1... CV R²: -2.4491 (±4.4037) | Concluído em 570.73s
#   Testando filtro: OSC_2... CV R²: -2.4401 (±4.5335) | Concluído em 513.99s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.5882 (±1.4513) | Concluído em 530.25s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.6225 (±1.4674) | Concluído em 527.96s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.9747 (±3.0495) | Concluído em 524.36s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -2.8037 (±4.4340) | Concluído em 509.81s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Condutancia estomatica (mmol/m²/s¹)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Condutancia_estomatica__mmol_m²_s¹_.joblib
#    - Modelo: RFR
#    - Filtro: MSC_SG_OSC
#    - Melhor R² CV: -0.5882
#    - Melhores Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300, 'warm_start': True}
#
# --- Salvando os 5 melhores modelos para Condutancia estomatica (mmol/m²/s¹) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Condutancia_estomatica__mmol_m²_s¹__PLSR_OPLS1_SNV_SG_D1.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Condutancia_estomatica__mmol_m²_s¹__PLSR_MSC_SG_OSC.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Condutancia_estomatica__mmol_m²_s¹__PLSR_Continuum_Removal.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Condutancia_estomatica__mmol_m²_s¹__PLSR_Raw.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Condutancia_estomatica__mmol_m²_s¹__PLSR_Wavelet_Denoising.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Condutancia_estomatica__mmol_m²_s¹__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Condutancia_estomatica__mmol_m²_s¹__PCR_MSC_SG_OSC.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Condutancia_estomatica__mmol_m²_s¹__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Condutancia_estomatica__mmol_m²_s¹__PCR_OSC_2.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Condutancia_estomatica__mmol_m²_s¹__PCR_SG_D2.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Condutancia_estomatica__mmol_m²_s¹__SVMR_OSC_1.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Condutancia_estomatica__mmol_m²_s¹__SVMR_Continuum_Removal.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Condutancia_estomatica__mmol_m²_s¹__SVMR_OPLS2_SNV_SG_D1.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Condutancia_estomatica__mmol_m²_s¹__SVMR_EMSC.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Condutancia_estomatica__mmol_m²_s¹__SVMR_MSC.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Condutancia_estomatica__mmol_m²_s¹__RFR_MSC_SG_OSC.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Condutancia_estomatica__mmol_m²_s¹__RFR_OPLS1_SNV_SG_D1.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Condutancia_estomatica__mmol_m²_s¹__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Condutancia_estomatica__mmol_m²_s¹__RFR_Wavelet_Denoising.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Condutancia_estomatica__mmol_m²_s¹__RFR_Raw.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: Carbono Interno (ppm)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: -6.6320 (±8.7609) | Concluído em 0.06s
#   Testando filtro: MSC... CV R²: -7.2827 (±8.1037) | Concluído em 0.06s
#   Testando filtro: SNV... CV R²: -8.4645 (±10.0583) | Concluído em 0.06s
#   Testando filtro: SG_D1... CV R²: -6.0451 (±5.8619) | Concluído em 0.06s
#   Testando filtro: SG_D2... CV R²: -3.7324 (±4.4952) | Concluído em 0.06s
#   Testando filtro: Detrend... CV R²: -10.6235 (±15.9255) | Concluído em 0.06s
#   Testando filtro: Normalize... CV R²: -7.3693 (±7.8404) | Concluído em 0.07s
#   Testando filtro: EMSC... CV R²: -7.2827 (±8.1037) | Concluído em 0.06s
#   Testando filtro: Continuum_Removal... CV R²: -12.2830 (±23.4712) | Concluído em 0.15s
#   Testando filtro: Wavelet_Denoising... CV R²: -6.6303 (±8.7601) | Concluído em 0.06s
#   Testando filtro: OSC_1... CV R²: -7.2994 (±7.8048) | Concluído em 0.10s
#   Testando filtro: OSC_2... CV R²: -6.1707 (±7.4602) | Concluído em 0.08s
#   Testando filtro: MSC_SG_OSC... CV R²: -8.9728 (±17.4983) | Concluído em 0.06s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -8.0227 (±14.7652) | Concluído em 0.06s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -5.2771 (±5.6588) | Concluído em 0.06s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -4.5663 (±5.6796) | Concluído em 0.06s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: -4.0939 (±5.3973) | Concluído em 0.09s
#   Testando filtro: MSC... CV R²: -5.0092 (±6.1095) | Concluído em 0.11s
#   Testando filtro: SNV... CV R²: -4.9094 (±6.0255) | Concluído em 0.11s
#   Testando filtro: SG_D1... CV R²: -4.1516 (±6.4000) | Concluído em 0.11s
#   Testando filtro: SG_D2... CV R²: -2.5723 (±3.2122) | Concluído em 0.09s
#   Testando filtro: Detrend... CV R²: -6.5770 (±10.7642) | Concluído em 0.09s
#   Testando filtro: Normalize... CV R²: -4.8356 (±6.5642) | Concluído em 0.10s
#   Testando filtro: EMSC... CV R²: -5.0093 (±6.1099) | Concluído em 0.12s
#   Testando filtro: Continuum_Removal... CV R²: -8.8284 (±20.9249) | Concluído em 0.17s
#   Testando filtro: Wavelet_Denoising... CV R²: -4.0941 (±5.3979) | Concluído em 0.11s
#   Testando filtro: OSC_1... CV R²: -5.3903 (±7.3520) | Concluído em 0.12s
#   Testando filtro: OSC_2... CV R²: -4.9123 (±8.0586) | Concluído em 0.10s
#   Testando filtro: MSC_SG_OSC... CV R²: -2.9616 (±5.2840) | Concluído em 0.11s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -2.9707 (±5.3200) | Concluído em 0.10s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -2.3970 (±2.7089) | Concluído em 0.10s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -3.3021 (±6.2626) | Concluído em 0.11s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: -0.7248 (±0.9134) | Concluído em 0.35s
#   Testando filtro: MSC... CV R²: -0.4607 (±0.6736) | Concluído em 0.36s
#   Testando filtro: SNV... CV R²: -0.4350 (±0.7529) | Concluído em 0.39s
#   Testando filtro: SG_D1... CV R²: -0.8623 (±0.5268) | Concluído em 0.37s
#   Testando filtro: SG_D2... CV R²: -1.1674 (±0.8008) | Concluído em 0.38s
#   Testando filtro: Detrend... CV R²: -0.7731 (±0.5890) | Concluído em 0.34s
#   Testando filtro: Normalize... CV R²: -0.3876 (±0.7549) | Concluído em 0.35s
#   Testando filtro: EMSC... CV R²: -0.4607 (±0.6736) | Concluído em 0.35s
#   Testando filtro: Continuum_Removal... CV R²: -0.6400 (±0.4668) | Concluído em 0.43s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.7248 (±0.9134) | Concluído em 0.37s
#   Testando filtro: OSC_1... CV R²: -0.4940 (±0.6707) | Concluído em 0.36s
#   Testando filtro: OSC_2... CV R²: -1.0454 (±0.7405) | Concluído em 0.36s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.8664 (±0.6960) | Concluído em 0.36s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.6557 (±0.6448) | Concluído em 0.36s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -1.1959 (±0.9231) | Concluído em 0.59s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.8641 (±0.4939) | Concluído em 0.36s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: -1.9205 (±3.0245) | Concluído em 556.05s
#   Testando filtro: MSC... CV R²: -2.4730 (±2.7925) | Concluído em 582.47s
#   Testando filtro: SNV... CV R²: -2.6549 (±2.9119) | Concluído em 575.54s
#   Testando filtro: SG_D1... CV R²: -2.6374 (±2.8725) | Concluído em 634.32s
#   Testando filtro: SG_D2... CV R²: -2.6772 (±3.4255) | Concluído em 627.68s
#   Testando filtro: Detrend... CV R²: -2.5560 (±3.6070) | Concluído em 597.90s
#   Testando filtro: Normalize... CV R²: -3.5239 (±3.8266) | Concluído em 589.17s
#   Testando filtro: EMSC... CV R²: -2.4730 (±2.7925) | Concluído em 582.71s
#   Testando filtro: Continuum_Removal... CV R²: -1.7553 (±1.7274) | Concluído em 618.41s
#   Testando filtro: Wavelet_Denoising... CV R²: -1.9454 (±3.0262) | Concluído em 553.80s
#   Testando filtro: OSC_1... CV R²: -3.8969 (±8.5018) | Concluído em 532.44s
#   Testando filtro: OSC_2... CV R²: -4.2964 (±7.6638) | Concluído em 614.66s
#   Testando filtro: MSC_SG_OSC... CV R²: -4.5261 (±11.0466) | Concluído em 552.79s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -4.6564 (±11.8512) | Concluído em 575.08s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.1931 (±1.6140) | Concluído em 626.92s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -2.1227 (±2.1701) | Concluído em 633.17s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Carbono Interno (ppm)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Carbono_Interno__ppm_.joblib
#    - Modelo: RFR
#    - Filtro: OPLS2_SNV_SG_D1
#    - Melhor R² CV: -0.1931
#    - Melhores Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 300, 'warm_start': True}
#
# --- Salvando os 5 melhores modelos para Carbono Interno (ppm) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Carbono_Interno__ppm__PLSR_SG_D2.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Carbono_Interno__ppm__PLSR_SNV_Detrend_SG_D1.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Carbono_Interno__ppm__PLSR_OPLS2_SNV_SG_D1.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Carbono_Interno__ppm__PLSR_SG_D1.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Carbono_Interno__ppm__PLSR_OSC_2.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Carbono_Interno__ppm__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Carbono_Interno__ppm__PCR_SG_D2.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Carbono_Interno__ppm__PCR_MSC_SG_OSC.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Carbono_Interno__ppm__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Carbono_Interno__ppm__PCR_SNV_Detrend_SG_D1.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Carbono_Interno__ppm__SVMR_Normalize.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Carbono_Interno__ppm__SVMR_SNV.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Carbono_Interno__ppm__SVMR_EMSC.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Carbono_Interno__ppm__SVMR_MSC.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Carbono_Interno__ppm__SVMR_OSC_1.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Carbono_Interno__ppm__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Carbono_Interno__ppm__RFR_Continuum_Removal.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Carbono_Interno__ppm__RFR_Raw.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Carbono_Interno__ppm__RFR_Wavelet_Denoising.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Carbono_Interno__ppm__RFR_SNV_Detrend_SG_D1.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: Transpiração (mol/m²/s¹)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: -7.6194 (±15.1901) | Concluído em 0.06s
#   Testando filtro: MSC... CV R²: -5.9047 (±10.0091) | Concluído em 0.06s
#   Testando filtro: SNV... CV R²: -6.9489 (±12.1056) | Concluído em 0.06s
#   Testando filtro: SG_D1... CV R²: -6.6201 (±11.6767) | Concluído em 0.06s
#   Testando filtro: SG_D2... CV R²: -2.5209 (±4.8050) | Concluído em 0.09s
#   Testando filtro: Detrend... CV R²: -6.4999 (±10.8822) | Concluído em 0.06s
#   Testando filtro: Normalize... CV R²: -9.5841 (±16.7842) | Concluído em 0.06s
#   Testando filtro: EMSC... CV R²: -5.9047 (±10.0091) | Concluído em 0.06s
#   Testando filtro: Continuum_Removal... CV R²: -2.9322 (±6.1770) | Concluído em 0.13s
#   Testando filtro: Wavelet_Denoising... CV R²: -7.6152 (±15.1842) | Concluído em 0.06s
#   Testando filtro: OSC_1... CV R²: -7.5993 (±14.5817) | Concluído em 0.06s
#   Testando filtro: OSC_2... CV R²: -5.2714 (±9.6257) | Concluído em 0.10s
#   Testando filtro: MSC_SG_OSC... CV R²: -4.4805 (±7.0391) | Concluído em 0.07s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -4.5023 (±6.9899) | Concluído em 0.07s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -2.3151 (±4.9686) | Concluído em 0.08s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -6.9638 (±12.6326) | Concluído em 0.06s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: -3.0966 (±5.5143) | Concluído em 0.10s
#   Testando filtro: MSC... CV R²: -3.8358 (±6.5658) | Concluído em 0.11s
#   Testando filtro: SNV... CV R²: -3.7983 (±6.4810) | Concluído em 0.10s
#   Testando filtro: SG_D1... CV R²: -1.7082 (±3.1904) | Concluído em 0.10s
#   Testando filtro: SG_D2... CV R²: -2.0664 (±3.5087) | Concluído em 0.12s
#   Testando filtro: Detrend... CV R²: -4.5782 (±8.4436) | Concluído em 0.09s
#   Testando filtro: Normalize... CV R²: -5.0438 (±9.7252) | Concluído em 0.10s
#   Testando filtro: EMSC... CV R²: -3.8358 (±6.5658) | Concluído em 0.10s
#   Testando filtro: Continuum_Removal... CV R²: -1.8498 (±4.0770) | Concluído em 0.17s
#   Testando filtro: Wavelet_Denoising... CV R²: -3.0967 (±5.5147) | Concluído em 0.11s
#   Testando filtro: OSC_1... CV R²: -4.0635 (±7.5604) | Concluído em 0.10s
#   Testando filtro: OSC_2... CV R²: -2.9406 (±6.3312) | Concluído em 0.09s
#   Testando filtro: MSC_SG_OSC... CV R²: -1.6711 (±3.1738) | Concluído em 0.11s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -1.6739 (±3.1779) | Concluído em 0.11s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -1.5400 (±3.1411) | Concluído em 0.11s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -1.8338 (±3.3800) | Concluído em 0.10s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: -1.1360 (±1.6463) | Concluído em 0.34s
#   Testando filtro: MSC... CV R²: -1.0485 (±1.2323) | Concluído em 0.35s
#   Testando filtro: SNV... CV R²: -1.1114 (±1.3762) | Concluído em 0.61s
#   Testando filtro: SG_D1... CV R²: -0.9810 (±1.1805) | Concluído em 0.34s
#   Testando filtro: SG_D2... CV R²: -1.1848 (±1.4919) | Concluído em 0.34s
#   Testando filtro: Detrend... CV R²: -1.1253 (±1.6462) | Concluído em 0.34s
#   Testando filtro: Normalize... CV R²: -1.0376 (±1.1694) | Concluído em 0.34s
#   Testando filtro: EMSC... CV R²: -1.0485 (±1.2323) | Concluído em 0.35s
#   Testando filtro: Continuum_Removal... CV R²: -0.7905 (±1.0858) | Concluído em 0.42s
#   Testando filtro: Wavelet_Denoising... CV R²: -1.1360 (±1.6463) | Concluído em 0.35s
#   Testando filtro: OSC_1... CV R²: -0.9767 (±2.2704) | Concluído em 0.34s
#   Testando filtro: OSC_2... CV R²: -1.0413 (±1.4929) | Concluído em 0.35s
#   Testando filtro: MSC_SG_OSC... CV R²: -1.0118 (±1.1615) | Concluído em 0.34s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.9330 (±1.0424) | Concluído em 0.35s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.8737 (±1.0143) | Concluído em 0.36s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -1.0101 (±1.2559) | Concluído em 0.34s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: -1.8533 (±3.0531) | Concluído em 550.69s
#   Testando filtro: MSC... CV R²: -3.1722 (±6.2253) | Concluído em 579.39s
#   Testando filtro: SNV... CV R²: -3.1423 (±6.5537) | Concluído em 598.13s
#   Testando filtro: SG_D1... CV R²: -3.7968 (±7.2361) | Concluído em 643.54s
#   Testando filtro: SG_D2... CV R²: -3.0454 (±5.3757) | Concluído em 602.68s
#   Testando filtro: Detrend... CV R²: -2.3590 (±4.4311) | Concluído em 581.18s
#   Testando filtro: Normalize... CV R²: -3.4098 (±5.9702) | Concluído em 597.91s
#   Testando filtro: EMSC... CV R²: -3.1722 (±6.2253) | Concluído em 579.80s
#   Testando filtro: Continuum_Removal... CV R²: -1.8915 (±2.7283) | Concluído em 591.52s
#   Testando filtro: Wavelet_Denoising... CV R²: -1.8312 (±2.9763) | Concluído em 550.34s
#   Testando filtro: OSC_1... CV R²: -2.6726 (±5.5731) | Concluído em 635.39s
#   Testando filtro: OSC_2... CV R²: -2.4389 (±5.6479) | Concluído em 618.66s
#   Testando filtro: MSC_SG_OSC... CV R²: -1.6295 (±3.2640) | Concluído em 567.41s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -1.7869 (±3.2060) | Concluído em 638.78s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -1.4576 (±2.9794) | Concluído em 569.86s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -3.8496 (±7.5926) | Concluído em 631.73s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Transpiração (mol/m²/s¹)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Transpiração__mol_m²_s¹_.joblib
#    - Modelo: SVMR
#    - Filtro: Continuum_Removal
#    - Melhor R² CV: -0.7905
#    - Melhores Parâmetros: {'C': 10, 'epsilon': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}
#
# --- Salvando os 5 melhores modelos para Transpiração (mol/m²/s¹) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Transpiração__mol_m²_s¹__PLSR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Transpiração__mol_m²_s¹__PLSR_SG_D2.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Transpiração__mol_m²_s¹__PLSR_Continuum_Removal.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Transpiração__mol_m²_s¹__PLSR_MSC_SG_OSC.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Transpiração__mol_m²_s¹__PLSR_OPLS1_SNV_SG_D1.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Transpiração__mol_m²_s¹__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Transpiração__mol_m²_s¹__PCR_MSC_SG_OSC.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Transpiração__mol_m²_s¹__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Transpiração__mol_m²_s¹__PCR_SG_D1.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Transpiração__mol_m²_s¹__PCR_SNV_Detrend_SG_D1.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Transpiração__mol_m²_s¹__SVMR_Continuum_Removal.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Transpiração__mol_m²_s¹__SVMR_OPLS2_SNV_SG_D1.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Transpiração__mol_m²_s¹__SVMR_OPLS1_SNV_SG_D1.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Transpiração__mol_m²_s¹__SVMR_OSC_1.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Transpiração__mol_m²_s¹__SVMR_SG_D1.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Transpiração__mol_m²_s¹__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Transpiração__mol_m²_s¹__RFR_MSC_SG_OSC.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Transpiração__mol_m²_s¹__RFR_OPLS1_SNV_SG_D1.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Transpiração__mol_m²_s¹__RFR_Wavelet_Denoising.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Transpiração__mol_m²_s¹__RFR_Raw.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: Eficiencia uso de agua (g/MJ¹)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: -1.9380 (±4.8143) | Concluído em 0.06s
#   Testando filtro: MSC... CV R²: -2.8648 (±4.7828) | Concluído em 0.06s
#   Testando filtro: SNV... CV R²: -3.0500 (±4.9044) | Concluído em 0.06s
#   Testando filtro: SG_D1... CV R²: -2.6276 (±3.4805) | Concluído em 0.06s
#   Testando filtro: SG_D2... CV R²: -1.4715 (±1.8811) | Concluído em 0.07s
#   Testando filtro: Detrend... CV R²: -2.0706 (±4.1265) | Concluído em 0.06s
#   Testando filtro: Normalize... CV R²: -2.1806 (±3.0568) | Concluído em 0.06s
#   Testando filtro: EMSC... CV R²: -2.8648 (±4.7828) | Concluído em 0.06s
#   Testando filtro: Continuum_Removal... CV R²: -1.9644 (±3.6350) | Concluído em 0.16s
#   Testando filtro: Wavelet_Denoising... CV R²: -1.9378 (±4.8146) | Concluído em 0.06s
#   Testando filtro: OSC_1... CV R²: -2.1633 (±4.4516) | Concluído em 0.06s
#   Testando filtro: OSC_2... CV R²: -3.2903 (±5.6403) | Concluído em 0.06s
#   Testando filtro: MSC_SG_OSC... CV R²: -1.2467 (±1.5331) | Concluído em 0.06s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -1.2318 (±1.5400) | Concluído em 0.06s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.5712 (±1.0770) | Concluído em 0.06s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -1.9820 (±2.1939) | Concluído em 0.06s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: -1.8650 (±5.5624) | Concluído em 0.10s
#   Testando filtro: MSC... CV R²: -0.8864 (±2.1725) | Concluído em 0.10s
#   Testando filtro: SNV... CV R²: -0.8815 (±2.1629) | Concluído em 0.09s
#   Testando filtro: SG_D1... CV R²: -1.0877 (±3.1076) | Concluído em 0.10s
#   Testando filtro: SG_D2... CV R²: -0.5652 (±0.6136) | Concluído em 0.09s
#   Testando filtro: Detrend... CV R²: -1.4965 (±4.5093) | Concluído em 0.10s
#   Testando filtro: Normalize... CV R²: -0.6398 (±1.5023) | Concluído em 0.10s
#   Testando filtro: EMSC... CV R²: -0.8864 (±2.1725) | Concluído em 0.09s
#   Testando filtro: Continuum_Removal... CV R²: -1.4344 (±2.4147) | Concluído em 0.21s
#   Testando filtro: Wavelet_Denoising... CV R²: -1.8653 (±5.5632) | Concluído em 0.11s
#   Testando filtro: OSC_1... CV R²: -1.6533 (±5.3937) | Concluído em 0.10s
#   Testando filtro: OSC_2... CV R²: -1.4857 (±4.6372) | Concluído em 0.10s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.9242 (±1.8277) | Concluído em 0.10s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.9098 (±1.8126) | Concluído em 0.10s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.5872 (±1.1225) | Concluído em 0.10s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.7303 (±1.7277) | Concluído em 0.11s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: -0.3563 (±0.7611) | Concluído em 0.32s
#   Testando filtro: MSC... CV R²: -0.1906 (±0.8012) | Concluído em 0.32s
#   Testando filtro: SNV... CV R²: -0.2574 (±0.8969) | Concluído em 0.32s
#   Testando filtro: SG_D1... CV R²: -0.4178 (±0.6967) | Concluído em 0.32s
#   Testando filtro: SG_D2... CV R²: -0.5139 (±0.6888) | Concluído em 0.32s
#   Testando filtro: Detrend... CV R²: -0.3944 (±0.9076) | Concluído em 0.33s
#   Testando filtro: Normalize... CV R²: -0.2515 (±0.8089) | Concluído em 0.31s
#   Testando filtro: EMSC... CV R²: -0.1906 (±0.8012) | Concluído em 0.33s
#   Testando filtro: Continuum_Removal... CV R²: -0.4325 (±0.7997) | Concluído em 0.39s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.3564 (±0.7611) | Concluído em 0.32s
#   Testando filtro: OSC_1... CV R²: -0.4446 (±1.0960) | Concluído em 0.33s
#   Testando filtro: OSC_2... CV R²: -0.2067 (±0.9739) | Concluído em 0.35s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.4683 (±0.7389) | Concluído em 0.31s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.4669 (±0.7228) | Concluído em 0.33s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.2439 (±0.9012) | Concluído em 0.31s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.4113 (±0.7378) | Concluído em 0.31s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: -0.6624 (±1.5623) | Concluído em 524.00s
#   Testando filtro: MSC... CV R²: -0.7572 (±1.7313) | Concluído em 558.02s
#   Testando filtro: SNV... CV R²: -0.7748 (±1.7951) | Concluído em 552.08s
#   Testando filtro: SG_D1... CV R²: -0.7184 (±1.8958) | Concluído em 557.85s
#   Testando filtro: SG_D2... CV R²: -0.5361 (±0.9187) | Concluído em 559.09s
#   Testando filtro: Detrend... CV R²: -0.0960 (±0.8147) | Concluído em 602.53s
#   Testando filtro: Normalize... CV R²: -1.1122 (±2.5237) | Concluído em 537.09s
#   Testando filtro: EMSC... CV R²: -0.7572 (±1.7313) | Concluído em 558.06s
#   Testando filtro: Continuum_Removal... CV R²: -0.4116 (±0.8481) | Concluído em 533.68s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.6555 (±1.6753) | Concluído em 529.46s
#   Testando filtro: OSC_1... CV R²: -0.5505 (±1.6073) | Concluído em 538.49s
#   Testando filtro: OSC_2... CV R²: -1.0110 (±2.8293) | Concluído em 546.87s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.1314 (±1.1477) | Concluído em 557.83s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.1238 (±1.1694) | Concluído em 557.08s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.2890 (±0.8189) | Concluído em 536.30s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.5271 (±1.0346) | Concluído em 550.47s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Eficiencia uso de agua (g/MJ¹)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Eficiencia_uso_de_agua__g_MJ¹_.joblib
#    - Modelo: RFR
#    - Filtro: Detrend
#    - Melhor R² CV: -0.0960
#    - Melhores Parâmetros: {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300, 'warm_start': True}
#
# --- Salvando os 5 melhores modelos para Eficiencia uso de agua (g/MJ¹) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Eficiencia_uso_de_agua__g_MJ¹__PLSR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Eficiencia_uso_de_agua__g_MJ¹__PLSR_OPLS1_SNV_SG_D1.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Eficiencia_uso_de_agua__g_MJ¹__PLSR_MSC_SG_OSC.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Eficiencia_uso_de_agua__g_MJ¹__PLSR_SG_D2.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Eficiencia_uso_de_agua__g_MJ¹__PLSR_Wavelet_Denoising.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Eficiencia_uso_de_agua__g_MJ¹__PCR_SG_D2.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Eficiencia_uso_de_agua__g_MJ¹__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Eficiencia_uso_de_agua__g_MJ¹__PCR_Normalize.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Eficiencia_uso_de_agua__g_MJ¹__PCR_SNV_Detrend_SG_D1.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Eficiencia_uso_de_agua__g_MJ¹__PCR_SNV.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Eficiencia_uso_de_agua__g_MJ¹__SVMR_MSC.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Eficiencia_uso_de_agua__g_MJ¹__SVMR_EMSC.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Eficiencia_uso_de_agua__g_MJ¹__SVMR_OSC_2.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Eficiencia_uso_de_agua__g_MJ¹__SVMR_OPLS2_SNV_SG_D1.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Eficiencia_uso_de_agua__g_MJ¹__SVMR_Normalize.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Eficiencia_uso_de_agua__g_MJ¹__RFR_Detrend.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Eficiencia_uso_de_agua__g_MJ¹__RFR_OPLS1_SNV_SG_D1.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Eficiencia_uso_de_agua__g_MJ¹__RFR_MSC_SG_OSC.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Eficiencia_uso_de_agua__g_MJ¹__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Eficiencia_uso_de_agua__g_MJ¹__RFR_Continuum_Removal.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: Eficiencia de carboxilacao (μmol CO2/m²/s)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: -4.6323 (±8.1894) | Concluído em 0.06s
#   Testando filtro: MSC... CV R²: -5.6415 (±10.7027) | Concluído em 0.06s
#   Testando filtro: SNV... CV R²: -5.3961 (±9.0731) | Concluído em 0.06s
#   Testando filtro: SG_D1... CV R²: -3.0381 (±4.8914) | Concluído em 0.07s
#   Testando filtro: SG_D2... CV R²: -3.3138 (±6.2528) | Concluído em 0.06s
#   Testando filtro: Detrend... CV R²: -5.7530 (±11.3742) | Concluído em 0.06s
#   Testando filtro: Normalize... CV R²: -4.9846 (±10.6167) | Concluído em 0.06s
#   Testando filtro: EMSC... CV R²: -5.6415 (±10.7027) | Concluído em 0.06s
#   Testando filtro: Continuum_Removal... CV R²: -4.8193 (±11.1789) | Concluído em 0.13s
#   Testando filtro: Wavelet_Denoising... CV R²: -4.6305 (±8.1872) | Concluído em 0.06s
#   Testando filtro: OSC_1... CV R²: -4.6720 (±10.0812) | Concluído em 0.06s
#   Testando filtro: OSC_2... CV R²: -3.5188 (±6.3889) | Concluído em 0.06s
#   Testando filtro: MSC_SG_OSC... CV R²: -5.2447 (±8.5691) | Concluído em 0.08s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -5.0412 (±8.2629) | Concluído em 0.08s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.9680 (±1.8565) | Concluído em 0.09s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -2.6877 (±4.8084) | Concluído em 0.08s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: -4.0491 (±8.6126) | Concluído em 0.09s
#   Testando filtro: MSC... CV R²: -2.6964 (±6.0627) | Concluído em 0.10s
#   Testando filtro: SNV... CV R²: -2.7171 (±6.1298) | Concluído em 0.09s
#   Testando filtro: SG_D1... CV R²: -2.6955 (±4.4471) | Concluído em 0.09s
#   Testando filtro: SG_D2... CV R²: -1.8436 (±2.9014) | Concluído em 0.11s
#   Testando filtro: Detrend... CV R²: -2.8908 (±5.0464) | Concluído em 0.09s
#   Testando filtro: Normalize... CV R²: -4.3192 (±9.4533) | Concluído em 0.09s
#   Testando filtro: EMSC... CV R²: -2.6964 (±6.0627) | Concluído em 0.09s
#   Testando filtro: Continuum_Removal... CV R²: -2.5071 (±4.1217) | Concluído em 0.20s
#   Testando filtro: Wavelet_Denoising... CV R²: -4.0494 (±8.6134) | Concluído em 0.11s
#   Testando filtro: OSC_1... CV R²: -3.9931 (±6.3940) | Concluído em 0.12s
#   Testando filtro: OSC_2... CV R²: -2.3169 (±5.5482) | Concluído em 0.09s
#   Testando filtro: MSC_SG_OSC... CV R²: -3.5263 (±6.5013) | Concluído em 0.11s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -3.4837 (±6.3977) | Concluído em 0.11s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -3.4642 (±6.4001) | Concluído em 0.12s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -2.4025 (±3.6627) | Concluído em 0.11s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: -1.9131 (±4.0234) | Concluído em 0.27s
#   Testando filtro: MSC... CV R²: -1.9131 (±4.0234) | Concluído em 0.66s
#   Testando filtro: SNV... CV R²: -1.9131 (±4.0234) | Concluído em 0.29s
#   Testando filtro: SG_D1... CV R²: -1.9131 (±4.0234) | Concluído em 0.29s
#   Testando filtro: SG_D2... CV R²: -1.9131 (±4.0234) | Concluído em 0.28s
#   Testando filtro: Detrend... CV R²: -1.9131 (±4.0234) | Concluído em 0.27s
#   Testando filtro: Normalize... CV R²: -1.9131 (±4.0234) | Concluído em 0.30s
#   Testando filtro: EMSC... CV R²: -1.9131 (±4.0234) | Concluído em 0.28s
#   Testando filtro: Continuum_Removal... CV R²: -1.9131 (±4.0234) | Concluído em 0.34s
#   Testando filtro: Wavelet_Denoising... CV R²: -1.9131 (±4.0234) | Concluído em 0.27s
#   Testando filtro: OSC_1... CV R²: -1.9131 (±4.0234) | Concluído em 0.27s
#   Testando filtro: OSC_2... CV R²: -1.9131 (±4.0234) | Concluído em 0.27s
#   Testando filtro: MSC_SG_OSC... CV R²: -1.9131 (±4.0234) | Concluído em 0.28s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -1.9131 (±4.0234) | Concluído em 0.27s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -1.9131 (±4.0234) | Concluído em 0.28s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -1.9131 (±4.0234) | Concluído em 0.28s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: -2.2018 (±3.5619) | Concluído em 498.44s
#   Testando filtro: MSC... CV R²: -2.9846 (±6.3296) | Concluído em 521.52s
#   Testando filtro: SNV... CV R²: -2.9922 (±6.4629) | Concluído em 521.38s
#   Testando filtro: SG_D1... CV R²: -1.7329 (±2.7668) | Concluído em 488.98s
#   Testando filtro: SG_D2... CV R²: -1.8824 (±3.3998) | Concluído em 509.99s
#   Testando filtro: Detrend... CV R²: -2.4722 (±4.7460) | Concluído em 515.70s
#   Testando filtro: Normalize... CV R²: -2.1044 (±5.3934) | Concluído em 519.12s
#   Testando filtro: EMSC... CV R²: -2.9846 (±6.3296) | Concluído em 519.60s
#   Testando filtro: Continuum_Removal... CV R²: -2.6781 (±5.4560) | Concluído em 503.00s
#   Testando filtro: Wavelet_Denoising... CV R²: -2.3179 (±3.2380) | Concluído em 502.07s
#   Testando filtro: OSC_1... CV R²: -2.2832 (±4.0320) | Concluído em 487.96s
#   Testando filtro: OSC_2... CV R²: -2.5966 (±4.5035) | Concluído em 517.25s
#   Testando filtro: MSC_SG_OSC... CV R²: -2.4824 (±4.2089) | Concluído em 530.42s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -2.5542 (±4.3244) | Concluído em 514.55s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -1.5945 (±3.6074) | Concluído em 494.24s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -1.5433 (±3.8813) | Concluído em 537.69s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Eficiencia de carboxilacao (μmol CO2/m²/s)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Eficiencia_de_carboxilacao__μmol_CO2_m²_s_.joblib
#    - Modelo: PLSR
#    - Filtro: OPLS2_SNV_SG_D1
#    - Melhor R² CV: -0.9680
#    - Melhores Parâmetros: {'n_components': 20}
#
# --- Salvando os 5 melhores modelos para Eficiencia de carboxilacao (μmol CO2/m²/s) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__PLSR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__PLSR_SNV_Detrend_SG_D1.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__PLSR_SG_D1.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__PLSR_SG_D2.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__PLSR_OSC_2.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__PCR_SG_D2.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__PCR_OSC_2.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__PCR_SNV_Detrend_SG_D1.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__PCR_Continuum_Removal.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__PCR_SG_D1.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__SVMR_Raw.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__SVMR_MSC.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__SVMR_SNV.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__SVMR_SG_D1.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__SVMR_SG_D2.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__RFR_SNV_Detrend_SG_D1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__RFR_SG_D1.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__RFR_SG_D2.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Eficiencia_de_carboxilacao__μmol_CO2_m²_s__RFR_Normalize.joblib
#
#
#  ✅ Modelagem exaustiva com Cross-Validation!
#   ✅Resultados salvos em "analise_completa_resultados_cv.xlsx"
#
# --- Melhores Resultados por Atributo (Cross-Validation) ---
#                                   Atributo Modelo            Filtro  CV_R2_Mean  CV_R2_Std  CV_RMSE                                                                                                                Melhores_Params
#                      Carbono Interno (ppm)    RFR   OPLS2_SNV_SG_D1     -0.1931     1.6140  56.3247 {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 300, 'warm_start': True}
#        Condutancia estomatica (mmol/m²/s¹)    RFR        MSC_SG_OSC     -0.5882     1.4513   0.0680   {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 300, 'warm_start': True}
# Eficiencia de carboxilacao (μmol CO2/m²/s)   PLSR   OPLS2_SNV_SG_D1     -0.9680     1.8565   0.0129                                                                                                           {'n_components': 20}
#             Eficiencia uso de agua (g/MJ¹)    RFR           Detrend     -0.0960     0.8147   0.3280  {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300, 'warm_start': True}
#               Fotossintese (μmol CO2/m²/s)   SVMR             SG_D1     -0.2086     0.3703   3.3170                                                               {'C': 100, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#                   Transpiração (mol/m²/s¹)   SVMR Continuum_Removal     -0.7905     1.0858   1.9462                                                                      {'C': 10, 'epsilon': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}

# %% [markdown]
# ## 7. Análise Comparativa dos Resultados

# %%
import pandas as pd
import numpy as np

# Carregar os resultados salvos para análise
df_analise = pd.read_excel('analise_completa_resultados_cv.xlsx')

idx = df_analise.groupby(['Atributo', 'Modelo'])['CV_R2_Mean'].transform(max) == df_analise['CV_R2_Mean']
df_melhores_por_modelo = df_analise[idx]

print("--- Tabela Comparativa dos Melhores Resultados por Modelo (Cross-Validation) ---")
print(df_melhores_por_modelo[['Atributo', 'Modelo', 'Filtro', 'CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE']].round(4))

print("\n--- Melhores Modelos Gerais por Atributo (baseado no R² de Cross-Validation) ---")
idx_geral = df_melhores_por_modelo.groupby(['Atributo'])['CV_R2_Mean'].transform(max) == df_melhores_por_modelo['CV_R2_Mean']
df_melhores_gerais = df_melhores_por_modelo[idx_geral]
print(df_melhores_gerais[['Atributo', 'Modelo', 'Filtro', 'CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE']].round(4))

# Análise estatística adicional
print("\n--- Análise Estatística dos Resultados ---")
print(f"Número total de combinações testadas: {len(df_analise)}")
print(f"Número de atributos analisados: {df_analise['Atributo'].nunique()}")
print(f"Número de modelos testados: {df_analise['Modelo'].nunique()}")
print(f"Número de filtros testados: {df_analise['Filtro'].nunique()}")

print(f"\nEstatísticas do R² de Cross-Validation:")
print(f"  Média geral: {df_analise['CV_R2_Mean'].mean():.4f}")
print(f"  Desvio padrão: {df_analise['CV_R2_Mean'].std():.4f}")
print(f"  Melhor resultado: {df_analise['CV_R2_Mean'].max():.4f}")
print(f"  Pior resultado: {df_analise['CV_R2_Mean'].min():.4f}")

# Análise por modelo
print(f"\n--- Desempenho Médio por Modelo ---")
desempenho_por_modelo = df_analise.groupby('Modelo')['CV_R2_Mean'].agg(['mean', 'std', 'max', 'min']).round(4)
print(desempenho_por_modelo)

# Análise por filtro
print(f"\n--- Top 10 Filtros com Melhor Desempenho Médio ---")
desempenho_por_filtro = df_analise.groupby('Filtro')['CV_R2_Mean'].agg(['mean', 'std', 'count']).round(4)
desempenho_por_filtro = desempenho_por_filtro.sort_values('mean', ascending=False)
print(desempenho_por_filtro.head(10))

print("\n✅ Análise de resultados concluída!")
# Out:
# --- Tabela Comparativa dos Melhores Resultados por Modelo (Cross-Validation) ---
#                                        Atributo Modelo             Filtro  \
# 0                         Carbono Interno (ppm)    RFR    OPLS2_SNV_SG_D1
# 1                         Carbono Interno (ppm)   SVMR          Normalize
# 21                        Carbono Interno (ppm)    PCR    OPLS2_SNV_SG_D1
# 33                        Carbono Interno (ppm)   PLSR              SG_D2
# 64          Condutancia estomatica (mmol/m²/s¹)    RFR         MSC_SG_OSC
# 67          Condutancia estomatica (mmol/m²/s¹)   SVMR              OSC_1
# 77          Condutancia estomatica (mmol/m²/s¹)    PCR    OPLS2_SNV_SG_D1
# 88          Condutancia estomatica (mmol/m²/s¹)   PLSR    OPLS1_SNV_SG_D1
# 128  Eficiencia de carboxilacao (μmol CO2/m²/s)   PLSR    OPLS2_SNV_SG_D1
# 129  Eficiencia de carboxilacao (μmol CO2/m²/s)    RFR  SNV_Detrend_SG_D1
# 132  Eficiencia de carboxilacao (μmol CO2/m²/s)    PCR              SG_D2
# 134  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR                Raw
# 135  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR                MSC
# 136  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR                SNV
# 137  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR              SG_D1
# 138  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR              SG_D2
# 139  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR            Detrend
# 140  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR          Normalize
# 141  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR               EMSC
# 142  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR  Continuum_Removal
# 143  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR  Wavelet_Denoising
# 144  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR              OSC_1
# 145  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR              OSC_2
# 146  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR         MSC_SG_OSC
# 147  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR    OPLS1_SNV_SG_D1
# 148  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR    OPLS2_SNV_SG_D1
# 149  Eficiencia de carboxilacao (μmol CO2/m²/s)   SVMR  SNV_Detrend_SG_D1
# 192              Eficiencia uso de agua (g/MJ¹)    RFR            Detrend
# 195              Eficiencia uso de agua (g/MJ¹)   SVMR                MSC
# 216              Eficiencia uso de agua (g/MJ¹)    PCR              SG_D2
# 217              Eficiencia uso de agua (g/MJ¹)   PLSR    OPLS2_SNV_SG_D1
# 256                Fotossintese (μmol CO2/m²/s)   SVMR              SG_D1
# 258                Fotossintese (μmol CO2/m²/s)    RFR  Continuum_Removal
# 274                Fotossintese (μmol CO2/m²/s)    PCR  SNV_Detrend_SG_D1
# 283                Fotossintese (μmol CO2/m²/s)   PLSR              SG_D2
# 320                    Transpiração (mol/m²/s¹)   SVMR  Continuum_Removal
# 336                    Transpiração (mol/m²/s¹)    RFR    OPLS2_SNV_SG_D1
# 337                    Transpiração (mol/m²/s¹)    PCR    OPLS2_SNV_SG_D1
# 349                    Transpiração (mol/m²/s¹)   PLSR    OPLS2_SNV_SG_D1
#
#      CV_R2_Mean  CV_R2_Std  CV_RMSE
# 0       -0.1931     1.6140  56.3247
# 1       -0.3876     0.7549  92.6201
# 21      -2.3970     2.7089  86.4529
# 33      -3.7324     4.4952  93.6940
# 64      -0.5882     1.4513   0.0680
# 67      -1.6277     2.7230   0.0781
# 77      -1.8049     3.0335   0.0755
# 88      -2.2137     3.6244   0.0811
# 128     -0.9680     1.8565   0.0129
# 129     -1.5433     3.8813   0.0155
# 132     -1.8436     2.9014   0.0154
# 134     -1.9131     4.0234   0.0151
# 135     -1.9131     4.0234   0.0151
# 136     -1.9131     4.0234   0.0151
# 137     -1.9131     4.0234   0.0151
# 138     -1.9131     4.0234   0.0151
# 139     -1.9131     4.0234   0.0151
# 140     -1.9131     4.0234   0.0151
# 141     -1.9131     4.0234   0.0151
# 142     -1.9131     4.0234   0.0151
# 143     -1.9131     4.0234   0.0151
# 144     -1.9131     4.0234   0.0151
# 145     -1.9131     4.0234   0.0151
# 146     -1.9131     4.0234   0.0151
# 147     -1.9131     4.0234   0.0151
# 148     -1.9131     4.0234   0.0151
# 149     -1.9131     4.0234   0.0151
# 192     -0.0960     0.8147   0.3280
# 195     -0.1906     0.8012   0.3293
# 216     -0.5652     0.6136   0.3686
# 217     -0.5712     1.0770   0.3541
# 256     -0.2086     0.3703   3.3170
# 258     -0.2661     0.4299   3.3545
# 274     -0.5437     1.1097   3.3090
# 283     -0.8189     1.3392   3.5016
# 320     -0.7905     1.0858   1.9462
# 336     -1.4576     2.9794   1.6780
# 337     -1.5400     3.1411   1.6861
# 349     -2.3151     4.9686   1.6888
#
# --- Melhores Modelos Gerais por Atributo (baseado no R² de Cross-Validation) ---
#                                        Atributo Modelo             Filtro  \
# 0                         Carbono Interno (ppm)    RFR    OPLS2_SNV_SG_D1
# 64          Condutancia estomatica (mmol/m²/s¹)    RFR         MSC_SG_OSC
# 128  Eficiencia de carboxilacao (μmol CO2/m²/s)   PLSR    OPLS2_SNV_SG_D1
# 192              Eficiencia uso de agua (g/MJ¹)    RFR            Detrend
# 256                Fotossintese (μmol CO2/m²/s)   SVMR              SG_D1
# 320                    Transpiração (mol/m²/s¹)   SVMR  Continuum_Removal
#
#      CV_R2_Mean  CV_R2_Std  CV_RMSE
# 0       -0.1931     1.6140  56.3247
# 64      -0.5882     1.4513   0.0680
# 128     -0.9680     1.8565   0.0129
# 192     -0.0960     0.8147   0.3280
# 256     -0.2086     0.3703   3.3170
# 320     -0.7905     1.0858   1.9462
#
# --- Análise Estatística dos Resultados ---
# Número total de combinações testadas: 384
# Número de atributos analisados: 6
# Número de modelos testados: 4
# Número de filtros testados: 16
#
# Estatísticas do R² de Cross-Validation:
#   Média geral: -2.4883
#   Desvio padrão: 1.9539
#   Melhor resultado: -0.0960
#   Pior resultado: -12.2830
#
# --- Desempenho Médio por Modelo ---
#           mean     std     max      min
# Modelo
# PCR    -2.5232  1.5109 -0.5437  -8.8284
# PLSR   -4.4652  2.2546 -0.5712 -12.2830
# RFR    -1.9287  1.1030 -0.0960  -4.6564
# SVMR   -1.0361  0.6405 -0.1906  -1.9145
#
# --- Top 10 Filtros com Melhor Desempenho Médio ---
#                      mean     std  count
# Filtro
# OPLS2_SNV_SG_D1   -1.5359  1.2276     24
# SG_D2             -1.7866  1.0041     24
# SNV_Detrend_SG_D1 -2.1780  1.5609     24
# OPLS1_SNV_SG_D1   -2.2207  1.9071     24
# MSC_SG_OSC        -2.2662  2.0312     24
# SG_D1             -2.4479  1.7257     24
# Continuum_Removal -2.4682  2.7491     24
# OSC_2             -2.4754  1.5761     24
# Raw               -2.5362  1.8349     24
# Wavelet_Denoising -2.5403  1.8338     24
#
# ✅ Análise de resultados concluída!

# %% [markdown]
# ## Testes

# %%
## Linha de teste
