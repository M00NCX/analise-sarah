# %% [markdown]
# # Análise Espectroscópica
#
# Este notebook segue as melhores práticas da literatura para análise espectroscópica robusta, incluindo:
# - Cross Validation
# - Remoção de outliers espectrais (PCA, T²/Q)
# - Remoção de outliers dos atributos (boxplot + seaborn)
# - Teste de todos os filtros (dependentes e independentes de y)
# - Modelagem com PLSR, PCR, RFR, SVMR (hiperparâmetros da literatura)
# - Plotagens robustas e salvamento de métricas

# %% [markdown]
# ## 1. Imports

# %%
# Imports necessários
import os
import time
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from scipy.signal import savgol_filter
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, GridSearchCV, cross_val_predict, cross_val_score
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_squared_error
from matplotlib.mlab import detrend
import pywt
from sklearn.pipeline import Pipeline

# Cria diretórios para organizar todas as imagens salvas
print("Criando diretórios para salvar os gráficos...")
os.makedirs('graficos_outliers_pca', exist_ok=True)
os.makedirs('graficos_outliers_boxplot', exist_ok=True)
os.makedirs('modelos_salvos', exist_ok=True)
os.makedirs('graficos_modelos', exist_ok=True) 
os.makedirs('graficos_mlpr', exist_ok=True)

warnings.filterwarnings('ignore')

# Configurações de plot
plt.style.use('default')
sns.set_palette('husl')
plt.rcParams['figure.figsize'] = (12, 8)
# Out:
# Criando diretórios para salvar os gráficos...

# %% [markdown]
# ## 2. Carregamento dos Dados

# %% [markdown]
# O primeiro passo em qualquer projeto de ciência de dados é carregar e entender os dados. Nesta seção, realizamos as seguintes ações:
# - **Carregamento:** Utilizamos a biblioteca `pandas` para ler o arquivo `Simulacao_Exportacao_Keitt_e_Kent_Tellspec.xlsx`, que contém os dados espectrais e os valores de referência (atributos físico-químicos).
# - **Separação de Dados:** A função `load_data` inteligentemente separa o arquivo em duas partes:
#     - `metadata`: Um DataFrame contendo as informações de referência (ex: Firmness, Dry Mass, TSS, TA, AA), que serão nossas variáveis-alvo (y).
#     - `wavelengths`: Um DataFrame contendo a resposta espectral (absorbância ou reflectância) em cada comprimento de onda, que serão nossas variáveis preditoras (X).
# - **Definição de Variáveis:** Convertemos os dados espectrais para um array NumPy (`X`) para otimizar os cálculos e definimos a lista de `atributos` que desejamos modelar.

# %%
# Função para carregar dados
def load_data(filepath):
    """Carrega dados espectrais e separa metadados de espectros."""
    df = pd.read_excel(filepath, engine='openpyxl')
    
    # Identificar colunas que são comprimentos de onda (numéricas)
    numeric_cols = []
    for col in df.columns:
        try:
            float(col)
            numeric_cols.append(col)
        except ValueError:
            continue
    
    # Separar metadados e comprimentos de onda
    metadata = df.drop(columns=numeric_cols)
    wavelengths = df[numeric_cols]
    
    return metadata, wavelengths

# Carregar dados
filepath = '../Data/raw/Folha/Avaliacao_nutricional.xlsx'
metadata, wavelengths = load_data(filepath)
X = wavelengths.values
wavelength_values = wavelengths.columns.astype(float)

# VARIÁVEIS DA SARAH
atributos = ['N (g/kg)', 'P (g/kg)', 'K (g/kg)', 'Ca (g/kg)', 'Mg (g/kg)', 'S (g/kg)', 'B (mg/kg)', 'Fe (mg/kg)', 'Mn (mg/kg)', 'Zn (mg/kg)', 'Mo ']


print(f'Dados carregados: {X.shape[0]} amostras, {X.shape[1]} comprimentos de onda')
print(f'Faixa espectral: {wavelength_values.min():.1f} - {wavelength_values.max():.1f} nm')
print(f'Atributos disponíveis: {list(metadata.columns)}')
print(f'Atributos a analisar: {atributos}')

# remoção de NaN antes de passar pelo pré-processamento e conferência

dados_completos = {}
for atributo in atributos:
    y = metadata[atributo].values
    original_indices = np.arange(len(y))
    
    # Remove apenas valores NaN
    mask = ~np.isnan(y)
    X_clean = X[mask]
    y_clean = y[mask]
    original_indices_clean = original_indices[mask]
    
    dados_completos[atributo] = {
        'X': X_clean,
        'y': y_clean,
        'indices_orig': original_indices_clean
    }
    
    print(f'{atributo}: {X_clean.shape[0]} amostras válidas')

print(f'\nPreparação dos dados concluída para {len(atributos)} atributos!')
# Out:
# Dados carregados: 76 amostras, 2151 comprimentos de onda
# Faixa espectral: 350.0 - 2500.0 nm
# Atributos disponíveis: ['Wavelength', 'Variedade', 'N (g/kg)', 'P (g/kg)', 'K (g/kg)', 'Ca (g/kg)', 'Mg (g/kg)', 'S (g/kg)', 'B (mg/kg)', 'Fe (mg/kg)', 'Mn (mg/kg)', 'Zn (mg/kg)', 'Mo ']
# Atributos a analisar: ['N (g/kg)', 'P (g/kg)', 'K (g/kg)', 'Ca (g/kg)', 'Mg (g/kg)', 'S (g/kg)', 'B (mg/kg)', 'Fe (mg/kg)', 'Mn (mg/kg)', 'Zn (mg/kg)', 'Mo ']
# N (g/kg): 76 amostras válidas
# P (g/kg): 76 amostras válidas
# K (g/kg): 76 amostras válidas
# Ca (g/kg): 76 amostras válidas
# Mg (g/kg): 76 amostras válidas
# S (g/kg): 76 amostras válidas
# B (mg/kg): 76 amostras válidas
# Fe (mg/kg): 76 amostras válidas
# Mn (mg/kg): 76 amostras válidas
# Zn (mg/kg): 76 amostras válidas
# Mo : 76 amostras válidas
#
# Preparação dos dados concluída para 11 atributos!

# %% [markdown]
# ## 3. Filtros de Pré-processamento (Independentes e Dependentes de y)

# %% [markdown]
# Os dados espectrais brutos contêm diversas fontes de variação indesejada que podem mascarar a informação química relevante. Essas variações podem ser causadas por espalhamento de luz (efeitos físicos da amostra), mudanças na linha de base (drift do instrumento) e ruído. O pré-processing visa minimizar esses efeitos para que o modelo foque na correlação entre o espectro e o atributo de interesse.
#
# Neste notebook, testamos uma ampla gama de filtros, divididos em duas categorias:
#
# ### Filtros Independentes de y
#
# São aplicados apenas aos espectros (`X`) e não utilizam a informação da variável alvo (`y`).
#
# -   **`Raw`**: Utiliza os dados espectrais brutos, sem nenhum tratamento. Serve como uma linha de base para comparar a eficácia dos outros filtros.
# -   **`MSC` (Multiplicative Scatter Correction)**: Corrige o espalhamento de luz (aditivo e multiplicativo) causado por variações no tamanho de partícula e compactação da amostra. Ele ajusta cada espectro para se parecer mais com um espectro "ideal" (geralmente a média de todos os espectros).
# -   **`SNV` (Standard Normal Variate)**: Alternativa ao MSC que também corrige o espalhamento de luz. A diferença é que o SNV padroniza cada espectro individualmente (subtrai a média e divide pelo desvio padrão daquele espectro), sem usar um espectro de referência.
# -   **`SG_D1` e `SG_D2` (Savitzky-Golay Derivatives)**: Calcula a primeira ou a segunda derivada do espectro. Derivadas são excelentes para remover desvios de linha de base (efeitos aditivos) e para resolver picos espectrais sobrepostos, realçando a informação de bandas de absorção específicas.
# -   **`Detrend`**: Remove tendências lineares ou polinomiais da linha de base do espectro. É muito eficaz para corrigir "inclinações" no espectro causadas por drift do instrumento.
# -   **`Normalize`**: Realiza uma normalização Min-Max, escalonando a intensidade de cada espectro para um intervalo fixo (geralmente [0, 1]). Ajuda a corrigir variações de intensidade causadas por diferenças na distância da amostra ou na potência da fonte de luz.
# -   **`EMSC` (Extended Multiplicative Signal Correction)**: Uma versão avançada do MSC. Além de corrigir os efeitos de espalhamento, o EMSC pode incluir termos polinomiais para modelar e remover efeitos de linha de base mais complexos e não-lineares.
# -   **`Continuum Removal`**: Técnica que normaliza os espectros para que as bandas de absorção possam ser comparadas em termos de sua profundidade, e não de sua intensidade absoluta. Ele ajusta um "envelope" (casco convexo) sobre o espectro e divide o espectro original por este envelope, realçando as características de absorção.
# -   **`Wavelet_Denoising`**: Utiliza a Transformada Wavelet para decompor o espectro em diferentes níveis de frequência. A técnica permite remover o ruído (geralmente presente em altas frequências) de forma muito eficaz, preservando as principais características do sinal espectral.
#
# ### Filtros Dependentes de y e Combinações
#
# Estes filtros utilizam a variável alvo (`y`) para otimizar a remoção de variação não correlacionada em `X`, ou são combinações sequenciais de múltiplos filtros para um tratamento mais completo.
#
# -   **`OSC_1` e `OSC_2` (Orthogonal Signal Correction)**: Filtro que remove componentes (1 ou 2, neste caso) dos espectros `X` que são ortogonais (não correlacionados) à variável alvo `y`. O objetivo é limpar `X` da variação que não ajuda na predição, potencialmente melhorando o modelo subsequente. Esta técnica é frequentemente referida como um pré-processamento **OPLS** (Orthogonal Projections to Latent Structures).
# -   **`MSC_SG_OSC`**: Uma **cadeia de pré-processamentos** aplicada na seguinte ordem:
#     1.  `MSC` para corrigir o espalhamento.
#     2.  `Savitzky-Golay (1ª derivada)` para corrigir a linha de base.
#     3.  `OSC (1 componente)` para remover variação não correlacionada com `y`.
# -   **`OPLS1_SNV_SG_D1` e `OPLS2_SNV_SG_D1`**: Outra cadeia de processamento:
#     1.  `SNV` para correção de espalhamento.
#     2.  `Savitzky-Golay (1ª derivada)`.
#     3.  `OPLS/OSC` para remover 1 ou 2 componentes ortogonais a `y`.
# -   **`SNV_Detrend_SG_D1`**: Uma combinação de filtros independentes de `y`, mas que, por sua complexidade, é testada junto às outras cadeias:
#     1.  `SNV`.
#     2.  `Detrend` para remoção de tendência.
#     3.  `Savitzky-Golay (1ª derivada)`.

# %%
# Implementação dos filtros de pré-processamento
# Filtros independentes de y

def msc(X):
    """Multiplicative Scatter Correction."""
    X = np.asarray(X)
    mean_spectrum = np.mean(X, axis=0)
    corrected_spectra = np.zeros_like(X)
    for i in range(X.shape[0]):
        slope, intercept = np.polyfit(mean_spectrum, X[i, :], 1)
        corrected_spectra[i, :] = (X[i, :] - intercept) / slope
    return corrected_spectra

def snv(X):
    """Standard Normal Variate."""
    X = np.asarray(X)
    return (X - np.mean(X, axis=1, keepdims=True)) / np.std(X, axis=1, keepdims=True)

def savitzky_golay(X, window_size=11, poly_order=2, deriv_order=1):
    """Savitzky-Golay filter."""
    return savgol_filter(X, window_length=window_size, polyorder=poly_order, deriv=deriv_order, axis=1)

def detrend_filter(X):
    """Detrending filter."""
    return detrend(X, axis=1)

def normalize(X):
    """Normalização Min-Max."""
    return (X - np.min(X, axis=1, keepdims=True)) / (np.max(X, axis=1, keepdims=True) - np.min(X, axis=1, keepdims=True))

def emsc(X, reference=None):
    """Extended Multiplicative Signal Correction."""
    X = np.asarray(X)
    if reference is None:
        reference = np.mean(X, axis=0)  # Usa o espectro médio como referência
    
    X_corr = np.zeros_like(X)
    for i in range(X.shape[0]):
        # Modelo: X[i] ≈ a + b*reference
        model = np.vstack([np.ones_like(reference), reference]).T
        params, _, _, _ = np.linalg.lstsq(model, X[i, :], rcond=None)
        a, b = params[0], params[1]
        X_corr[i,:] = (X[i, :] - a) / b
    return X_corr

def continuum_removal(X, wavelengths):
    """Continuum Removal."""
    X = np.asarray(X)
    X_cr = np.zeros_like(X)
    for i in range(X.shape[0]):
        spectrum = X[i, :]
        # Encontra os pontos do casco convexo superior
        q_u = [0]
        for k in range(1, len(wavelengths) - 1):
            s_k = (spectrum[len(wavelengths)-1] - spectrum[0]) / (wavelengths[-1] - wavelengths[0])
            s_q = (spectrum[k] - spectrum[q_u[-1]]) / (wavelengths[k] - wavelengths[q_u[-1]])
            if s_q > s_k:
                q_u.append(k)
        q_u.append(len(wavelengths)-1)
        
        # Interpolação linear entre os pontos do casco
        continuum = np.interp(wavelengths, wavelengths[q_u], spectrum[q_u])
        X_cr[i, :] = spectrum / continuum
    return X_cr

def wavelet_denoising(X, wavelet='db4', level=4):
    """Wavelet Transform para Denoising."""
    X = np.asarray(X)
    original_length = X.shape[1]
    denoised_list = []

    for i in range(X.shape[0]):
        # 1. Decomposição Wavelet
        coeffs = pywt.wavedec(X[i, :], wavelet, level=level)

        # 2. Cálculo do limiar (threshold)
        sigma = np.median(np.abs(coeffs[-1])) / 0.6745
        threshold = sigma * np.sqrt(2 * np.log(original_length))

        # 3. Aplicação do filtro (soft thresholding) nos coeficientes de detalhe
        coeffs[1:] = [pywt.threshold(c, value=threshold, mode='soft') for c in coeffs[1:]]

        # 4. Reconstrução do sinal
        reconstructed_signal = pywt.waverec(coeffs, wavelet)

        # 5. Ajuste do tamanho
        denoised_list.append(reconstructed_signal[:original_length])

    return np.asarray(denoised_list)

# Filtros dependentes de y (Orthogonal Signal Correction)
class OrthogonalCorrection:
    """Orthogonal Signal Correction (OSC)."""
    def __init__(self, n_components=1):
        self.n_components = n_components
    
    def fit_transform(self, X, y):
        X, y = np.asarray(X), np.asarray(y).ravel()
        self.w_ortho_ = []
        self.p_ortho_ = []
        self.X_corr_ = X.copy()
        
        for _ in range(self.n_components):
            pls = PLSRegression(n_components=1)
            pls.fit(self.X_corr_, y)
            t = pls.x_scores_
            w = pls.x_weights_
            p = pls.x_loadings_
            
            # Componente Ortogonal
            w_ortho = p - (np.dot(w.T, p) / np.dot(w.T, w)) * w
            t_ortho = np.dot(self.X_corr_, w_ortho)
            p_ortho = np.dot(t_ortho.T, self.X_corr_) / np.dot(t_ortho.T, t_ortho)
            
            # Remover variação ortogonal
            self.X_corr_ -= np.dot(t_ortho, p_ortho)
            self.w_ortho_.append(w_ortho)
            self.p_ortho_.append(p_ortho)
        
        return self.X_corr_
    
    def transform(self, X):
        X_res = np.asarray(X).copy()
        for i in range(self.n_components):
            t_ortho = np.dot(X_res, self.w_ortho_[i])
            X_res -= np.dot(t_ortho, self.p_ortho_[i])
        return X_res

# Dicionário de filtros independentes de y
filtros_independentes = {
    'Raw': lambda X: X,
    'MSC': msc,
    'SNV': snv,
    'SG_D1': lambda X: savitzky_golay(X, window_size=11, poly_order=2, deriv_order=1),
    'SG_D2': lambda X: savitzky_golay(X, window_size=11, poly_order=2, deriv_order=2),
    'Detrend': detrend_filter,
    'Normalize': normalize,
    'EMSC': emsc,
    'Continuum_Removal': lambda X: continuum_removal(X, wavelength_values),
    'Wavelet_Denoising': wavelet_denoising
}

# Dicionário de filtros dependentes de y
filtros_dependentes = {
    'OSC_1': lambda X, y: OrthogonalCorrection(n_components=1).fit_transform(X, y),
    'OSC_2': lambda X, y: OrthogonalCorrection(n_components=2).fit_transform(X, y),
    'MSC_SG_OSC': lambda X, y: OrthogonalCorrection(n_components=1).fit_transform(
        savitzky_golay(msc(X), window_size=11, poly_order=2, deriv_order=1), y),
    'OPLS1_SNV_SG_D1': lambda X, y: OrthogonalCorrection(n_components=1).fit_transform(
        savitzky_golay(snv(X), window_size=11, poly_order=2, deriv_order=1), y),
    'OPLS2_SNV_SG_D1': lambda X, y: OrthogonalCorrection(n_components=2).fit_transform(
        savitzky_golay(snv(X), window_size=11, poly_order=2, deriv_order=1), y),
    'SNV_Detrend_SG_D1': lambda X, y: savitzky_golay(detrend_filter(snv(X)), window_size=11, poly_order=2, deriv_order=1)
}

print(f'Filtros independentes de y: {list(filtros_independentes.keys())}')
print(f'Filtros dependentes de y: {list(filtros_dependentes.keys())}')
print(f'Total de filtros: {len(filtros_independentes) + len(filtros_dependentes)}')
# Out:
# Filtros independentes de y: ['Raw', 'MSC', 'SNV', 'SG_D1', 'SG_D2', 'Detrend', 'Normalize', 'EMSC', 'Continuum_Removal', 'Wavelet_Denoising']
# Filtros dependentes de y: ['OSC_1', 'OSC_2', 'MSC_SG_OSC', 'OPLS1_SNV_SG_D1', 'OPLS2_SNV_SG_D1', 'SNV_Detrend_SG_D1']
# Total de filtros: 16

# %% [markdown]
# ## 4. Remoção de Outliers Espectrais (PCA, T²/Q)

# %% [markdown]
# Outliers espectrais são amostras cujo espectro é muito diferente do resto da população, podendo ser causados por erros de medição, contaminação ou características únicas da amostra. Eles podem prejudicar significativamente a capacidade de generalização do modelo.
# - **Método PCA (T²/Q):** Usamos a Análise de Componentes Principais (PCA) para identificar esses outliers.
#     - **Estatística T² (Hotelling's T²):** Mede a variação de uma amostra *dentro* do modelo PCA. Valores altos indicam que a amostra é um outlier na combinação das variáveis principais.
#     - **Estatística Q (Resíduos):** Mede a variação da amostra *fora* do modelo PCA (o que o modelo não conseguiu capturar). Valores altos indicam que a estrutura do espectro da amostra é anormal.
# - **Lógica:** Uma amostra é considerada outlier se seu valor de T² ou Q ultrapassa um limite de confiança (geralmente 3 desvios padrão da média).
# - **Importante:** A remoção de outliers é feita **apenas no conjunto de calibração**. O conjunto de validação deve permanecer intacto para simular dados "reais" que o modelo encontrará no futuro.

# %%
def pca_outlier_removal(X, n_components=10, threshold=3):
    """Remove outliers usando PCA com estatísticas T² e Q."""
    # Padronizar dados
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Aplicar PCA
    pca = PCA(n_components=n_components)
    X_pca = pca.fit_transform(X_scaled)
    
    # Calcular estatística T² (Hotelling's T²)
    T2 = np.sum((X_pca / np.std(X_pca, axis=0)) ** 2, axis=1)
    
    # Calcular estatística Q (resíduos)
    X_reconstructed = pca.inverse_transform(X_pca)
    Q = np.sum((X_scaled - X_reconstructed) ** 2, axis=1)
    
    # Definir limites (média + threshold * desvio padrão)
    T2_limit = np.mean(T2) + threshold * np.std(T2)
    Q_limit = np.mean(Q) + threshold * np.std(Q)
    
    # Identificar outliers
    outliers_mask = (T2 > T2_limit) | (Q > Q_limit)
    
    # Retornamos a máscara de quem NÃO é outlier e o modelo PCA treinado
    return ~outliers_mask, pca, T2, Q, T2_limit, Q_limit

dados_pca = {}

#para todo o conjunto de dado e não separado em cal e val
for atributo in atributos:
    X_full = dados_completos[atributo]['X']
    y_full = dados_completos[atributo]['y']
    indices_orig_full = dados_completos[atributo]['indices_orig']
    
    # Chama a função de remoção de outliers espectrais
    keep_mask, pca_model, T2, Q, T2_limit, Q_limit = pca_outlier_removal(X_full)
    
    # Identifica e informa os outliers removidos
    outliers_indices = indices_orig_full[~keep_mask]
    print(f'{atributo}: {len(outliers_indices)} outliers espectrais removidos.')
    if len(outliers_indices) > 0:
        print(f'  Índices Originais Removidos: {outliers_indices}')
    
    # Filtra os dados
    X_clean = X_full[keep_mask]
    y_clean = y_full[keep_mask]
    indices_orig_clean = indices_orig_full[keep_mask]
    
    dados_pca[atributo] = {
        'X': X_clean,
        'y': y_clean,
        'indices_orig': indices_orig_clean,
        'pca_model': pca_model,
        'T2': T2,
        'Q': Q,
        'T2_limit': T2_limit,
        'Q_limit': Q_limit,
        'keep_mask': keep_mask
    }
    
    print(f'  Dataset final: {X_clean.shape[0]} amostras')
    print()
# Out:
# N (g/kg): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [43 62 63]
#   Dataset final: 73 amostras
#
# P (g/kg): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [43 62 63]
#   Dataset final: 73 amostras
#
# K (g/kg): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [43 62 63]
#   Dataset final: 73 amostras
#
# Ca (g/kg): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [43 62 63]
#   Dataset final: 73 amostras
#
# Mg (g/kg): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [43 62 63]
#   Dataset final: 73 amostras
#
# S (g/kg): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [43 62 63]
#   Dataset final: 73 amostras
#
# B (mg/kg): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [43 62 63]
#   Dataset final: 73 amostras
#
# Fe (mg/kg): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [43 62 63]
#   Dataset final: 73 amostras
#
# Mn (mg/kg): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [43 62 63]
#   Dataset final: 73 amostras
#
# Zn (mg/kg): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [43 62 63]
#   Dataset final: 73 amostras
#
# Mo : 3 outliers espectrais removidos.
#   Índices Originais Removidos: [43 62 63]
#   Dataset final: 73 amostras

# %% [markdown]
# ### 4.1 Gráficos de Outliers T² e Q

# %%
# Plotagem dos gráficos de outliers PCA
for atributo in atributos:
    d = dados_pca[atributo]
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    
    # Gráfico 1: Variância explicada cumulativa
    # Acessa o modelo PCA com a chave correta 'pca_model'

    cumulative_variance = np.cumsum(d['pca_model'].explained_variance_ratio_)
    axes[0].plot(range(1, len(cumulative_variance) + 1), cumulative_variance, 'o-', linewidth=2, markersize=6)
    axes[0].set_xlabel('Número de Componentes Principais')
    axes[0].set_ylabel('Variância Explicada Cumulativa')
    axes[0].set_title(f'Variância Explicada - {atributo}')
    axes[0].grid(True, alpha=0.3)
    axes[0].axhline(y=0.95, color='r', linestyle='--', alpha=0.7, label='95%')
    axes[0].legend()
    
    # Gráfico 2: T² vs Q (detecção de outliers)
    # Acessa as variáveis T2, Q, T2_limit, Q_limit e keep_mask com as chaves corretas
    scatter = axes[1].scatter(d['T2'], d['Q'], c=d['keep_mask'], cmap='coolwarm', 
                              edgecolor='k', alpha=0.7, s=50)
    axes[1].axhline(d['Q_limit'], color='r', linestyle='--', linewidth=2, label=f'Q Limit: {d["Q_limit"]:.2f}')
    axes[1].axvline(d['T2_limit'], color='g', linestyle='--', linewidth=2, label=f'T² Limit: {d["T2_limit"]:.2f}')
    axes[1].set_xlabel("Hotelling's T²")
    axes[1].set_ylabel('Q Residual')
    axes[1].set_title(f'Detecção de Outliers - {atributo}')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    
    # Adicionar legenda de cores
    legend1 = axes[1].legend(*scatter.legend_elements(), title="Status")
    axes[1].add_artist(legend1)
    
    plt.tight_layout()
    
    # Salvar gráfico
    nome_arquivo = f'graficos_outliers_pca/pca_outliers_{atributo.replace(" ", "_").replace("(", "").replace(")", "").replace("/", "_")}.png'
    plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f'Gráficos de outliers PCA para {atributo} salvos em: {nome_arquivo}')
    print()
# Out:
# Gráficos de outliers PCA para N (g/kg) salvos em: graficos_outliers_pca/pca_outliers_N_g_kg.png
# Gráficos de outliers PCA para P (g/kg) salvos em: graficos_outliers_pca/pca_outliers_P_g_kg.png
# Gráficos de outliers PCA para K (g/kg) salvos em: graficos_outliers_pca/pca_outliers_K_g_kg.png
# Gráficos de outliers PCA para Ca (g/kg) salvos em: graficos_outliers_pca/pca_outliers_Ca_g_kg.png
# Gráficos de outliers PCA para Mg (g/kg) salvos em: graficos_outliers_pca/pca_outliers_Mg_g_kg.png
# Gráficos de outliers PCA para S (g/kg) salvos em: graficos_outliers_pca/pca_outliers_S_g_kg.png
# Gráficos de outliers PCA para B (mg/kg) salvos em: graficos_outliers_pca/pca_outliers_B_mg_kg.png
# Gráficos de outliers PCA para Fe (mg/kg) salvos em: graficos_outliers_pca/pca_outliers_Fe_mg_kg.png
# Gráficos de outliers PCA para Mn (mg/kg) salvos em: graficos_outliers_pca/pca_outliers_Mn_mg_kg.png
# Gráficos de outliers PCA para Zn (mg/kg) salvos em: graficos_outliers_pca/pca_outliers_Zn_mg_kg.png
# Gráficos de outliers PCA para Mo  salvos em: graficos_outliers_pca/pca_outliers_Mo_.png

# %% [markdown]
# ## 5. Remoção de Outliers dos Atributos (Boxplot + Seaborn)

# %% [markdown]
# Além dos outliers espectrais (em X), podemos ter outliers nos valores de referência (em y). Por exemplo, um valor de pH ou SST que é analiticamente improvável ou resultado de um erro de anotação.
# - **Método (IQR):** O método do Intervalo Interquartil (IQR) é uma forma estatística robusta de identificar esses pontos.
#     - `IQR = Q3 (percentil 75) - Q1 (percentil 25)`
#     - Um valor é considerado outlier se estiver abaixo de `Q1 - 1.5 * IQR` ou acima de `Q3 + 1.5 * IQR`.
# - **Visualização:** O `boxplot` é a ferramenta visual perfeita para essa análise, pois ele desenha os "bigodes" exatamente nesses limites de 1.5 * IQR, mostrando os outliers como pontos individuais.
# - **Ação:** Novamente, a remoção é feita apenas no conjunto de calibração.

# %%
# Remover outliers dos atributos usando boxplot e IQR

dados_final = {}

for atributo in atributos:
    # Pega os dados já limpos de outliers espectrais
    d = dados_pca[atributo]
    X_clean = d['X']
    y_clean = d['y']
    indices_orig_clean = d['indices_orig']
    
    # Boxplot
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=y_clean)
    sns.stripplot(x=y_clean, color='red', alpha=0.6)
    plt.title(f'Boxplot com Dispersão - {atributo}')
    
    nome_arquivo = f'graficos_outliers_boxplot/boxplot_outliers_{atributo.replace(" ", "_").replace("(", "").replace(")", "").replace("/", "_")}.png'
    plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
    plt.show()

    # Lógica de remoção de outliers dos atributos
    Q1 = np.percentile(y_clean, 25)
    Q3 = np.percentile(y_clean, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    keep_mask_attr = (y_clean >= lower_bound) & (y_clean <= upper_bound)
    
    # Identifica e informa os outliers removidos
    outliers_attr_indices = indices_orig_clean[~keep_mask_attr]
    print(f'{atributo}: {len(outliers_attr_indices)} outliers de atributo removidos.')
    if len(outliers_attr_indices) > 0:
        print(f'  Índices Originais Removidos: {outliers_attr_indices}')
    
    # Armazena os dados finais e limpos para modelagem
    dados_final[atributo] = {
        'X': X_clean[keep_mask_attr],
        'y': y_clean[keep_mask_attr]
    }
    
    print(f'  Dataset final para modelagem: {dados_final[atributo]["X"].shape[0]} amostras')
    print()

print("Remoção de outliers concluída!")
# Out:
# N (g/kg): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 73 amostras
# P (g/kg): 1 outliers de atributo removidos.
#   Índices Originais Removidos: [32]
#   Dataset final para modelagem: 72 amostras
# K (g/kg): 1 outliers de atributo removidos.
#   Índices Originais Removidos: [31]
#   Dataset final para modelagem: 72 amostras
# Ca (g/kg): 1 outliers de atributo removidos.
#   Índices Originais Removidos: [32]
#   Dataset final para modelagem: 72 amostras
# Mg (g/kg): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 73 amostras
# S (g/kg): 1 outliers de atributo removidos.
#   Índices Originais Removidos: [32]
#   Dataset final para modelagem: 72 amostras
# B (mg/kg): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 73 amostras
# Fe (mg/kg): 1 outliers de atributo removidos.
#   Índices Originais Removidos: [35]
#   Dataset final para modelagem: 72 amostras
# Mn (mg/kg): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 73 amostras
# Zn (mg/kg): 4 outliers de atributo removidos.
#   Índices Originais Removidos: [31 32 33 38]
#   Dataset final para modelagem: 69 amostras
# Mo : 0 outliers de atributo removidos.
#   Dataset final para modelagem: 73 amostras
#
# Remoção de outliers concluída!

# %%
# --- Função para o Gráfico de CALIBRAÇÃO (Ref vs Predito vs CV) ---
def save_calibration_plot(y_cal, y_pred_cal, y_pred_cv, atributo, filtro, modelo, file_path):
    """
    Gera e salva um gráfico comparando predições de treino e de validação cruzada
    no conjunto de calibração.
    """
    try:
        # Garante que o diretório exista
        os.makedirs(os.path.dirname(file_path), exist_ok=True)

        # Métricas para Predição no Treino Completo
        slope_pred, offset_pred = np.polyfit(y_cal, y_pred_cal, 1)
        rmse_pred = np.sqrt(mean_squared_error(y_cal, y_pred_cal))
        r2_pred = r2_score(y_cal, y_pred_cal)

        # Métricas para Predição da Validação Cruzada
        slope_cv, offset_cv = np.polyfit(y_cal, y_pred_cv, 1)
        rmse_cv = np.sqrt(mean_squared_error(y_cal, y_pred_cv))
        r2_cv = r2_score(y_cal, y_pred_cv)

        plt.figure(figsize=(10, 8))
        plt.scatter(y_cal, y_pred_cal, color='blue', marker='o', alpha=0.6, label=f'Predição no Treino (R²={r2_pred:.3f})')
        plt.scatter(y_cal, y_pred_cv, color='red', marker='x', alpha=0.7, label=f'Predição CV (R²={r2_cv:.3f})')
        
        # Linha ideal 1:1
        min_val = min(min(y_cal), min(y_pred_cal), min(y_pred_cv))
        max_val = max(max(y_cal), max(y_pred_cal), max(y_pred_cv))
        plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='Linha Ideal (1:1)')

        plt.xlabel("Valores Reais (Calibração)")
        plt.ylabel("Valores Preditos")
        plt.title(f'Desempenho na Calibração: {atributo} | {modelo} | {filtro}')
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.legend(loc='lower right')
        
        # Adiciona texto com métricas
        stats_text = (
            f'Treino - RMSE: {rmse_pred:.3f}, Slope: {slope_pred:.3f}, Offset: {offset_pred:.3f}\n'
            f'CV     - RMSE: {rmse_cv:.3f}, Slope: {slope_cv:.3f}, Offset: {offset_cv:.3f}'
        )
        plt.text(0.05, 0.95, stats_text, transform=plt.gca().transAxes, fontsize=10,
                 verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5))

        plt.savefig(file_path, format='png', dpi=200, bbox_inches='tight')
        plt.close()

    except Exception as e:
        print(f"Erro ao gerar gráfico de calibração para {modelo} com {filtro}: {e}")
        plt.close()


# --- Função para o Gráfico de VALIDAÇÃO (Predito vs Real) ---
def save_validation_plot(y_val, y_pred_val, atributo, filtro, modelo, file_path):
    """
    Gera e salva o gráfico de predições no conjunto de validação (teste).
    """
    try:
        # Garante que o diretório exista
        os.makedirs(os.path.dirname(file_path), exist_ok=True)
        
        # Métricas
        r2 = r2_score(y_val, y_pred_val)
        rmse = np.sqrt(mean_squared_error(y_val, y_pred_val))
        slope, offset = np.polyfit(y_val, y_pred_val, 1)

        plt.figure(figsize=(8, 8))
        plt.scatter(y_val, y_pred_val, alpha=0.7, edgecolors='k', label='Dados de Validação')
        
        # Linha ideal 1:1
        min_val = min(min(y_val), min(y_pred_val))
        max_val = max(max(y_val), max(y_pred_val))
        plt.plot([min_val, max_val], [min_val, max_val], 'r--', lw=2, label='Linha Ideal (1:1)')

        plt.xlabel('Valores Reais (Validação)')
        plt.ylabel('Valores Preditos')
        plt.title(f'Desempenho na Validação: {atributo} | {modelo} | {filtro}')
        plt.grid(True, linestyle='--', alpha=0.6)
        
        stats_text = f'R² = {r2:.4f}\nRMSE = {rmse:.4f}\nSlope = {slope:.4f}'
        plt.text(0.05, 0.95, stats_text, transform=plt.gca().transAxes, fontsize=12,
                 verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='lightblue', alpha=0.5))
        
        plt.legend()
        plt.savefig(file_path, format='png', dpi=200, bbox_inches='tight')
        plt.close()

    except Exception as e:
        print(f"Erro ao gerar gráfico de validação para {modelo} com {filtro}: {e}")
        plt.close()

# %% [markdown]
# ## 6. Avaliação dos Filtros e Seleção dos Melhores Modelos com Validação Cruzada

# %% [markdown]
# Nesta etapa crucial, construímos e avaliamos os modelos de regressão. Em vez de testar cada modelo separadamente, criamos um fluxo automatizado e exaustivo para garantir que encontremos a melhor performance possível.
# - **Estratégia:**
#     1. **Iteração por Atributo:** Um loop externo passa por cada variável alvo (AT, PH, etc.).
#     2. **Iteração por Modelo:** Para cada atributo, testamos uma lista de modelos quimiométricos:
#         - `PLSR`: Padrão da área, lida bem com multicolinearidade.
#         - `PCR`: Alternativa que primeiro reduz a dimensionalidade.
#         - `RFR` (Random Forest): Modelo não-linear, robusto e poderoso.
#         - `SVMR` (Support Vector Machine): Eficaz em espaços de alta dimensão.
#     3. **Iteração por Filtro:** Para cada modelo, aplicamos **todos os 16 filtros** de pré-processamento definidos na seção anterior.
#     4. **Otimização (GridSearchCV):** Para cada combinação `(atributo, modelo, filtro)`, usamos `GridSearchCV` com validação cruzada (10-fold) para encontrar os melhores hiperparâmetros do modelo (ex: número de componentes para PLS, parâmetros C e gamma para SVM).
# - **Avaliação:** O desempenho de cada combinação é medido pelo R² da validação cruzada. O melhor modelo é então treinado com todos os dados de calibração e sua performance final é avaliada no conjunto de validação, que foi mantido separado durante todo o processo.
# - **Saídas:** Ao final, teremos os resultados de centenas de modelos, permitindo uma comparação justa e a seleção do campeão para cada atributo. Todos os gráficos de predição e as métricas são salvos automaticamente.

# %%
def save_calibration_plot_cv(y_true, y_pred_cv, atributo, filtro, modelo, file_path):
 
    try:
        # Garante que o diretório exista
        os.makedirs(os.path.dirname(file_path), exist_ok=True)

        # Métricas para Predição da Validação Cruzada
        slope_cv, offset_cv = np.polyfit(y_true, y_pred_cv, 1)
        rmse_cv = np.sqrt(mean_squared_error(y_true, y_pred_cv))
        r2_cv = r2_score(y_true, y_pred_cv)

        plt.figure(figsize=(10, 8))
        plt.scatter(y_true, y_pred_cv, color='blue', marker='o', alpha=0.7, label=f'Cross-Validation (R²={r2_cv:.3f})')
        
        # Linha ideal 1:1
        min_val = min(min(y_true), min(y_pred_cv))
        max_val = max(max(y_true), max(y_pred_cv))
        plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='Linha Ideal (1:1)')

        plt.xlabel("Valores Reais")
        plt.ylabel("Valores Preditos (CV)")
        plt.title(f'Cross-Validation: {atributo} | {modelo} | {filtro}')
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.legend(loc='lower right')
        
        # Adiciona texto com métricas
        stats_text = f'CV - R²: {r2_cv:.3f}, RMSE: {rmse_cv:.3f}, Slope: {slope_cv:.3f}, Offset: {offset_cv:.3f}'
        plt.text(0.05, 0.95, stats_text, transform=plt.gca().transAxes, fontsize=10,
                 verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5))

        plt.savefig(file_path, format='png', dpi=200, bbox_inches='tight')
        plt.close()

    except Exception as e:
        print(f"Erro ao gerar gráfico de CV para {modelo} com {filtro}: {e}")
        plt.close()

# %% [markdown]
# ### 6.1 Modelos e Grids de Parâmetros

# %%
import re


modelos = {
    'PLSR': {
        'estimador': PLSRegression(),
        'params': {'n_components': [5, 10, 15, 20]}
    },
    'PCR': {
        'estimador': Pipeline([('pca', PCA()), ('regressor', LinearRegression())]),
        'params': {'pca__n_components': [5, 10, 15, 20]}
    },
        'SVMR': {
        'estimador': SVR(),
        'params': {
            'C': [0.1, 1, 10, 100],
            'gamma': ['scale', 'auto', 0.001, 0.01, 0.1],
            'kernel': ['rbf', 'linear'],
            'epsilon': [0.1, 0.2, 0.5, 1.0]
        }
    },
     'RFR': {
        'estimador': RandomForestRegressor(random_state=42),
        'params': {
            'n_estimators': [100, 150, 200, 250, 300],
            'max_depth': [10, 20, 30, None],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 4],
            'warm_start': [True, False],
            'bootstrap': [True, False]
        }
     }

}

# Combina todos os filtros
todos_filtros = {**filtros_independentes, **filtros_dependentes}

# Lista para armazenar todos os resultados
lista_resultados_finais = []

#AQUI COMEÇA O CROSS VALIDATION -- PRINCIPAIS ALTERAÇÕES DO CÓDIGO DE ANDRESSA

cv_folds = 10  # Número de folds para cross-validation
kf = KFold(n_splits=cv_folds, shuffle=True, random_state=42)

for atributo in atributos: 
    print(f'\n{"="*30}')
    print(f'INICIANDO MODELAGEM PARA: {atributo}')
    print(f'{"="*30}')

    melhor_r2_atributo = -999  # Inicia com um valor muito baixo
    melhor_combinacao_info = {}  # Dicionário para guardar as infos do melhor
    
    # Dicionário para armazenar as 5 melhores combinações por modelo
    melhores_por_modelo = {nome: [] for nome in modelos.keys()}

    dados = dados_final[atributo]
    X_full, y_full = dados['X'], dados['y']

    for nome_modelo, info_modelo in modelos.items():
        print(f'\n--- Modelo: {nome_modelo} ---')
        
        combinacoes_deste_modelo = [] # Lista temporária para este modelo

        for nome_filtro, funcao_filtro in todos_filtros.items():
            start_time = time.time()
            print(f'  Testando filtro: {nome_filtro}...', end='')

            if nome_filtro in filtros_independentes:
                X_filtered = funcao_filtro(X_full)
                tipo_filtro = 'independente'
            else:  # Filtro dependente de Y
                X_filtered = funcao_filtro(X_full, y_full)
                tipo_filtro = 'dependente'
            
            grid = GridSearchCV(
                info_modelo['estimador'], 
                info_modelo['params'], 
                cv=kf,  # Usa o mesmo KFold para consistência
                scoring='r2', 
                n_jobs=-1
            )
            grid.fit(X_filtered, y_full)
            
            melhor_modelo = grid.best_estimator_
            
            cv_scores = cross_val_score(melhor_modelo, X_filtered, y_full, cv=kf, scoring='r2')
            cv_r2_mean = cv_scores.mean()
            cv_r2_std = cv_scores.std()
            
            # Predições de cross-validation para plotagem
            y_pred_cv = cross_val_predict(melhor_modelo, X_filtered, y_full, cv=kf)
            cv_rmse = np.sqrt(mean_squared_error(y_full, y_pred_cv))
            
            end_time = time.time()
            print(f' CV R²: {cv_r2_mean:.4f} (±{cv_r2_std:.4f}) | Concluído em {end_time - start_time:.2f}s')

            # Salvar o resultado da combinação atual
            resultados_atuais = {
                'Atributo': atributo,
                'Modelo': nome_modelo,
                'Filtro': nome_filtro,
                'Tipo_Filtro': tipo_filtro,
                'CV_R2_Mean': cv_r2_mean,
                'CV_R2_Std': cv_r2_std,
                'CV_RMSE': cv_rmse,
                'Grid_Best_Score': grid.best_score_,
                'Melhores_Params': str(grid.best_params_),
                'Tempo_s': end_time - start_time,
                'objeto_modelo': melhor_modelo 
            }
            
            lista_resultados_finais.append(resultados_atuais)
            combinacoes_deste_modelo.append(resultados_atuais)

            # Lógica para salvar o melhor modelo geral
            if cv_r2_mean > melhor_r2_atributo:
                melhor_r2_atributo = cv_r2_mean
                melhor_combinacao_info = {
                    'objeto_modelo': melhor_modelo,
                    'nome_modelo': nome_modelo,
                    'nome_filtro': nome_filtro,
                    'parametros': grid.best_params_
                }
            
            path_cv = f'graficos_modelos/cross_validation/{atributo}_{nome_modelo}_{nome_filtro}.png'
            os.makedirs('graficos_modelos/cross_validation', exist_ok=True)
            save_calibration_plot_cv(y_full, y_pred_cv, atributo, nome_filtro, nome_modelo, path_cv)

        # Ordenar e salvar as 5 melhores para este modelo
        combinacoes_deste_modelo.sort(key=lambda x: x['CV_R2_Mean'], reverse=True)
        melhores_por_modelo[nome_modelo] = combinacoes_deste_modelo[:5]
        atributo_limpo = re.sub(r"[ \/\[\]\(\)]", "_", atributo)
    if melhor_combinacao_info:  # Garante que encontrou pelo menos um modelo
        melhor_obj = melhor_combinacao_info['objeto_modelo']
        nome_arquivo_modelo = f"modelos_salvos/melhor_modelo_{atributo_limpo}.joblib"
        
        joblib.dump(melhor_obj, nome_arquivo_modelo)
        
        print(f"\n 🏆 MELHOR COMBINAÇÃO GERAL PARA '{atributo}' FOI SALVA!")
        print(f"   - Arquivo: {nome_arquivo_modelo}")
        print(f"   - Modelo: {melhor_combinacao_info['nome_modelo']}")
        print(f"   - Filtro: {melhor_combinacao_info['nome_filtro']}")
        print(f"   - Melhor R² CV: {melhor_r2_atributo:.4f}")
        print(f"   - Melhores Parâmetros: {melhor_combinacao_info['parametros']}")
    
    # Salvar os 5 melhores modelos para cada tipo
    print(f"\n--- Salvando os 5 melhores modelos para {atributo} ---")
    for nome_modelo, lista_combinacoes in melhores_por_modelo.items():
        for i, combinacao in enumerate(lista_combinacoes):
            nome_arquivo = f"modelos_salvos_top5/top_{i+1}_{atributo_limpo}_{combinacao['Modelo']}_{combinacao['Filtro']}.joblib"
            os.makedirs('modelos_salvos_top5', exist_ok=True)
            joblib.dump(combinacao['objeto_modelo'], nome_arquivo)
            print(f"  - Top {i+1} do modelo {nome_modelo} salvo em: {nome_arquivo}")

print('\n\n ✅ Modelagem exaustiva com Cross-Validation!')

df_completo = pd.DataFrame(lista_resultados_finais)
df_completo_ordenado = df_completo.sort_values(by=['Atributo', 'CV_R2_Mean'], ascending=[True, False])
df_completo_ordenado.to_excel('analise_completa_resultados_cv.xlsx', index=False)
print('  ✅Resultados salvos em "analise_completa_resultados_cv.xlsx"')

print("\n--- Melhores Resultados por Atributo (Cross-Validation) ---")
melhores_resultados = df_completo_ordenado.groupby('Atributo').first().reset_index()

# Arredondar colunas numéricas para melhor visualização
colunas_numericas_para_arredondar = ['CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE', 'Grid_Best_Score']
melhores_resultados[colunas_numericas_para_arredondar] = melhores_resultados[colunas_numericas_para_arredondar].round(4)

# Selecionar e exibir as colunas mais importantes
colunas_para_exibir = ['Atributo', 'Modelo', 'Filtro', 'CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE', 'Melhores_Params']
print(melhores_resultados[colunas_para_exibir].to_string(index=False))
# Out:
# ==============================
# INICIANDO MODELAGEM PARA: N (g/kg)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.4845 (±0.2295) | Concluído em 1.76s
#   Testando filtro: MSC... CV R²: 0.4329 (±0.3306) | Concluído em 0.31s
#   Testando filtro: SNV... CV R²: 0.4987 (±0.2628) | Concluído em 0.31s
#   Testando filtro: SG_D1... CV R²: 0.5221 (±0.2456) | Concluído em 0.26s
#   Testando filtro: SG_D2... CV R²: 0.5897 (±0.2179) | Concluído em 0.27s
#   Testando filtro: Detrend... CV R²: 0.4374 (±0.2480) | Concluído em 0.29s
#   Testando filtro: Normalize... CV R²: 0.3429 (±0.3753) | Concluído em 0.30s
#   Testando filtro: EMSC... CV R²: 0.4329 (±0.3306) | Concluído em 0.31s
#   Testando filtro: Continuum_Removal... CV R²: 0.3938 (±0.2062) | Concluído em 0.43s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.4845 (±0.2296) | Concluído em 0.27s
#   Testando filtro: OSC_1... CV R²: 0.3919 (±0.2016) | Concluído em 0.31s
#   Testando filtro: OSC_2... CV R²: 0.3591 (±0.2094) | Concluído em 0.31s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.5411 (±0.2074) | Concluído em 0.27s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.5372 (±0.2083) | Concluído em 0.27s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.6504 (±0.1749) | Concluído em 0.40s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.5834 (±0.2078) | Concluído em 0.39s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.4692 (±0.2545) | Concluído em 0.31s
#   Testando filtro: MSC... CV R²: 0.4771 (±0.2745) | Concluído em 0.27s
#   Testando filtro: SNV... CV R²: 0.4817 (±0.2725) | Concluído em 0.26s
#   Testando filtro: SG_D1... CV R²: 0.4584 (±0.3528) | Concluído em 0.27s
#   Testando filtro: SG_D2... CV R²: 0.5619 (±0.2225) | Concluído em 0.27s
#   Testando filtro: Detrend... CV R²: 0.4558 (±0.2400) | Concluído em 0.28s
#   Testando filtro: Normalize... CV R²: 0.4689 (±0.3096) | Concluído em 0.27s
#   Testando filtro: EMSC... CV R²: 0.4771 (±0.2745) | Concluído em 0.27s
#   Testando filtro: Continuum_Removal... CV R²: 0.4748 (±0.2148) | Concluído em 0.44s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.4692 (±0.2545) | Concluído em 0.25s
#   Testando filtro: OSC_1... CV R²: 0.4553 (±0.1819) | Concluído em 0.28s
#   Testando filtro: OSC_2... CV R²: 0.4577 (±0.1674) | Concluído em 0.28s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.4606 (±0.3296) | Concluído em 0.27s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.4608 (±0.3290) | Concluído em 0.27s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.5041 (±0.2351) | Concluído em 0.26s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.4427 (±0.3458) | Concluído em 0.27s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.5122 (±0.2692) | Concluído em 0.59s
#   Testando filtro: MSC... CV R²: 0.5460 (±0.2038) | Concluído em 0.56s
#   Testando filtro: SNV... CV R²: 0.5507 (±0.1942) | Concluído em 0.65s
#   Testando filtro: SG_D1... CV R²: 0.5158 (±0.2265) | Concluído em 0.57s
#   Testando filtro: SG_D2... CV R²: 0.5449 (±0.1819) | Concluído em 0.56s
#   Testando filtro: Detrend... CV R²: 0.5310 (±0.2025) | Concluído em 0.58s
#   Testando filtro: Normalize... CV R²: 0.5360 (±0.1923) | Concluído em 0.56s
#   Testando filtro: EMSC... CV R²: 0.5460 (±0.2038) | Concluído em 0.54s
#   Testando filtro: Continuum_Removal... CV R²: 0.4314 (±0.2044) | Concluído em 0.74s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.5127 (±0.2691) | Concluído em 0.60s
#   Testando filtro: OSC_1... CV R²: 0.4833 (±0.2580) | Concluído em 0.69s
#   Testando filtro: OSC_2... CV R²: 0.4969 (±0.2477) | Concluído em 0.57s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.4869 (±0.2571) | Concluído em 0.58s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.5131 (±0.2343) | Concluído em 0.57s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.5098 (±0.1932) | Concluído em 0.59s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.4859 (±0.2219) | Concluído em 0.57s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.3643 (±0.3053) | Concluído em 1557.79s
#   Testando filtro: MSC... CV R²: 0.2980 (±0.3276) | Concluído em 1690.22s
#   Testando filtro: SNV... CV R²: 0.3150 (±0.3260) | Concluído em 1714.27s
#   Testando filtro: SG_D1... CV R²: 0.5434 (±0.1873) | Concluído em 1649.00s
#   Testando filtro: SG_D2... CV R²: 0.5248 (±0.2591) | Concluído em 1544.81s
#   Testando filtro: Detrend... CV R²: 0.3253 (±0.3146) | Concluído em 1549.21s
#   Testando filtro: Normalize... CV R²: 0.3795 (±0.2858) | Concluído em 1689.91s
#   Testando filtro: EMSC... CV R²: 0.2980 (±0.3276) | Concluído em 1679.02s
#   Testando filtro: Continuum_Removal... CV R²: 0.5475 (±0.1619) | Concluído em 1577.15s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.3636 (±0.3096) | Concluído em 1532.89s
#   Testando filtro: OSC_1... CV R²: 0.2315 (±0.3524) | Concluído em 1595.07s
#   Testando filtro: OSC_2... CV R²: 0.3021 (±0.3311) | Concluído em 1635.81s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.4963 (±0.2494) | Concluído em 1536.73s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.4952 (±0.2718) | Concluído em 1537.10s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.6483 (±0.1623) | Concluído em 1520.73s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.6023 (±0.1848) | Concluído em 1545.77s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'N (g/kg)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_N__g_kg_.joblib
#    - Modelo: PLSR
#    - Filtro: OPLS2_SNV_SG_D1
#    - Melhor R² CV: 0.6504
#    - Melhores Parâmetros: {'n_components': 20}
#
# --- Salvando os 5 melhores modelos para N (g/kg) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_N__g_kg__PLSR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_N__g_kg__PLSR_SG_D2.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_N__g_kg__PLSR_SNV_Detrend_SG_D1.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_N__g_kg__PLSR_MSC_SG_OSC.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_N__g_kg__PLSR_OPLS1_SNV_SG_D1.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_N__g_kg__PCR_SG_D2.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_N__g_kg__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_N__g_kg__PCR_SNV.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_N__g_kg__PCR_EMSC.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_N__g_kg__PCR_MSC.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_N__g_kg__SVMR_SNV.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_N__g_kg__SVMR_MSC.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_N__g_kg__SVMR_EMSC.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_N__g_kg__SVMR_SG_D2.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_N__g_kg__SVMR_Normalize.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_N__g_kg__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_N__g_kg__RFR_SNV_Detrend_SG_D1.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_N__g_kg__RFR_Continuum_Removal.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_N__g_kg__RFR_SG_D1.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_N__g_kg__RFR_SG_D2.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: P (g/kg)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.1608 (±0.4222) | Concluído em 0.25s
#   Testando filtro: MSC... CV R²: 0.1357 (±0.4144) | Concluído em 0.27s
#   Testando filtro: SNV... CV R²: 0.1643 (±0.3827) | Concluído em 0.26s
#   Testando filtro: SG_D1... CV R²: -0.0294 (±0.6802) | Concluído em 0.27s
#   Testando filtro: SG_D2... CV R²: -0.0092 (±0.6616) | Concluído em 0.34s
#   Testando filtro: Detrend... CV R²: 0.2167 (±0.2936) | Concluído em 0.26s
#   Testando filtro: Normalize... CV R²: 0.2400 (±0.2702) | Concluído em 0.26s
#   Testando filtro: EMSC... CV R²: 0.1357 (±0.4144) | Concluído em 0.27s
#   Testando filtro: Continuum_Removal... CV R²: 0.1724 (±0.3326) | Concluído em 0.41s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.1608 (±0.4221) | Concluído em 0.26s
#   Testando filtro: OSC_1... CV R²: 0.2037 (±0.2949) | Concluído em 0.26s
#   Testando filtro: OSC_2... CV R²: 0.2064 (±0.4009) | Concluído em 0.27s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.0492 (±0.5982) | Concluído em 0.27s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.0483 (±0.5978) | Concluído em 0.26s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.0366 (±0.3598) | Concluído em 0.27s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.1025 (±0.5327) | Concluído em 0.26s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.1641 (±0.4354) | Concluído em 0.24s
#   Testando filtro: MSC... CV R²: 0.2648 (±0.2888) | Concluído em 0.27s
#   Testando filtro: SNV... CV R²: 0.2718 (±0.2799) | Concluído em 0.26s
#   Testando filtro: SG_D1... CV R²: 0.1617 (±0.3664) | Concluído em 0.25s
#   Testando filtro: SG_D2... CV R²: 0.1095 (±0.3384) | Concluído em 0.28s
#   Testando filtro: Detrend... CV R²: 0.2120 (±0.3797) | Concluído em 0.27s
#   Testando filtro: Normalize... CV R²: 0.2082 (±0.3737) | Concluído em 0.27s
#   Testando filtro: EMSC... CV R²: 0.2648 (±0.2888) | Concluído em 0.26s
#   Testando filtro: Continuum_Removal... CV R²: 0.1990 (±0.3237) | Concluído em 0.41s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.1642 (±0.4354) | Concluído em 0.25s
#   Testando filtro: OSC_1... CV R²: 0.1806 (±0.4496) | Concluído em 0.27s
#   Testando filtro: OSC_2... CV R²: 0.2465 (±0.2909) | Concluído em 0.25s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.1896 (±0.3146) | Concluído em 0.26s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.1894 (±0.3148) | Concluído em 0.25s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.2940 (±0.2390) | Concluído em 0.26s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.1761 (±0.2846) | Concluído em 0.25s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.2779 (±0.3097) | Concluído em 0.54s
#   Testando filtro: MSC... CV R²: 0.2871 (±0.2828) | Concluído em 0.51s
#   Testando filtro: SNV... CV R²: 0.3010 (±0.2737) | Concluído em 0.53s
#   Testando filtro: SG_D1... CV R²: 0.2397 (±0.3077) | Concluído em 0.51s
#   Testando filtro: SG_D2... CV R²: 0.1198 (±0.2204) | Concluído em 0.50s
#   Testando filtro: Detrend... CV R²: 0.2716 (±0.3054) | Concluído em 0.49s
#   Testando filtro: Normalize... CV R²: 0.2732 (±0.2864) | Concluído em 0.51s
#   Testando filtro: EMSC... CV R²: 0.2871 (±0.2828) | Concluído em 0.51s
#   Testando filtro: Continuum_Removal... CV R²: 0.2798 (±0.1918) | Concluído em 0.67s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.2775 (±0.3096) | Concluído em 0.54s
#   Testando filtro: OSC_1... CV R²: 0.3077 (±0.2849) | Concluído em 0.53s
#   Testando filtro: OSC_2... CV R²: 0.2807 (±0.2770) | Concluído em 0.54s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.1957 (±0.2576) | Concluído em 0.51s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.3017 (±0.2790) | Concluído em 0.51s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.3102 (±0.3114) | Concluído em 0.49s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.2851 (±0.2555) | Concluído em 0.52s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.0146 (±0.3096) | Concluído em 1552.72s
#   Testando filtro: MSC... CV R²: 0.1956 (±0.3526) | Concluído em 1569.93s
#   Testando filtro: SNV... CV R²: 0.1933 (±0.3487) | Concluído em 1551.59s
#   Testando filtro: SG_D1... CV R²: 0.1356 (±0.2799) | Concluído em 1633.24s
#   Testando filtro: SG_D2... CV R²: 0.2245 (±0.2376) | Concluído em 1528.07s
#   Testando filtro: Detrend... CV R²: 0.2292 (±0.2291) | Concluído em 1616.89s
#   Testando filtro: Normalize... CV R²: 0.2207 (±0.3528) | Concluído em 1539.79s
#   Testando filtro: EMSC... CV R²: 0.1956 (±0.3526) | Concluído em 1568.52s
#   Testando filtro: Continuum_Removal... CV R²: 0.0553 (±0.2343) | Concluído em 1558.76s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.0107 (±0.3156) | Concluído em 1557.80s
#   Testando filtro: OSC_1... CV R²: 0.1570 (±0.4331) | Concluído em 1502.87s
#   Testando filtro: OSC_2... CV R²: 0.1218 (±0.3198) | Concluído em 1553.03s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.0747 (±0.3865) | Concluído em 1761.06s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2078 (±0.4989) | Concluído em 1764.15s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.1995 (±0.3925) | Concluído em 1643.31s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.2041 (±0.2525) | Concluído em 1574.32s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'P (g/kg)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_P__g_kg_.joblib
#    - Modelo: SVMR
#    - Filtro: OPLS2_SNV_SG_D1
#    - Melhor R² CV: 0.3102
#    - Melhores Parâmetros: {'C': 100, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#
# --- Salvando os 5 melhores modelos para P (g/kg) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_P__g_kg__PLSR_Normalize.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_P__g_kg__PLSR_Detrend.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_P__g_kg__PLSR_OSC_2.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_P__g_kg__PLSR_OSC_1.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_P__g_kg__PLSR_Continuum_Removal.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_P__g_kg__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_P__g_kg__PCR_SNV.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_P__g_kg__PCR_EMSC.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_P__g_kg__PCR_MSC.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_P__g_kg__PCR_OSC_2.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_P__g_kg__SVMR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_P__g_kg__SVMR_OSC_1.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_P__g_kg__SVMR_OPLS1_SNV_SG_D1.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_P__g_kg__SVMR_SNV.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_P__g_kg__SVMR_MSC.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_P__g_kg__RFR_Detrend.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_P__g_kg__RFR_SG_D2.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_P__g_kg__RFR_Normalize.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_P__g_kg__RFR_OPLS1_SNV_SG_D1.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_P__g_kg__RFR_SNV_Detrend_SG_D1.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: K (g/kg)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.1893 (±0.3816) | Concluído em 0.30s
#   Testando filtro: MSC... CV R²: 0.0552 (±0.4048) | Concluído em 0.27s
#   Testando filtro: SNV... CV R²: 0.0425 (±0.3988) | Concluído em 0.26s
#   Testando filtro: SG_D1... CV R²: 0.1231 (±0.4407) | Concluído em 0.27s
#   Testando filtro: SG_D2... CV R²: 0.0648 (±0.3743) | Concluído em 0.30s
#   Testando filtro: Detrend... CV R²: 0.1149 (±0.4789) | Concluído em 0.30s
#   Testando filtro: Normalize... CV R²: 0.0801 (±0.3615) | Concluído em 0.33s
#   Testando filtro: EMSC... CV R²: 0.0552 (±0.4048) | Concluído em 0.27s
#   Testando filtro: Continuum_Removal... CV R²: 0.3221 (±0.2565) | Concluído em 0.40s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.1897 (±0.3814) | Concluído em 0.29s
#   Testando filtro: OSC_1... CV R²: 0.1513 (±0.3914) | Concluído em 0.29s
#   Testando filtro: OSC_2... CV R²: -0.0011 (±0.3329) | Concluído em 0.27s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.2646 (±0.4023) | Concluído em 0.26s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2618 (±0.4112) | Concluído em 0.26s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.1676 (±0.4205) | Concluído em 0.25s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.0720 (±0.4289) | Concluído em 0.26s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.2451 (±0.3022) | Concluído em 0.26s
#   Testando filtro: MSC... CV R²: 0.1349 (±0.3567) | Concluído em 0.27s
#   Testando filtro: SNV... CV R²: 0.1190 (±0.3960) | Concluído em 0.27s
#   Testando filtro: SG_D1... CV R²: 0.2387 (±0.4401) | Concluído em 0.25s
#   Testando filtro: SG_D2... CV R²: 0.2202 (±0.2147) | Concluído em 0.26s
#   Testando filtro: Detrend... CV R²: 0.1575 (±0.2711) | Concluído em 0.26s
#   Testando filtro: Normalize... CV R²: 0.1214 (±0.5884) | Concluído em 0.44s
#   Testando filtro: EMSC... CV R²: 0.1349 (±0.3567) | Concluído em 0.26s
#   Testando filtro: Continuum_Removal... CV R²: 0.2838 (±0.4170) | Concluído em 0.46s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.2440 (±0.3032) | Concluído em 0.27s
#   Testando filtro: OSC_1... CV R²: 0.2558 (±0.2689) | Concluído em 0.28s
#   Testando filtro: OSC_2... CV R²: 0.0557 (±0.2633) | Concluído em 0.27s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.2975 (±0.4145) | Concluído em 0.25s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2960 (±0.4171) | Concluído em 0.25s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.3066 (±0.4539) | Concluído em 0.26s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.2682 (±0.3696) | Concluído em 0.26s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.2889 (±0.3341) | Concluído em 0.77s
#   Testando filtro: MSC... CV R²: 0.2663 (±0.4020) | Concluído em 0.62s
#   Testando filtro: SNV... CV R²: 0.2745 (±0.3824) | Concluído em 0.67s
#   Testando filtro: SG_D1... CV R²: 0.2719 (±0.3253) | Concluído em 0.58s
#   Testando filtro: SG_D2... CV R²: 0.3440 (±0.2978) | Concluído em 0.59s
#   Testando filtro: Detrend... CV R²: 0.2759 (±0.3320) | Concluído em 0.65s
#   Testando filtro: Normalize... CV R²: 0.2878 (±0.4300) | Concluído em 0.61s
#   Testando filtro: EMSC... CV R²: 0.2663 (±0.4020) | Concluído em 0.62s
#   Testando filtro: Continuum_Removal... CV R²: 0.3867 (±0.3055) | Concluído em 0.77s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.2802 (±0.3350) | Concluído em 0.76s
#   Testando filtro: OSC_1... CV R²: 0.3024 (±0.3264) | Concluído em 1.46s
#   Testando filtro: OSC_2... CV R²: 0.0593 (±0.2402) | Concluído em 1.05s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.2682 (±0.3435) | Concluído em 0.58s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2854 (±0.3359) | Concluído em 0.59s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.3039 (±0.4445) | Concluído em 0.59s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.2897 (±0.3097) | Concluído em 0.60s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: -0.0739 (±0.4948) | Concluído em 1594.63s
#   Testando filtro: MSC... CV R²: -0.0612 (±0.4630) | Concluído em 1751.13s
#   Testando filtro: SNV... CV R²: -0.0516 (±0.4971) | Concluído em 1802.49s
#   Testando filtro: SG_D1... CV R²: 0.1693 (±0.3585) | Concluído em 1697.04s
#   Testando filtro: SG_D2... CV R²: 0.1959 (±0.1772) | Concluído em 1677.54s
#   Testando filtro: Detrend... CV R²: 0.0572 (±0.3502) | Concluído em 1601.65s
#   Testando filtro: Normalize... CV R²: 0.0486 (±0.4205) | Concluído em 2008.79s
#   Testando filtro: EMSC... CV R²: -0.0612 (±0.4630) | Concluído em 1747.05s
#   Testando filtro: Continuum_Removal... CV R²: 0.2329 (±0.3011) | Concluído em 2041.77s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.0778 (±0.5147) | Concluído em 3015.41s
#   Testando filtro: OSC_1... CV R²: -0.2252 (±0.5190) | Concluído em 3347.18s
#   Testando filtro: OSC_2... CV R²: -0.1325 (±0.3411) | Concluído em 3222.94s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.3016 (±0.2684) | Concluído em 3164.72s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2909 (±0.2595) | Concluído em 3373.74s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.3308 (±0.2756) | Concluído em 3323.33s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.2537 (±0.3371) | Concluído em 3188.18s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'K (g/kg)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_K__g_kg_.joblib
#    - Modelo: SVMR
#    - Filtro: Continuum_Removal
#    - Melhor R² CV: 0.3867
#    - Melhores Parâmetros: {'C': 100, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#
# --- Salvando os 5 melhores modelos para K (g/kg) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_K__g_kg__PLSR_Continuum_Removal.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_K__g_kg__PLSR_MSC_SG_OSC.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_K__g_kg__PLSR_OPLS1_SNV_SG_D1.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_K__g_kg__PLSR_Wavelet_Denoising.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_K__g_kg__PLSR_Raw.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_K__g_kg__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_K__g_kg__PCR_MSC_SG_OSC.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_K__g_kg__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_K__g_kg__PCR_Continuum_Removal.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_K__g_kg__PCR_SNV_Detrend_SG_D1.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_K__g_kg__SVMR_Continuum_Removal.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_K__g_kg__SVMR_SG_D2.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_K__g_kg__SVMR_OPLS2_SNV_SG_D1.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_K__g_kg__SVMR_OSC_1.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_K__g_kg__SVMR_SNV_Detrend_SG_D1.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_K__g_kg__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_K__g_kg__RFR_MSC_SG_OSC.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_K__g_kg__RFR_OPLS1_SNV_SG_D1.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_K__g_kg__RFR_SNV_Detrend_SG_D1.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_K__g_kg__RFR_Continuum_Removal.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: Ca (g/kg)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.6568 (±0.2465) | Concluído em 0.35s
#   Testando filtro: MSC... CV R²: 0.7015 (±0.1562) | Concluído em 0.44s
#   Testando filtro: SNV... CV R²: 0.6962 (±0.1585) | Concluído em 0.42s
#   Testando filtro: SG_D1... CV R²: 0.5843 (±0.2426) | Concluído em 0.35s
#   Testando filtro: SG_D2... CV R²: 0.6500 (±0.2640) | Concluído em 0.35s
#   Testando filtro: Detrend... CV R²: 0.6964 (±0.1740) | Concluído em 0.44s
#   Testando filtro: Normalize... CV R²: 0.6324 (±0.1972) | Concluído em 0.41s
#   Testando filtro: EMSC... CV R²: 0.7015 (±0.1562) | Concluído em 0.44s
#   Testando filtro: Continuum_Removal... CV R²: 0.6429 (±0.1499) | Concluído em 0.60s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.6564 (±0.2479) | Concluído em 0.36s
#   Testando filtro: OSC_1... CV R²: 0.6838 (±0.1610) | Concluído em 0.42s
#   Testando filtro: OSC_2... CV R²: 0.6947 (±0.1656) | Concluído em 0.44s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.6185 (±0.2416) | Concluído em 0.44s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.6184 (±0.2376) | Concluído em 0.42s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.5249 (±0.2261) | Concluído em 0.36s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.5827 (±0.2236) | Concluído em 0.38s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.6832 (±0.1848) | Concluído em 0.64s
#   Testando filtro: MSC... CV R²: 0.6729 (±0.2654) | Concluído em 0.91s
#   Testando filtro: SNV... CV R²: 0.6683 (±0.2706) | Concluído em 0.87s
#   Testando filtro: SG_D1... CV R²: 0.6511 (±0.2446) | Concluído em 0.43s
#   Testando filtro: SG_D2... CV R²: 0.5749 (±0.2447) | Concluído em 0.56s
#   Testando filtro: Detrend... CV R²: 0.6773 (±0.1836) | Concluído em 0.54s
#   Testando filtro: Normalize... CV R²: 0.6686 (±0.2047) | Concluído em 0.50s
#   Testando filtro: EMSC... CV R²: 0.6729 (±0.2653) | Concluído em 0.86s
#   Testando filtro: Continuum_Removal... CV R²: 0.6591 (±0.1226) | Concluído em 0.84s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.6834 (±0.1847) | Concluído em 0.55s
#   Testando filtro: OSC_1... CV R²: 0.6860 (±0.2244) | Concluído em 0.81s
#   Testando filtro: OSC_2... CV R²: 0.6765 (±0.2005) | Concluído em 0.58s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.6770 (±0.1994) | Concluído em 0.50s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.6765 (±0.1996) | Concluído em 0.60s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.6604 (±0.1812) | Concluído em 0.44s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.6981 (±0.1960) | Concluído em 0.43s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.7042 (±0.2154) | Concluído em 1.14s
#   Testando filtro: MSC... CV R²: 0.7082 (±0.1812) | Concluído em 0.95s
#   Testando filtro: SNV... CV R²: 0.7035 (±0.1791) | Concluído em 1.03s
#   Testando filtro: SG_D1... CV R²: 0.6292 (±0.2805) | Concluído em 0.95s
#   Testando filtro: SG_D2... CV R²: 0.6299 (±0.2132) | Concluído em 0.95s
#   Testando filtro: Detrend... CV R²: 0.7172 (±0.1843) | Concluído em 1.02s
#   Testando filtro: Normalize... CV R²: 0.7105 (±0.1631) | Concluído em 1.00s
#   Testando filtro: EMSC... CV R²: 0.7082 (±0.1812) | Concluído em 1.00s
#   Testando filtro: Continuum_Removal... CV R²: 0.6314 (±0.1683) | Concluído em 1.19s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.7039 (±0.2131) | Concluído em 1.16s
#   Testando filtro: OSC_1... CV R²: 0.7221 (±0.1445) | Concluído em 1.43s
#   Testando filtro: OSC_2... CV R²: 0.6998 (±0.1635) | Concluído em 1.08s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.7050 (±0.1856) | Concluído em 0.94s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.7055 (±0.1852) | Concluído em 0.95s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.6669 (±0.2510) | Concluído em 0.96s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.5832 (±0.2756) | Concluído em 0.93s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.5614 (±0.5005) | Concluído em 2958.79s
#   Testando filtro: MSC... CV R²: 0.3770 (±0.4902) | Concluído em 2083.54s
#   Testando filtro: SNV... CV R²: 0.3772 (±0.4827) | Concluído em 1540.98s
#   Testando filtro: SG_D1... CV R²: 0.5877 (±0.3242) | Concluído em 1460.23s
#   Testando filtro: SG_D2... CV R²: 0.5402 (±0.3874) | Concluído em 1456.51s
#   Testando filtro: Detrend... CV R²: 0.5482 (±0.4330) | Concluído em 1464.77s
#   Testando filtro: Normalize... CV R²: 0.5805 (±0.2014) | Concluído em 1538.55s
#   Testando filtro: EMSC... CV R²: 0.3770 (±0.4902) | Concluído em 1622.52s
#   Testando filtro: Continuum_Removal... CV R²: 0.5170 (±0.4627) | Concluído em 1555.43s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.5658 (±0.4912) | Concluído em 1463.87s
#   Testando filtro: OSC_1... CV R²: 0.4590 (±0.3032) | Concluído em 1553.12s
#   Testando filtro: OSC_2... CV R²: 0.4545 (±0.2948) | Concluído em 1676.63s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.6005 (±0.2427) | Concluído em 1429.57s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.6005 (±0.2592) | Concluído em 1425.30s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.6242 (±0.2095) | Concluído em 1493.61s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.6796 (±0.1902) | Concluído em 1429.10s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Ca (g/kg)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Ca__g_kg_.joblib
#    - Modelo: SVMR
#    - Filtro: OSC_1
#    - Melhor R² CV: 0.7221
#    - Melhores Parâmetros: {'C': 100, 'epsilon': 1.0, 'gamma': 'scale', 'kernel': 'linear'}
#
# --- Salvando os 5 melhores modelos para Ca (g/kg) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Ca__g_kg__PLSR_MSC.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Ca__g_kg__PLSR_EMSC.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Ca__g_kg__PLSR_Detrend.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Ca__g_kg__PLSR_SNV.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Ca__g_kg__PLSR_OSC_2.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Ca__g_kg__PCR_SNV_Detrend_SG_D1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Ca__g_kg__PCR_OSC_1.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Ca__g_kg__PCR_Wavelet_Denoising.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Ca__g_kg__PCR_Raw.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Ca__g_kg__PCR_Detrend.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Ca__g_kg__SVMR_OSC_1.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Ca__g_kg__SVMR_Detrend.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Ca__g_kg__SVMR_Normalize.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Ca__g_kg__SVMR_EMSC.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Ca__g_kg__SVMR_MSC.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Ca__g_kg__RFR_SNV_Detrend_SG_D1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Ca__g_kg__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Ca__g_kg__RFR_MSC_SG_OSC.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Ca__g_kg__RFR_OPLS1_SNV_SG_D1.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Ca__g_kg__RFR_SG_D1.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: Mg (g/kg)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.3159 (±0.6546) | Concluído em 0.26s
#   Testando filtro: MSC... CV R²: 0.3265 (±0.7686) | Concluído em 0.27s
#   Testando filtro: SNV... CV R²: 0.3458 (±0.6109) | Concluído em 0.30s
#   Testando filtro: SG_D1... CV R²: 0.1238 (±0.8701) | Concluído em 0.26s
#   Testando filtro: SG_D2... CV R²: 0.1768 (±0.6287) | Concluído em 0.26s
#   Testando filtro: Detrend... CV R²: 0.2867 (±0.7506) | Concluído em 0.27s
#   Testando filtro: Normalize... CV R²: 0.3385 (±0.6237) | Concluído em 0.26s
#   Testando filtro: EMSC... CV R²: 0.3265 (±0.7686) | Concluído em 0.27s
#   Testando filtro: Continuum_Removal... CV R²: 0.2004 (±0.9073) | Concluído em 0.41s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.3159 (±0.6546) | Concluído em 0.26s
#   Testando filtro: OSC_1... CV R²: 0.3362 (±0.5405) | Concluído em 0.38s
#   Testando filtro: OSC_2... CV R²: 0.3225 (±0.5367) | Concluído em 0.40s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.1524 (±0.8052) | Concluído em 0.27s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.1534 (±0.8039) | Concluído em 0.27s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.0656 (±0.6881) | Concluído em 0.27s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.0640 (±0.9019) | Concluído em 0.26s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.2693 (±0.7951) | Concluído em 0.25s
#   Testando filtro: MSC... CV R²: 0.3259 (±0.7102) | Concluído em 0.26s
#   Testando filtro: SNV... CV R²: 0.3256 (±0.7093) | Concluído em 0.25s
#   Testando filtro: SG_D1... CV R²: 0.2659 (±0.6496) | Concluído em 0.25s
#   Testando filtro: SG_D2... CV R²: 0.2606 (±0.5264) | Concluído em 0.28s
#   Testando filtro: Detrend... CV R²: 0.3115 (±0.7430) | Concluído em 0.25s
#   Testando filtro: Normalize... CV R²: 0.3515 (±0.6452) | Concluído em 0.25s
#   Testando filtro: EMSC... CV R²: 0.3259 (±0.7102) | Concluído em 0.25s
#   Testando filtro: Continuum_Removal... CV R²: 0.2580 (±0.8301) | Concluído em 0.41s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.2690 (±0.7954) | Concluído em 0.26s
#   Testando filtro: OSC_1... CV R²: 0.2998 (±0.7830) | Concluído em 0.25s
#   Testando filtro: OSC_2... CV R²: 0.3414 (±0.7612) | Concluído em 0.26s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.2689 (±0.7133) | Concluído em 0.26s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2694 (±0.7131) | Concluído em 0.25s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.2434 (±0.5747) | Concluído em 0.25s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.2817 (±0.7003) | Concluído em 0.25s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.4036 (±0.5695) | Concluído em 0.64s
#   Testando filtro: MSC... CV R²: 0.4012 (±0.5768) | Concluído em 0.57s
#   Testando filtro: SNV... CV R²: 0.4125 (±0.5852) | Concluído em 0.72s
#   Testando filtro: SG_D1... CV R²: 0.3284 (±0.6080) | Concluído em 0.58s
#   Testando filtro: SG_D2... CV R²: 0.3235 (±0.5016) | Concluído em 0.58s
#   Testando filtro: Detrend... CV R²: 0.3859 (±0.6552) | Concluído em 0.58s
#   Testando filtro: Normalize... CV R²: 0.3755 (±0.6481) | Concluído em 0.59s
#   Testando filtro: EMSC... CV R²: 0.4012 (±0.5768) | Concluído em 0.59s
#   Testando filtro: Continuum_Removal... CV R²: 0.3674 (±0.7769) | Concluído em 0.73s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.4037 (±0.5694) | Concluído em 0.68s
#   Testando filtro: OSC_1... CV R²: 0.3586 (±0.5458) | Concluído em 0.56s
#   Testando filtro: OSC_2... CV R²: 0.3792 (±0.6585) | Concluído em 0.60s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.3813 (±0.6484) | Concluído em 0.58s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.3814 (±0.6484) | Concluído em 0.57s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.3613 (±0.5381) | Concluído em 0.59s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.3323 (±0.6430) | Concluído em 0.57s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.2713 (±0.5037) | Concluído em 1526.94s
#   Testando filtro: MSC... CV R²: 0.3718 (±0.5877) | Concluído em 1592.32s
#   Testando filtro: SNV... CV R²: 0.3600 (±0.5883) | Concluído em 1544.43s
#   Testando filtro: SG_D1... CV R²: 0.3055 (±0.6265) | Concluído em 1536.75s
#   Testando filtro: SG_D2... CV R²: 0.3331 (±0.5875) | Concluído em 1515.82s
#   Testando filtro: Detrend... CV R²: 0.3363 (±0.5792) | Concluído em 1584.02s
#   Testando filtro: Normalize... CV R²: 0.3249 (±0.6108) | Concluído em 1507.33s
#   Testando filtro: EMSC... CV R²: 0.3718 (±0.5877) | Concluído em 1592.98s
#   Testando filtro: Continuum_Removal... CV R²: 0.3713 (±0.5485) | Concluído em 1517.79s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.2708 (±0.4995) | Concluído em 1527.66s
#   Testando filtro: OSC_1... CV R²: 0.3285 (±0.5726) | Concluído em 1595.32s
#   Testando filtro: OSC_2... CV R²: 0.2608 (±0.6532) | Concluído em 1527.09s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.3497 (±0.6742) | Concluído em 1627.77s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.3479 (±0.6805) | Concluído em 1615.10s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.4211 (±0.5736) | Concluído em 1651.26s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.3235 (±0.6200) | Concluído em 1576.84s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Mg (g/kg)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Mg__g_kg_.joblib
#    - Modelo: RFR
#    - Filtro: OPLS2_SNV_SG_D1
#    - Melhor R² CV: 0.4211
#    - Melhores Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300, 'warm_start': True}
#
# --- Salvando os 5 melhores modelos para Mg (g/kg) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Mg__g_kg__PLSR_SNV.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Mg__g_kg__PLSR_Normalize.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Mg__g_kg__PLSR_OSC_1.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Mg__g_kg__PLSR_MSC.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Mg__g_kg__PLSR_EMSC.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Mg__g_kg__PCR_Normalize.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Mg__g_kg__PCR_OSC_2.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Mg__g_kg__PCR_EMSC.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Mg__g_kg__PCR_MSC.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Mg__g_kg__PCR_SNV.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Mg__g_kg__SVMR_SNV.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Mg__g_kg__SVMR_Wavelet_Denoising.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Mg__g_kg__SVMR_Raw.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Mg__g_kg__SVMR_EMSC.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Mg__g_kg__SVMR_MSC.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Mg__g_kg__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Mg__g_kg__RFR_MSC.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Mg__g_kg__RFR_EMSC.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Mg__g_kg__RFR_Continuum_Removal.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Mg__g_kg__RFR_SNV.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: S (g/kg)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.5305 (±0.2657) | Concluído em 0.26s
#   Testando filtro: MSC... CV R²: 0.5782 (±0.2298) | Concluído em 0.30s
#   Testando filtro: SNV... CV R²: 0.5847 (±0.2041) | Concluído em 0.31s
#   Testando filtro: SG_D1... CV R²: 0.5705 (±0.1989) | Concluído em 0.26s
#   Testando filtro: SG_D2... CV R²: 0.5333 (±0.2153) | Concluído em 0.25s
#   Testando filtro: Detrend... CV R²: 0.5449 (±0.1851) | Concluído em 0.29s
#   Testando filtro: Normalize... CV R²: 0.5819 (±0.1994) | Concluído em 0.29s
#   Testando filtro: EMSC... CV R²: 0.5782 (±0.2298) | Concluído em 0.31s
#   Testando filtro: Continuum_Removal... CV R²: 0.5447 (±0.1839) | Concluído em 0.41s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.5305 (±0.2658) | Concluído em 0.26s
#   Testando filtro: OSC_1... CV R²: 0.5515 (±0.2131) | Concluído em 0.31s
#   Testando filtro: OSC_2... CV R²: 0.4432 (±0.3232) | Concluído em 0.31s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.5799 (±0.1965) | Concluído em 0.27s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.5796 (±0.1977) | Concluído em 0.27s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.5278 (±0.2167) | Concluído em 0.27s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.5927 (±0.1806) | Concluído em 0.26s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.5785 (±0.2721) | Concluído em 0.25s
#   Testando filtro: MSC... CV R²: 0.5309 (±0.2264) | Concluído em 0.26s
#   Testando filtro: SNV... CV R²: 0.5354 (±0.2163) | Concluído em 0.25s
#   Testando filtro: SG_D1... CV R²: 0.6161 (±0.1648) | Concluído em 0.25s
#   Testando filtro: SG_D2... CV R²: 0.5114 (±0.2454) | Concluído em 0.27s
#   Testando filtro: Detrend... CV R²: 0.5741 (±0.2520) | Concluído em 0.25s
#   Testando filtro: Normalize... CV R²: 0.6027 (±0.1632) | Concluído em 0.25s
#   Testando filtro: EMSC... CV R²: 0.5309 (±0.2263) | Concluído em 0.26s
#   Testando filtro: Continuum_Removal... CV R²: 0.5936 (±0.1978) | Concluído em 0.40s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.5784 (±0.2721) | Concluído em 0.25s
#   Testando filtro: OSC_1... CV R²: 0.5343 (±0.2740) | Concluído em 0.25s
#   Testando filtro: OSC_2... CV R²: 0.5141 (±0.2822) | Concluído em 0.25s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.6088 (±0.1637) | Concluído em 0.26s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.6094 (±0.1631) | Concluído em 0.25s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.6218 (±0.1498) | Concluído em 0.26s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.5970 (±0.1782) | Concluído em 0.25s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.6579 (±0.1834) | Concluído em 0.74s
#   Testando filtro: MSC... CV R²: 0.6153 (±0.1626) | Concluído em 0.64s
#   Testando filtro: SNV... CV R²: 0.6508 (±0.1419) | Concluído em 0.72s
#   Testando filtro: SG_D1... CV R²: 0.6049 (±0.1881) | Concluído em 0.54s
#   Testando filtro: SG_D2... CV R²: 0.5420 (±0.2278) | Concluído em 0.55s
#   Testando filtro: Detrend... CV R²: 0.6731 (±0.1611) | Concluído em 0.61s
#   Testando filtro: Normalize... CV R²: 0.6541 (±0.1336) | Concluído em 0.69s
#   Testando filtro: EMSC... CV R²: 0.6153 (±0.1626) | Concluído em 0.64s
#   Testando filtro: Continuum_Removal... CV R²: 0.6234 (±0.1517) | Concluído em 0.69s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.6578 (±0.1834) | Concluído em 0.72s
#   Testando filtro: OSC_1... CV R²: 0.6780 (±0.1415) | Concluído em 0.58s
#   Testando filtro: OSC_2... CV R²: 0.6848 (±0.1561) | Concluído em 0.60s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.6355 (±0.1632) | Concluído em 0.56s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.6393 (±0.1531) | Concluído em 0.54s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.6279 (±0.1708) | Concluído em 0.56s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.6077 (±0.1808) | Concluído em 0.53s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.5092 (±0.2640) | Concluído em 1475.03s
#   Testando filtro: MSC... CV R²: 0.5721 (±0.1714) | Concluído em 1420.91s
#   Testando filtro: SNV... CV R²: 0.6072 (±0.1679) | Concluído em 1506.13s
#   Testando filtro: SG_D1... CV R²: 0.6591 (±0.1863) | Concluído em 1506.63s
#   Testando filtro: SG_D2... CV R²: 0.6261 (±0.1942) | Concluído em 1440.32s
#   Testando filtro: Detrend... CV R²: 0.6426 (±0.1604) | Concluído em 1403.18s
#   Testando filtro: Normalize... CV R²: 0.5891 (±0.1900) | Concluído em 1418.40s
#   Testando filtro: EMSC... CV R²: 0.5721 (±0.1714) | Concluído em 1420.69s
#   Testando filtro: Continuum_Removal... CV R²: 0.6323 (±0.1129) | Concluído em 1419.82s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.5090 (±0.2643) | Concluído em 1477.49s
#   Testando filtro: OSC_1... CV R²: 0.5701 (±0.1918) | Concluído em 1463.02s
#   Testando filtro: OSC_2... CV R²: 0.5978 (±0.1401) | Concluído em 1508.96s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.6419 (±0.1664) | Concluído em 1394.76s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.6558 (±0.1600) | Concluído em 1437.88s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.6895 (±0.1377) | Concluído em 1419.61s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.6922 (±0.1444) | Concluído em 1503.58s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'S (g/kg)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_S__g_kg_.joblib
#    - Modelo: RFR
#    - Filtro: SNV_Detrend_SG_D1
#    - Melhor R² CV: 0.6922
#    - Melhores Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300, 'warm_start': True}
#
# --- Salvando os 5 melhores modelos para S (g/kg) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_S__g_kg__PLSR_SNV_Detrend_SG_D1.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_S__g_kg__PLSR_SNV.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_S__g_kg__PLSR_Normalize.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_S__g_kg__PLSR_MSC_SG_OSC.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_S__g_kg__PLSR_OPLS1_SNV_SG_D1.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_S__g_kg__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_S__g_kg__PCR_SG_D1.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_S__g_kg__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_S__g_kg__PCR_MSC_SG_OSC.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_S__g_kg__PCR_Normalize.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_S__g_kg__SVMR_OSC_2.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_S__g_kg__SVMR_OSC_1.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_S__g_kg__SVMR_Detrend.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_S__g_kg__SVMR_Raw.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_S__g_kg__SVMR_Wavelet_Denoising.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_S__g_kg__RFR_SNV_Detrend_SG_D1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_S__g_kg__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_S__g_kg__RFR_SG_D1.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_S__g_kg__RFR_OPLS1_SNV_SG_D1.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_S__g_kg__RFR_Detrend.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: B (mg/kg)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.7327 (±0.1844) | Concluído em 0.26s
#   Testando filtro: MSC... CV R²: 0.6971 (±0.1584) | Concluído em 0.39s
#   Testando filtro: SNV... CV R²: 0.6743 (±0.1648) | Concluído em 0.37s
#   Testando filtro: SG_D1... CV R²: 0.6581 (±0.2595) | Concluído em 0.26s
#   Testando filtro: SG_D2... CV R²: 0.6340 (±0.2298) | Concluído em 0.26s
#   Testando filtro: Detrend... CV R²: 0.6981 (±0.1282) | Concluído em 0.26s
#   Testando filtro: Normalize... CV R²: 0.6723 (±0.2301) | Concluído em 0.30s
#   Testando filtro: EMSC... CV R²: 0.6971 (±0.1584) | Concluído em 0.39s
#   Testando filtro: Continuum_Removal... CV R²: 0.6394 (±0.2239) | Concluído em 0.42s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.7326 (±0.1843) | Concluído em 0.27s
#   Testando filtro: OSC_1... CV R²: 0.6712 (±0.2375) | Concluído em 0.29s
#   Testando filtro: OSC_2... CV R²: 0.6724 (±0.1447) | Concluído em 0.40s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.6743 (±0.2638) | Concluído em 0.26s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.6734 (±0.2587) | Concluído em 0.27s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.5995 (±0.3394) | Concluído em 0.26s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.6430 (±0.2855) | Concluído em 0.27s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.7075 (±0.2282) | Concluído em 0.25s
#   Testando filtro: MSC... CV R²: 0.6856 (±0.1849) | Concluído em 0.26s
#   Testando filtro: SNV... CV R²: 0.6861 (±0.1826) | Concluído em 0.26s
#   Testando filtro: SG_D1... CV R²: 0.7357 (±0.2087) | Concluído em 0.27s
#   Testando filtro: SG_D2... CV R²: 0.6820 (±0.1932) | Concluído em 0.26s
#   Testando filtro: Detrend... CV R²: 0.7153 (±0.1578) | Concluído em 0.26s
#   Testando filtro: Normalize... CV R²: 0.7065 (±0.2029) | Concluído em 0.27s
#   Testando filtro: EMSC... CV R²: 0.6856 (±0.1849) | Concluído em 0.24s
#   Testando filtro: Continuum_Removal... CV R²: 0.5984 (±0.2227) | Concluído em 0.40s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.7076 (±0.2282) | Concluído em 0.26s
#   Testando filtro: OSC_1... CV R²: 0.6957 (±0.2221) | Concluído em 0.26s
#   Testando filtro: OSC_2... CV R²: 0.6991 (±0.1866) | Concluído em 0.25s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.7661 (±0.1466) | Concluído em 0.26s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.7634 (±0.1591) | Concluído em 0.26s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.7269 (±0.1842) | Concluído em 0.26s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.7199 (±0.2096) | Concluído em 0.28s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.7744 (±0.1393) | Concluído em 0.65s
#   Testando filtro: MSC... CV R²: 0.5910 (±0.2303) | Concluído em 0.66s
#   Testando filtro: SNV... CV R²: 0.6951 (±0.2914) | Concluído em 0.64s
#   Testando filtro: SG_D1... CV R²: 0.3982 (±0.3962) | Concluído em 0.66s
#   Testando filtro: SG_D2... CV R²: 0.7108 (±0.1109) | Concluído em 0.65s
#   Testando filtro: Detrend... CV R²: 0.7278 (±0.1273) | Concluído em 0.64s
#   Testando filtro: Normalize... CV R²: 0.5322 (±0.3365) | Concluído em 0.63s
#   Testando filtro: EMSC... CV R²: 0.5910 (±0.2303) | Concluído em 0.63s
#   Testando filtro: Continuum_Removal... CV R²: 0.2295 (±0.5921) | Concluído em 0.79s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.7744 (±0.1393) | Concluído em 0.65s
#   Testando filtro: OSC_1... CV R²: 0.6772 (±0.1574) | Concluído em 0.64s
#   Testando filtro: OSC_2... CV R²: 0.6400 (±0.2146) | Concluído em 0.67s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.7463 (±0.2035) | Concluído em 0.65s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.7368 (±0.2166) | Concluído em 0.66s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.7375 (±0.2057) | Concluído em 0.66s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.3020 (±0.4850) | Concluído em 0.65s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.7614 (±0.1087) | Concluído em 1574.72s
#   Testando filtro: MSC... CV R²: 0.6250 (±0.4249) | Concluído em 1658.29s
# ...
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.1917 (±0.2148) | Concluído em 0.26s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.1100 (±0.3291) | Concluído em 0.26s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.1325 (±0.2845) | Concluído em 0.26s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.2222 (±0.2030) | Concluído em 0.25s
#   Testando filtro: MSC... CV R²: 0.2193 (±0.2739) | Concluído em 0.25s
#   Testando filtro: SNV... CV R²: 0.2158 (±0.2759) | Concluído em 0.26s
#   Testando filtro: SG_D1... CV R²: 0.3149 (±0.2449) | Concluído em 0.27s
#   Testando filtro: SG_D2... CV R²: 0.2465 (±0.2910) | Concluído em 0.27s
#   Testando filtro: Detrend... CV R²: 0.1783 (±0.3140) | Concluído em 0.25s
#   Testando filtro: Normalize... CV R²: 0.1368 (±0.2444) | Concluído em 0.26s
#   Testando filtro: EMSC... CV R²: 0.2193 (±0.2739) | Concluído em 0.25s
#   Testando filtro: Continuum_Removal... CV R²: 0.0753 (±0.4011) | Concluído em 0.38s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.2221 (±0.2030) | Concluído em 0.25s
#   Testando filtro: OSC_1... CV R²: 0.2299 (±0.1669) | Concluído em 0.25s
#   Testando filtro: OSC_2... CV R²: 0.2485 (±0.1419) | Concluído em 0.25s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.2991 (±0.2632) | Concluído em 0.26s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2987 (±0.2634) | Concluído em 0.25s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.3225 (±0.2797) | Concluído em 0.26s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.3015 (±0.2476) | Concluído em 0.24s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.2635 (±0.2258) | Concluído em 0.63s
#   Testando filtro: MSC... CV R²: 0.2529 (±0.2711) | Concluído em 0.60s
#   Testando filtro: SNV... CV R²: 0.2908 (±0.2449) | Concluído em 0.59s
#   Testando filtro: SG_D1... CV R²: 0.2455 (±0.2708) | Concluído em 0.60s
#   Testando filtro: SG_D2... CV R²: 0.2252 (±0.3238) | Concluído em 0.62s
#   Testando filtro: Detrend... CV R²: 0.2148 (±0.3052) | Concluído em 0.62s
#   Testando filtro: Normalize... CV R²: 0.2726 (±0.2700) | Concluído em 0.60s
#   Testando filtro: EMSC... CV R²: 0.2529 (±0.2711) | Concluído em 0.61s
#   Testando filtro: Continuum_Removal... CV R²: 0.1698 (±0.3319) | Concluído em 0.75s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.2635 (±0.2257) | Concluído em 0.62s
#   Testando filtro: OSC_1... CV R²: 0.2674 (±0.2203) | Concluído em 0.71s
#   Testando filtro: OSC_2... CV R²: 0.2494 (±0.1458) | Concluído em 0.66s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.2221 (±0.2793) | Concluído em 0.61s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2186 (±0.2839) | Concluído em 0.60s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.2229 (±0.2458) | Concluído em 0.60s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.2516 (±0.2613) | Concluído em 0.61s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: -0.0246 (±0.3200) | Concluído em 1451.07s
#   Testando filtro: MSC... CV R²: 0.1633 (±0.3264) | Concluído em 1542.85s
#   Testando filtro: SNV... CV R²: 0.1781 (±0.2891) | Concluído em 1520.09s
#   Testando filtro: SG_D1... CV R²: 0.1995 (±0.2612) | Concluído em 1687.02s
#   Testando filtro: SG_D2... CV R²: 0.2641 (±0.1881) | Concluído em 1527.24s
#   Testando filtro: Detrend... CV R²: 0.1271 (±0.2489) | Concluído em 1501.73s
#   Testando filtro: Normalize... CV R²: 0.2166 (±0.2421) | Concluído em 1560.95s
#   Testando filtro: EMSC... CV R²: 0.1633 (±0.3264) | Concluído em 1543.06s
#   Testando filtro: Continuum_Removal... CV R²: 0.2487 (±0.2600) | Concluído em 1536.66s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.0243 (±0.3197) | Concluído em 1452.71s
#   Testando filtro: OSC_1... CV R²: 0.0869 (±0.3078) | Concluído em 1399.94s
#   Testando filtro: OSC_2... CV R²: 0.2227 (±0.1960) | Concluído em 1442.25s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.2662 (±0.3024) | Concluído em 1674.73s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2949 (±0.2752) | Concluído em 1637.28s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.2820 (±0.1314) | Concluído em 1598.34s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.2040 (±0.2169) | Concluído em 1564.64s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Zn (mg/kg)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Zn__mg_kg_.joblib
#    - Modelo: PCR
#    - Filtro: OPLS2_SNV_SG_D1
#    - Melhor R² CV: 0.3225
#    - Melhores Parâmetros: {'pca__n_components': 5}
#
# --- Salvando os 5 melhores modelos para Zn (mg/kg) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Zn__mg_kg__PLSR_SG_D2.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Zn__mg_kg__PLSR_Raw.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Zn__mg_kg__PLSR_Wavelet_Denoising.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Zn__mg_kg__PLSR_Continuum_Removal.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Zn__mg_kg__PLSR_MSC_SG_OSC.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Zn__mg_kg__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Zn__mg_kg__PCR_SG_D1.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Zn__mg_kg__PCR_SNV_Detrend_SG_D1.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Zn__mg_kg__PCR_MSC_SG_OSC.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Zn__mg_kg__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Zn__mg_kg__SVMR_SNV.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Zn__mg_kg__SVMR_Normalize.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Zn__mg_kg__SVMR_OSC_1.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Zn__mg_kg__SVMR_Raw.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Zn__mg_kg__SVMR_Wavelet_Denoising.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Zn__mg_kg__RFR_OPLS1_SNV_SG_D1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Zn__mg_kg__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Zn__mg_kg__RFR_MSC_SG_OSC.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Zn__mg_kg__RFR_SG_D2.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Zn__mg_kg__RFR_Continuum_Removal.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: Mo
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.1314 (±0.3681) | Concluído em 0.28s
#   Testando filtro: MSC... CV R²: 0.0481 (±0.4870) | Concluído em 0.28s
#   Testando filtro: SNV... CV R²: 0.0847 (±0.4238) | Concluído em 0.27s
#   Testando filtro: SG_D1... CV R²: -0.0214 (±0.3509) | Concluído em 0.26s
#   Testando filtro: SG_D2... CV R²: -0.3895 (±0.7199) | Concluído em 0.26s
#   Testando filtro: Detrend... CV R²: 0.1738 (±0.4153) | Concluído em 0.26s
#   Testando filtro: Normalize... CV R²: 0.1194 (±0.3522) | Concluído em 0.26s
#   Testando filtro: EMSC... CV R²: 0.0481 (±0.4870) | Concluído em 0.27s
#   Testando filtro: Continuum_Removal... CV R²: 0.1424 (±0.3696) | Concluído em 0.43s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.1316 (±0.3683) | Concluído em 0.28s
#   Testando filtro: OSC_1... CV R²: -0.0078 (±0.4290) | Concluído em 0.28s
#   Testando filtro: OSC_2... CV R²: 0.1045 (±0.4223) | Concluído em 0.27s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.0246 (±0.4697) | Concluído em 0.27s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.0021 (±0.5230) | Concluído em 0.27s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.0092 (±0.4363) | Concluído em 0.27s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.1287 (±0.4218) | Concluído em 0.27s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.1631 (±0.3418) | Concluído em 0.25s
#   Testando filtro: MSC... CV R²: 0.1441 (±0.3713) | Concluído em 0.25s
#   Testando filtro: SNV... CV R²: 0.1458 (±0.3719) | Concluído em 0.26s
#   Testando filtro: SG_D1... CV R²: 0.1487 (±0.4066) | Concluído em 0.26s
#   Testando filtro: SG_D2... CV R²: 0.0236 (±0.4797) | Concluído em 0.26s
#   Testando filtro: Detrend... CV R²: 0.1133 (±0.4236) | Concluído em 0.24s
#   Testando filtro: Normalize... CV R²: 0.1679 (±0.3762) | Concluído em 0.26s
#   Testando filtro: EMSC... CV R²: 0.1441 (±0.3713) | Concluído em 0.26s
#   Testando filtro: Continuum_Removal... CV R²: 0.1096 (±0.4459) | Concluído em 0.41s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.1631 (±0.3418) | Concluído em 0.26s
#   Testando filtro: OSC_1... CV R²: 0.1249 (±0.3738) | Concluído em 0.25s
#   Testando filtro: OSC_2... CV R²: 0.1524 (±0.3902) | Concluído em 0.26s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.2483 (±0.3660) | Concluído em 0.26s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2490 (±0.3653) | Concluído em 0.25s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.2732 (±0.3550) | Concluído em 0.25s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.1556 (±0.3435) | Concluído em 0.26s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.2395 (±0.3538) | Concluído em 0.67s
#   Testando filtro: MSC... CV R²: 0.2143 (±0.2973) | Concluído em 0.57s
#   Testando filtro: SNV... CV R²: 0.2041 (±0.4105) | Concluído em 0.67s
#   Testando filtro: SG_D1... CV R²: 0.2119 (±0.3915) | Concluído em 0.57s
#   Testando filtro: SG_D2... CV R²: 0.0766 (±0.3630) | Concluído em 0.55s
#   Testando filtro: Detrend... CV R²: 0.1894 (±0.3886) | Concluído em 0.59s
#   Testando filtro: Normalize... CV R²: 0.1952 (±0.3685) | Concluído em 0.56s
#   Testando filtro: EMSC... CV R²: 0.2143 (±0.2973) | Concluído em 0.55s
#   Testando filtro: Continuum_Removal... CV R²: 0.1863 (±0.4332) | Concluído em 0.69s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.2394 (±0.3535) | Concluído em 0.66s
#   Testando filtro: OSC_1... CV R²: 0.2189 (±0.3565) | Concluído em 0.57s
#   Testando filtro: OSC_2... CV R²: 0.2206 (±0.4592) | Concluído em 0.56s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.2070 (±0.3478) | Concluído em 0.55s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2412 (±0.3339) | Concluído em 0.54s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.2565 (±0.3436) | Concluído em 0.55s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.1999 (±0.3980) | Concluído em 0.56s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.0309 (±0.6752) | Concluído em 1502.07s
#   Testando filtro: MSC... CV R²: 0.0816 (±0.5385) | Concluído em 1411.79s
#   Testando filtro: SNV... CV R²: 0.0489 (±0.5853) | Concluído em 1463.58s
#   Testando filtro: SG_D1... CV R²: 0.0623 (±0.6338) | Concluído em 1524.87s
#   Testando filtro: SG_D2... CV R²: 0.0724 (±0.5006) | Concluído em 1583.59s
#   Testando filtro: Detrend... CV R²: 0.0948 (±0.4475) | Concluído em 1492.77s
#   Testando filtro: Normalize... CV R²: 0.2044 (±0.4629) | Concluído em 1558.84s
#   Testando filtro: EMSC... CV R²: 0.0816 (±0.5385) | Concluído em 1413.13s
#   Testando filtro: Continuum_Removal... CV R²: 0.1733 (±0.5202) | Concluído em 1483.86s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.0327 (±0.6673) | Concluído em 1488.52s
#   Testando filtro: OSC_1... CV R²: 0.0112 (±0.6070) | Concluído em 1440.82s
#   Testando filtro: OSC_2... CV R²: 0.0337 (±0.6246) | Concluído em 1369.05s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.1474 (±0.5888) | Concluído em 1480.57s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.0805 (±0.6247) | Concluído em 1591.31s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.1819 (±0.5440) | Concluído em 1488.33s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.1737 (±0.4614) | Concluído em 1498.21s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Mo ' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Mo_.joblib
#    - Modelo: PCR
#    - Filtro: OPLS2_SNV_SG_D1
#    - Melhor R² CV: 0.2732
#    - Melhores Parâmetros: {'pca__n_components': 5}
#
# --- Salvando os 5 melhores modelos para Mo  ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Mo__PLSR_Detrend.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Mo__PLSR_Continuum_Removal.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Mo__PLSR_Wavelet_Denoising.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Mo__PLSR_Raw.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Mo__PLSR_Normalize.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Mo__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Mo__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Mo__PCR_MSC_SG_OSC.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Mo__PCR_Normalize.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Mo__PCR_Raw.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Mo__SVMR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Mo__SVMR_OPLS1_SNV_SG_D1.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Mo__SVMR_Raw.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Mo__SVMR_Wavelet_Denoising.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Mo__SVMR_OSC_2.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Mo__RFR_Normalize.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Mo__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Mo__RFR_SNV_Detrend_SG_D1.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Mo__RFR_Continuum_Removal.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Mo__RFR_MSC_SG_OSC.joblib
#
#
#  ✅ Modelagem exaustiva com Cross-Validation!
#   ✅Resultados salvos em "analise_completa_resultados_cv.xlsx"
#
# --- Melhores Resultados por Atributo (Cross-Validation) ---
#   Atributo Modelo            Filtro  CV_R2_Mean  CV_R2_Std  CV_RMSE                                                                                                               Melhores_Params
#  B (mg/kg)    RFR             OSC_1      0.7835     0.0888  18.1132 {'bootstrap': False, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200, 'warm_start': True}
#  Ca (g/kg)   SVMR             OSC_1      0.7221     0.1445   2.4350                                                              {'C': 100, 'epsilon': 1.0, 'gamma': 'scale', 'kernel': 'linear'}
# Fe (mg/kg)   SVMR             OSC_1      0.5865     0.3872  12.7273                                                                 {'C': 100, 'epsilon': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
#   K (g/kg)   SVMR Continuum_Removal      0.3867     0.3055   0.9256                                                              {'C': 100, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#  Mg (g/kg)    RFR   OPLS2_SNV_SG_D1      0.4211     0.5736   0.5143  {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300, 'warm_start': True}
# Mn (mg/kg)    RFR SNV_Detrend_SG_D1      0.7067     0.1426 141.6480  {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100, 'warm_start': True}
#        Mo     PCR   OPLS2_SNV_SG_D1      0.2732     0.3550   0.2238                                                                                                      {'pca__n_components': 5}
#   N (g/kg)   PLSR   OPLS2_SNV_SG_D1      0.6504     0.1749   0.8562                                                                                                          {'n_components': 20}
#   P (g/kg)   SVMR   OPLS2_SNV_SG_D1      0.3102     0.3114   0.1072                                                              {'C': 100, 'epsilon': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
#   S (g/kg)    RFR SNV_Detrend_SG_D1      0.6922     0.1444   0.1761  {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300, 'warm_start': True}
# Zn (mg/kg)    PCR   OPLS2_SNV_SG_D1      0.3225     0.2797   2.5102                                                                                                      {'pca__n_components': 5}

# %% [markdown]
# ## 7. Análise Comparativa dos Resultados

# %%
import pandas as pd
import numpy as np

# Carregar os resultados salvos para análise
df_analise = pd.read_excel('analise_completa_resultados_cv.xlsx')

idx = df_analise.groupby(['Atributo', 'Modelo'])['CV_R2_Mean'].transform(max) == df_analise['CV_R2_Mean']
df_melhores_por_modelo = df_analise[idx]

print("--- Tabela Comparativa dos Melhores Resultados por Modelo (Cross-Validation) ---")
print(df_melhores_por_modelo[['Atributo', 'Modelo', 'Filtro', 'CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE']].round(4))

print("\n--- Melhores Modelos Gerais por Atributo (baseado no R² de Cross-Validation) ---")
idx_geral = df_melhores_por_modelo.groupby(['Atributo'])['CV_R2_Mean'].transform(max) == df_melhores_por_modelo['CV_R2_Mean']
df_melhores_gerais = df_melhores_por_modelo[idx_geral]
print(df_melhores_gerais[['Atributo', 'Modelo', 'Filtro', 'CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE']].round(4))

# Análise estatística adicional
print("\n--- Análise Estatística dos Resultados ---")
print(f"Número total de combinações testadas: {len(df_analise)}")
print(f"Número de atributos analisados: {df_analise['Atributo'].nunique()}")
print(f"Número de modelos testados: {df_analise['Modelo'].nunique()}")
print(f"Número de filtros testados: {df_analise['Filtro'].nunique()}")

print(f"\nEstatísticas do R² de Cross-Validation:")
print(f"  Média geral: {df_analise['CV_R2_Mean'].mean():.4f}")
print(f"  Desvio padrão: {df_analise['CV_R2_Mean'].std():.4f}")
print(f"  Melhor resultado: {df_analise['CV_R2_Mean'].max():.4f}")
print(f"  Pior resultado: {df_analise['CV_R2_Mean'].min():.4f}")

# Análise por modelo
print(f"\n--- Desempenho Médio por Modelo ---")
desempenho_por_modelo = df_analise.groupby('Modelo')['CV_R2_Mean'].agg(['mean', 'std', 'max', 'min']).round(4)
print(desempenho_por_modelo)

# Análise por filtro
print(f"\n--- Top 10 Filtros com Melhor Desempenho Médio ---")
desempenho_por_filtro = df_analise.groupby('Filtro')['CV_R2_Mean'].agg(['mean', 'std', 'count']).round(4)
desempenho_por_filtro = desempenho_por_filtro.sort_values('mean', ascending=False)
print(desempenho_por_filtro.head(10))

print("\n✅ Análise de resultados concluída!")
# Out:
# --- Tabela Comparativa dos Melhores Resultados por Modelo (Cross-Validation) ---
#        Atributo Modelo             Filtro  CV_R2_Mean  CV_R2_Std   CV_RMSE
# 0     B (mg/kg)    RFR              OSC_1      0.7835     0.0888   18.1132
# 1     B (mg/kg)   SVMR  Wavelet_Denoising      0.7744     0.1393   17.4237
# 3     B (mg/kg)    PCR         MSC_SG_OSC      0.7661     0.1466   17.6626
# 12    B (mg/kg)   PLSR                Raw      0.7327     0.1844   19.0675
# 64    Ca (g/kg)   SVMR              OSC_1      0.7221     0.1445    2.4350
# 74    Ca (g/kg)   PLSR                MSC      0.7015     0.1562    2.4534
# 77    Ca (g/kg)    PCR  SNV_Detrend_SG_D1      0.6981     0.1960    2.5680
# 85    Ca (g/kg)    RFR  SNV_Detrend_SG_D1      0.6796     0.1902    2.6245
# 128  Fe (mg/kg)   SVMR              OSC_1      0.5865     0.3872   12.7273
# 129  Fe (mg/kg)   PLSR              SG_D2      0.5675     0.3340   12.3736
# 136  Fe (mg/kg)    RFR              OSC_1      0.5393     0.3807   13.4998
# 141  Fe (mg/kg)    PCR            Detrend      0.5236     0.4274   13.6055
# 192    K (g/kg)   SVMR  Continuum_Removal      0.3867     0.3055    0.9256
# 194    K (g/kg)    RFR    OPLS2_SNV_SG_D1      0.3308     0.2756    0.9675
# 195    K (g/kg)   PLSR  Continuum_Removal      0.3221     0.2565    0.9769
# 196    K (g/kg)    PCR    OPLS2_SNV_SG_D1      0.3066     0.4539    0.9361
# 256   Mg (g/kg)    RFR    OPLS2_SNV_SG_D1      0.4211     0.5736    0.5143
# 257   Mg (g/kg)   SVMR                SNV      0.4125     0.5852    0.5117
# 274   Mg (g/kg)    PCR          Normalize      0.3515     0.6452    0.5452
# 277   Mg (g/kg)   PLSR                SNV      0.3458     0.6109    0.5489
# 320  Mn (mg/kg)    RFR  SNV_Detrend_SG_D1      0.7067     0.1426  141.6480
# 321  Mn (mg/kg)   SVMR                SNV      0.6955     0.1602  147.0214
# 325  Mn (mg/kg)    PCR    OPLS2_SNV_SG_D1      0.6709     0.1896  146.1327
# 332  Mn (mg/kg)   PLSR              SG_D1      0.6595     0.1602  148.8417
# 384         Mo     PCR    OPLS2_SNV_SG_D1      0.2732     0.3550    0.2238
# 385         Mo    SVMR    OPLS2_SNV_SG_D1      0.2565     0.3436    0.2321
# 397         Mo     RFR          Normalize      0.2044     0.4629    0.2354
# 404         Mo    PLSR            Detrend      0.1738     0.4153    0.2433
# 448    N (g/kg)   PLSR    OPLS2_SNV_SG_D1      0.6504     0.1749    0.8562
# 449    N (g/kg)    RFR    OPLS2_SNV_SG_D1      0.6483     0.1623    0.8471
# 453    N (g/kg)    PCR              SG_D2      0.5619     0.2225    0.9574
# 454    N (g/kg)   SVMR                SNV      0.5507     0.1942    0.9634
# 512    P (g/kg)   SVMR    OPLS2_SNV_SG_D1      0.3102     0.3114    0.1072
# 516    P (g/kg)    PCR    OPLS2_SNV_SG_D1      0.2940     0.2390    0.1085
# 530    P (g/kg)   PLSR          Normalize      0.2400     0.2702    0.1103
# 532    P (g/kg)    RFR            Detrend      0.2292     0.2291    0.1134
# 576    S (g/kg)    RFR  SNV_Detrend_SG_D1      0.6922     0.1444    0.1761
# 578    S (g/kg)   SVMR              OSC_2      0.6848     0.1561    0.1829
# 595    S (g/kg)    PCR    OPLS2_SNV_SG_D1      0.6218     0.1498    0.1942
# 608    S (g/kg)   PLSR  SNV_Detrend_SG_D1      0.5927     0.1806    0.2006
# 640  Zn (mg/kg)    PCR    OPLS2_SNV_SG_D1      0.3225     0.2797    2.5102
# 645  Zn (mg/kg)    RFR    OPLS1_SNV_SG_D1      0.2949     0.2752    2.4985
# 646  Zn (mg/kg)   SVMR                SNV      0.2908     0.2449    2.5337
# 647  Zn (mg/kg)   PLSR              SG_D2      0.2908     0.2761    2.5700
#
# --- Melhores Modelos Gerais por Atributo (baseado no R² de Cross-Validation) ---
#        Atributo Modelo             Filtro  CV_R2_Mean  CV_R2_Std   CV_RMSE
# 0     B (mg/kg)    RFR              OSC_1      0.7835     0.0888   18.1132
# 64    Ca (g/kg)   SVMR              OSC_1      0.7221     0.1445    2.4350
# 128  Fe (mg/kg)   SVMR              OSC_1      0.5865     0.3872   12.7273
# 192    K (g/kg)   SVMR  Continuum_Removal      0.3867     0.3055    0.9256
# 256   Mg (g/kg)    RFR    OPLS2_SNV_SG_D1      0.4211     0.5736    0.5143
# 320  Mn (mg/kg)    RFR  SNV_Detrend_SG_D1      0.7067     0.1426  141.6480
# 384         Mo     PCR    OPLS2_SNV_SG_D1      0.2732     0.3550    0.2238
# 448    N (g/kg)   PLSR    OPLS2_SNV_SG_D1      0.6504     0.1749    0.8562
# 512    P (g/kg)   SVMR    OPLS2_SNV_SG_D1      0.3102     0.3114    0.1072
# 576    S (g/kg)    RFR  SNV_Detrend_SG_D1      0.6922     0.1444    0.1761
# 640  Zn (mg/kg)    PCR    OPLS2_SNV_SG_D1      0.3225     0.2797    2.5102
#
# --- Análise Estatística dos Resultados ---
# Número total de combinações testadas: 704
# Número de atributos analisados: 11
# Número de modelos testados: 4
# Número de filtros testados: 16
#
# Estatísticas do R² de Cross-Validation:
#   Média geral: 0.4060
#   Desvio padrão: 0.2194
#   Melhor resultado: 0.7835
#   Pior resultado: -0.3895
#
# --- Desempenho Médio por Modelo ---
#           mean     std     max     min
# Modelo
# PCR     0.4236  0.2045  0.7661  0.0236
# PLSR    0.3734  0.2433  0.7327 -0.3895
# RFR     0.3802  0.2312  0.7835 -0.2252
# SVMR    0.4467  0.1875  0.7744  0.0593
#
# --- Top 10 Filtros com Melhor Desempenho Médio ---
#                      mean     std  count
# Filtro
# OPLS2_SNV_SG_D1    0.4320  0.2141     44
# OPLS1_SNV_SG_D1    0.4313  0.2086     44
# MSC_SG_OSC         0.4246  0.2149     44
# Detrend            0.4174  0.2192     44
# Normalize          0.4120  0.2032     44
# Raw                0.4104  0.2323     44
# Wavelet_Denoising  0.4102  0.2328     44
# SNV                0.4071  0.2237     44
# Continuum_Removal  0.4042  0.1954     44
# OSC_1              0.4028  0.2383     44
#
# ✅ Análise de resultados concluída!

# %% [markdown]
# ## Testes

# %%
## Linha de teste
