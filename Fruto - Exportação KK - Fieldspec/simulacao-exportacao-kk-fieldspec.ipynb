# %% [markdown]
# # Análise Espectroscópica
#
# Este notebook segue as melhores práticas da literatura para análise espectroscópica robusta, incluindo:
# - Cross Validation
# - Remoção de outliers espectrais (PCA, T²/Q)
# - Remoção de outliers dos atributos (boxplot + seaborn)
# - Teste de todos os filtros (dependentes e independentes de y)
# - Modelagem com PLSR, PCR, RFR, SVMR (hiperparâmetros da literatura)
# - Plotagens robustas e salvamento de métricas

# %% [markdown]
# ## 1. Imports

# %%
# Imports necessários
import os
import time
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
from scipy.signal import savgol_filter
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold, GridSearchCV, cross_val_predict, cross_val_score
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_squared_error
from matplotlib.mlab import detrend
import pywt
from sklearn.pipeline import Pipeline

# Cria diretórios para organizar todas as imagens salvas
print("Criando diretórios para salvar os gráficos...")
os.makedirs('graficos_outliers_pca', exist_ok=True)
os.makedirs('graficos_outliers_boxplot', exist_ok=True)
os.makedirs('modelos_salvos', exist_ok=True)
os.makedirs('graficos_modelos', exist_ok=True) 
os.makedirs('graficos_mlpr', exist_ok=True)

warnings.filterwarnings('ignore')

# Configurações de plot
plt.style.use('default')
sns.set_palette('husl')
plt.rcParams['figure.figsize'] = (12, 8)
# Out:
# Criando diretórios para salvar os gráficos...

# %% [markdown]
# ## 2. Carregamento dos Dados

# %% [markdown]
# O primeiro passo em qualquer projeto de ciência de dados é carregar e entender os dados. Nesta seção, realizamos as seguintes ações:
# - **Carregamento:** Utilizamos a biblioteca `pandas` para ler o arquivo `Simulacao_Exportacao_Keitt_e_Kent_Fieldspec.xlsx`, que contém os dados espectrais e os valores de referência (atributos físico-químicos).
# - **Separação de Dados:** A função `load_data` inteligentemente separa o arquivo em duas partes:
#     - `metadata`: Um DataFrame contendo as informações de referência (ex: Firmness, Dry Mass, TSS, TA, AA), que serão nossas variáveis-alvo (y).
#     - `wavelengths`: Um DataFrame contendo a resposta espectral (absorbância ou reflectância) em cada comprimento de onda, que serão nossas variáveis preditoras (X).
# - **Definição de Variáveis:** Convertemos os dados espectrais para um array NumPy (`X`) para otimizar os cálculos e definimos a lista de `atributos` que desejamos modelar.

# %%
# Função para carregar dados
def load_data(filepath):
    """Carrega dados espectrais e separa metadados de espectros."""
    df = pd.read_excel(filepath, engine='openpyxl')
    
    # Identificar colunas que são comprimentos de onda (numéricas)
    numeric_cols = []
    for col in df.columns:
        try:
            float(col)
            numeric_cols.append(col)
        except ValueError:
            continue
    
    # Separar metadados e comprimentos de onda
    metadata = df.drop(columns=numeric_cols)
    wavelengths = df[numeric_cols]
    
    return metadata, wavelengths

# Carregar dados
filepath = '../Data/raw/Fruto/Simulacao_Exportacao_Keitt_e_Kent_Fieldspec.xlsx'
metadata, wavelengths = load_data(filepath)
X = wavelengths.values
wavelength_values = wavelengths.columns.astype(float)

# VARIÁVEIS DA SARAH
atributos = ['Firmness (N)', 'Dry Mass (%)', 'TSS (Brix)', 'TA (g/mL)', 'AA (mg/100g)']

print(f'Dados carregados: {X.shape[0]} amostras, {X.shape[1]} comprimentos de onda')
print(f'Faixa espectral: {wavelength_values.min():.1f} - {wavelength_values.max():.1f} nm')
print(f'Atributos disponíveis: {list(metadata.columns)}')
print(f'Atributos a analisar: {atributos}')

# remoção de NaN antes de passar pelo pré-processamento e conferência

dados_completos = {}
for atributo in atributos:
    y = metadata[atributo].values
    original_indices = np.arange(len(y))
    
    # Remove apenas valores NaN
    mask = ~np.isnan(y)
    X_clean = X[mask]
    y_clean = y[mask]
    original_indices_clean = original_indices[mask]
    
    dados_completos[atributo] = {
        'X': X_clean,
        'y': y_clean,
        'indices_orig': original_indices_clean
    }
    
    print(f'{atributo}: {X_clean.shape[0]} amostras válidas')

print(f'\nPreparação dos dados concluída para {len(atributos)} atributos!')
# Out:
# Dados carregados: 60 amostras, 2151 comprimentos de onda
# Faixa espectral: 350.0 - 2500.0 nm
# Atributos disponíveis: ['Samples', 'Stage', 'Variety', 'Firmness (N)', 'Dry Mass (%)', 'TSS (Brix)', 'TA (g/mL)', 'AA (mg/100g)', 'Weight (g)', 'Width (mm)', 'Length (mm)']
# Atributos a analisar: ['Firmness (N)', 'Dry Mass (%)', 'TSS (Brix)', 'TA (g/mL)', 'AA (mg/100g)']
# Firmness (N): 60 amostras válidas
# Dry Mass (%): 60 amostras válidas
# TSS (Brix): 60 amostras válidas
# TA (g/mL): 60 amostras válidas
# AA (mg/100g): 60 amostras válidas
#
# Preparação dos dados concluída para 5 atributos!

# %% [markdown]
# ## 3. Filtros de Pré-processamento (Independentes e Dependentes de y)

# %% [markdown]
# Os dados espectrais brutos contêm diversas fontes de variação indesejada que podem mascarar a informação química relevante. Essas variações podem ser causadas por espalhamento de luz (efeitos físicos da amostra), mudanças na linha de base (drift do instrumento) e ruído. O pré-processing visa minimizar esses efeitos para que o modelo foque na correlação entre o espectro e o atributo de interesse.
#
# Neste notebook, testamos uma ampla gama de filtros, divididos em duas categorias:
#
# ### Filtros Independentes de y
#
# São aplicados apenas aos espectros (`X`) e não utilizam a informação da variável alvo (`y`).
#
# -   **`Raw`**: Utiliza os dados espectrais brutos, sem nenhum tratamento. Serve como uma linha de base para comparar a eficácia dos outros filtros.
# -   **`MSC` (Multiplicative Scatter Correction)**: Corrige o espalhamento de luz (aditivo e multiplicativo) causado por variações no tamanho de partícula e compactação da amostra. Ele ajusta cada espectro para se parecer mais com um espectro "ideal" (geralmente a média de todos os espectros).
# -   **`SNV` (Standard Normal Variate)**: Alternativa ao MSC que também corrige o espalhamento de luz. A diferença é que o SNV padroniza cada espectro individualmente (subtrai a média e divide pelo desvio padrão daquele espectro), sem usar um espectro de referência.
# -   **`SG_D1` e `SG_D2` (Savitzky-Golay Derivatives)**: Calcula a primeira ou a segunda derivada do espectro. Derivadas são excelentes para remover desvios de linha de base (efeitos aditivos) e para resolver picos espectrais sobrepostos, realçando a informação de bandas de absorção específicas.
# -   **`Detrend`**: Remove tendências lineares ou polinomiais da linha de base do espectro. É muito eficaz para corrigir "inclinações" no espectro causadas por drift do instrumento.
# -   **`Normalize`**: Realiza uma normalização Min-Max, escalonando a intensidade de cada espectro para um intervalo fixo (geralmente [0, 1]). Ajuda a corrigir variações de intensidade causadas por diferenças na distância da amostra ou na potência da fonte de luz.
# -   **`EMSC` (Extended Multiplicative Signal Correction)**: Uma versão avançada do MSC. Além de corrigir os efeitos de espalhamento, o EMSC pode incluir termos polinomiais para modelar e remover efeitos de linha de base mais complexos e não-lineares.
# -   **`Continuum Removal`**: Técnica que normaliza os espectros para que as bandas de absorção possam ser comparadas em termos de sua profundidade, e não de sua intensidade absoluta. Ele ajusta um "envelope" (casco convexo) sobre o espectro e divide o espectro original por este envelope, realçando as características de absorção.
# -   **`Wavelet_Denoising`**: Utiliza a Transformada Wavelet para decompor o espectro em diferentes níveis de frequência. A técnica permite remover o ruído (geralmente presente em altas frequências) de forma muito eficaz, preservando as principais características do sinal espectral.
#
# ### Filtros Dependentes de y e Combinações
#
# Estes filtros utilizam a variável alvo (`y`) para otimizar a remoção de variação não correlacionada em `X`, ou são combinações sequenciais de múltiplos filtros para um tratamento mais completo.
#
# -   **`OSC_1` e `OSC_2` (Orthogonal Signal Correction)**: Filtro que remove componentes (1 ou 2, neste caso) dos espectros `X` que são ortogonais (não correlacionados) à variável alvo `y`. O objetivo é limpar `X` da variação que não ajuda na predição, potencialmente melhorando o modelo subsequente. Esta técnica é frequentemente referida como um pré-processamento **OPLS** (Orthogonal Projections to Latent Structures).
# -   **`MSC_SG_OSC`**: Uma **cadeia de pré-processamentos** aplicada na seguinte ordem:
#     1.  `MSC` para corrigir o espalhamento.
#     2.  `Savitzky-Golay (1ª derivada)` para corrigir a linha de base.
#     3.  `OSC (1 componente)` para remover variação não correlacionada com `y`.
# -   **`OPLS1_SNV_SG_D1` e `OPLS2_SNV_SG_D1`**: Outra cadeia de processamento:
#     1.  `SNV` para correção de espalhamento.
#     2.  `Savitzky-Golay (1ª derivada)`.
#     3.  `OPLS/OSC` para remover 1 ou 2 componentes ortogonais a `y`.
# -   **`SNV_Detrend_SG_D1`**: Uma combinação de filtros independentes de `y`, mas que, por sua complexidade, é testada junto às outras cadeias:
#     1.  `SNV`.
#     2.  `Detrend` para remoção de tendência.
#     3.  `Savitzky-Golay (1ª derivada)`.

# %%
# Implementação dos filtros de pré-processamento
# Filtros independentes de y

def msc(X):
    """Multiplicative Scatter Correction."""
    X = np.asarray(X)
    mean_spectrum = np.mean(X, axis=0)
    corrected_spectra = np.zeros_like(X)
    for i in range(X.shape[0]):
        slope, intercept = np.polyfit(mean_spectrum, X[i, :], 1)
        corrected_spectra[i, :] = (X[i, :] - intercept) / slope
    return corrected_spectra

def snv(X):
    """Standard Normal Variate."""
    X = np.asarray(X)
    return (X - np.mean(X, axis=1, keepdims=True)) / np.std(X, axis=1, keepdims=True)

def savitzky_golay(X, window_size=11, poly_order=2, deriv_order=1):
    """Savitzky-Golay filter."""
    return savgol_filter(X, window_length=window_size, polyorder=poly_order, deriv=deriv_order, axis=1)

def detrend_filter(X):
    """Detrending filter."""
    return detrend(X, axis=1)

def normalize(X):
    """Normalização Min-Max."""
    return (X - np.min(X, axis=1, keepdims=True)) / (np.max(X, axis=1, keepdims=True) - np.min(X, axis=1, keepdims=True))

def emsc(X, reference=None):
    """Extended Multiplicative Signal Correction."""
    X = np.asarray(X)
    if reference is None:
        reference = np.mean(X, axis=0)  # Usa o espectro médio como referência
    
    X_corr = np.zeros_like(X)
    for i in range(X.shape[0]):
        # Modelo: X[i] ≈ a + b*reference
        model = np.vstack([np.ones_like(reference), reference]).T
        params, _, _, _ = np.linalg.lstsq(model, X[i, :], rcond=None)
        a, b = params[0], params[1]
        X_corr[i,:] = (X[i, :] - a) / b
    return X_corr

def continuum_removal(X, wavelengths):
    """Continuum Removal."""
    X = np.asarray(X)
    X_cr = np.zeros_like(X)
    for i in range(X.shape[0]):
        spectrum = X[i, :]
        # Encontra os pontos do casco convexo superior
        q_u = [0]
        for k in range(1, len(wavelengths) - 1):
            s_k = (spectrum[len(wavelengths)-1] - spectrum[0]) / (wavelengths[-1] - wavelengths[0])
            s_q = (spectrum[k] - spectrum[q_u[-1]]) / (wavelengths[k] - wavelengths[q_u[-1]])
            if s_q > s_k:
                q_u.append(k)
        q_u.append(len(wavelengths)-1)
        
        # Interpolação linear entre os pontos do casco
        continuum = np.interp(wavelengths, wavelengths[q_u], spectrum[q_u])
        X_cr[i, :] = spectrum / continuum
    return X_cr

def wavelet_denoising(X, wavelet='db4', level=4):
    """Wavelet Transform para Denoising."""
    X = np.asarray(X)
    original_length = X.shape[1]
    denoised_list = []

    for i in range(X.shape[0]):
        # 1. Decomposição Wavelet
        coeffs = pywt.wavedec(X[i, :], wavelet, level=level)

        # 2. Cálculo do limiar (threshold)
        sigma = np.median(np.abs(coeffs[-1])) / 0.6745
        threshold = sigma * np.sqrt(2 * np.log(original_length))

        # 3. Aplicação do filtro (soft thresholding) nos coeficientes de detalhe
        coeffs[1:] = [pywt.threshold(c, value=threshold, mode='soft') for c in coeffs[1:]]

        # 4. Reconstrução do sinal
        reconstructed_signal = pywt.waverec(coeffs, wavelet)

        # 5. Ajuste do tamanho
        denoised_list.append(reconstructed_signal[:original_length])

    return np.asarray(denoised_list)

# Filtros dependentes de y (Orthogonal Signal Correction)
class OrthogonalCorrection:
    """Orthogonal Signal Correction (OSC)."""
    def __init__(self, n_components=1):
        self.n_components = n_components
    
    def fit_transform(self, X, y):
        X, y = np.asarray(X), np.asarray(y).ravel()
        self.w_ortho_ = []
        self.p_ortho_ = []
        self.X_corr_ = X.copy()
        
        for _ in range(self.n_components):
            pls = PLSRegression(n_components=1)
            pls.fit(self.X_corr_, y)
            t = pls.x_scores_
            w = pls.x_weights_
            p = pls.x_loadings_
            
            # Componente Ortogonal
            w_ortho = p - (np.dot(w.T, p) / np.dot(w.T, w)) * w
            t_ortho = np.dot(self.X_corr_, w_ortho)
            p_ortho = np.dot(t_ortho.T, self.X_corr_) / np.dot(t_ortho.T, t_ortho)
            
            # Remover variação ortogonal
            self.X_corr_ -= np.dot(t_ortho, p_ortho)
            self.w_ortho_.append(w_ortho)
            self.p_ortho_.append(p_ortho)
        
        return self.X_corr_
    
    def transform(self, X):
        X_res = np.asarray(X).copy()
        for i in range(self.n_components):
            t_ortho = np.dot(X_res, self.w_ortho_[i])
            X_res -= np.dot(t_ortho, self.p_ortho_[i])
        return X_res

# Dicionário de filtros independentes de y
filtros_independentes = {
    'Raw': lambda X: X,
    'MSC': msc,
    'SNV': snv,
    'SG_D1': lambda X: savitzky_golay(X, window_size=11, poly_order=2, deriv_order=1),
    'SG_D2': lambda X: savitzky_golay(X, window_size=11, poly_order=2, deriv_order=2),
    'Detrend': detrend_filter,
    'Normalize': normalize,
    'EMSC': emsc,
    'Continuum_Removal': lambda X: continuum_removal(X, wavelength_values),
    'Wavelet_Denoising': wavelet_denoising
}

# Dicionário de filtros dependentes de y
filtros_dependentes = {
    'OSC_1': lambda X, y: OrthogonalCorrection(n_components=1).fit_transform(X, y),
    'OSC_2': lambda X, y: OrthogonalCorrection(n_components=2).fit_transform(X, y),
    'MSC_SG_OSC': lambda X, y: OrthogonalCorrection(n_components=1).fit_transform(
        savitzky_golay(msc(X), window_size=11, poly_order=2, deriv_order=1), y),
    'OPLS1_SNV_SG_D1': lambda X, y: OrthogonalCorrection(n_components=1).fit_transform(
        savitzky_golay(snv(X), window_size=11, poly_order=2, deriv_order=1), y),
    'OPLS2_SNV_SG_D1': lambda X, y: OrthogonalCorrection(n_components=2).fit_transform(
        savitzky_golay(snv(X), window_size=11, poly_order=2, deriv_order=1), y),
    'SNV_Detrend_SG_D1': lambda X, y: savitzky_golay(detrend_filter(snv(X)), window_size=11, poly_order=2, deriv_order=1)
}

print(f'Filtros independentes de y: {list(filtros_independentes.keys())}')
print(f'Filtros dependentes de y: {list(filtros_dependentes.keys())}')
print(f'Total de filtros: {len(filtros_independentes) + len(filtros_dependentes)}')
# Out:
# Filtros independentes de y: ['Raw', 'MSC', 'SNV', 'SG_D1', 'SG_D2', 'Detrend', 'Normalize', 'EMSC', 'Continuum_Removal', 'Wavelet_Denoising']
# Filtros dependentes de y: ['OSC_1', 'OSC_2', 'MSC_SG_OSC', 'OPLS1_SNV_SG_D1', 'OPLS2_SNV_SG_D1', 'SNV_Detrend_SG_D1']
# Total de filtros: 16

# %% [markdown]
# ## 4. Remoção de Outliers Espectrais (PCA, T²/Q)

# %% [markdown]
# Outliers espectrais são amostras cujo espectro é muito diferente do resto da população, podendo ser causados por erros de medição, contaminação ou características únicas da amostra. Eles podem prejudicar significativamente a capacidade de generalização do modelo.
# - **Método PCA (T²/Q):** Usamos a Análise de Componentes Principais (PCA) para identificar esses outliers.
#     - **Estatística T² (Hotelling's T²):** Mede a variação de uma amostra *dentro* do modelo PCA. Valores altos indicam que a amostra é um outlier na combinação das variáveis principais.
#     - **Estatística Q (Resíduos):** Mede a variação da amostra *fora* do modelo PCA (o que o modelo não conseguiu capturar). Valores altos indicam que a estrutura do espectro da amostra é anormal.
# - **Lógica:** Uma amostra é considerada outlier se seu valor de T² ou Q ultrapassa um limite de confiança (geralmente 3 desvios padrão da média).
# - **Importante:** A remoção de outliers é feita **apenas no conjunto de calibração**. O conjunto de validação deve permanecer intacto para simular dados "reais" que o modelo encontrará no futuro.

# %%
def pca_outlier_removal(X, n_components=10, threshold=3):
    """Remove outliers usando PCA com estatísticas T² e Q."""
    # Padronizar dados
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # Aplicar PCA
    pca = PCA(n_components=n_components)
    X_pca = pca.fit_transform(X_scaled)
    
    # Calcular estatística T² (Hotelling's T²)
    T2 = np.sum((X_pca / np.std(X_pca, axis=0)) ** 2, axis=1)
    
    # Calcular estatística Q (resíduos)
    X_reconstructed = pca.inverse_transform(X_pca)
    Q = np.sum((X_scaled - X_reconstructed) ** 2, axis=1)
    
    # Definir limites (média + threshold * desvio padrão)
    T2_limit = np.mean(T2) + threshold * np.std(T2)
    Q_limit = np.mean(Q) + threshold * np.std(Q)
    
    # Identificar outliers
    outliers_mask = (T2 > T2_limit) | (Q > Q_limit)
    
    # Retornamos a máscara de quem NÃO é outlier e o modelo PCA treinado
    return ~outliers_mask, pca, T2, Q, T2_limit, Q_limit

dados_pca = {}

#para todo o conjunto de dado e não separado em cal e val
for atributo in atributos:
    X_full = dados_completos[atributo]['X']
    y_full = dados_completos[atributo]['y']
    indices_orig_full = dados_completos[atributo]['indices_orig']
    
    # Chama a função de remoção de outliers espectrais
    keep_mask, pca_model, T2, Q, T2_limit, Q_limit = pca_outlier_removal(X_full)
    
    # Identifica e informa os outliers removidos
    outliers_indices = indices_orig_full[~keep_mask]
    print(f'{atributo}: {len(outliers_indices)} outliers espectrais removidos.')
    if len(outliers_indices) > 0:
        print(f'  Índices Originais Removidos: {outliers_indices}')
    
    # Filtra os dados
    X_clean = X_full[keep_mask]
    y_clean = y_full[keep_mask]
    indices_orig_clean = indices_orig_full[keep_mask]
    
    dados_pca[atributo] = {
        'X': X_clean,
        'y': y_clean,
        'indices_orig': indices_orig_clean,
        'pca_model': pca_model,
        'T2': T2,
        'Q': Q,
        'T2_limit': T2_limit,
        'Q_limit': Q_limit,
        'keep_mask': keep_mask
    }
    
    print(f'  Dataset final: {X_clean.shape[0]} amostras')
    print()
# Out:
# Firmness (N): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [23 33 35]
#   Dataset final: 57 amostras
#
# Dry Mass (%): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [23 33 35]
#   Dataset final: 57 amostras
#
# TSS (Brix): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [23 33 35]
#   Dataset final: 57 amostras
#
# TA (g/mL): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [23 33 35]
#   Dataset final: 57 amostras
#
# AA (mg/100g): 3 outliers espectrais removidos.
#   Índices Originais Removidos: [23 33 35]
#   Dataset final: 57 amostras

# %% [markdown]
# ### 4.1 Gráficos de Outliers T² e Q

# %%
# Plotagem dos gráficos de outliers PCA
for atributo in atributos:
    d = dados_pca[atributo]
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    
    # Gráfico 1: Variância explicada cumulativa
    # Acessa o modelo PCA com a chave correta 'pca_model'

    cumulative_variance = np.cumsum(d['pca_model'].explained_variance_ratio_)
    axes[0].plot(range(1, len(cumulative_variance) + 1), cumulative_variance, 'o-', linewidth=2, markersize=6)
    axes[0].set_xlabel('Número de Componentes Principais')
    axes[0].set_ylabel('Variância Explicada Cumulativa')
    axes[0].set_title(f'Variância Explicada - {atributo}')
    axes[0].grid(True, alpha=0.3)
    axes[0].axhline(y=0.95, color='r', linestyle='--', alpha=0.7, label='95%')
    axes[0].legend()
    
    # Gráfico 2: T² vs Q (detecção de outliers)
    # Acessa as variáveis T2, Q, T2_limit, Q_limit e keep_mask com as chaves corretas
    scatter = axes[1].scatter(d['T2'], d['Q'], c=d['keep_mask'], cmap='coolwarm', 
                              edgecolor='k', alpha=0.7, s=50)
    axes[1].axhline(d['Q_limit'], color='r', linestyle='--', linewidth=2, label=f'Q Limit: {d["Q_limit"]:.2f}')
    axes[1].axvline(d['T2_limit'], color='g', linestyle='--', linewidth=2, label=f'T² Limit: {d["T2_limit"]:.2f}')
    axes[1].set_xlabel("Hotelling's T²")
    axes[1].set_ylabel('Q Residual')
    axes[1].set_title(f'Detecção de Outliers - {atributo}')
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    
    # Adicionar legenda de cores
    legend1 = axes[1].legend(*scatter.legend_elements(), title="Status")
    axes[1].add_artist(legend1)
    
    plt.tight_layout()
    
    # Salvar gráfico
    nome_arquivo = f'graficos_outliers_pca/pca_outliers_{atributo.replace(" ", "_").replace("(", "").replace(")", "").replace("/", "_")}.png'
    plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f'Gráficos de outliers PCA para {atributo} salvos em: {nome_arquivo}')
    print()
# Out:
# Gráficos de outliers PCA para Firmness (N) salvos em: graficos_outliers_pca/pca_outliers_Firmness_N.png
# Gráficos de outliers PCA para Dry Mass (%) salvos em: graficos_outliers_pca/pca_outliers_Dry_Mass_%.png
# Gráficos de outliers PCA para TSS (Brix) salvos em: graficos_outliers_pca/pca_outliers_TSS_Brix.png
# Gráficos de outliers PCA para TA (g/mL) salvos em: graficos_outliers_pca/pca_outliers_TA_g_mL.png
# Gráficos de outliers PCA para AA (mg/100g) salvos em: graficos_outliers_pca/pca_outliers_AA_mg_100g.png

# %% [markdown]
# ## 5. Remoção de Outliers dos Atributos (Boxplot + Seaborn)

# %% [markdown]
# Além dos outliers espectrais (em X), podemos ter outliers nos valores de referência (em y). Por exemplo, um valor de pH ou SST que é analiticamente improvável ou resultado de um erro de anotação.
# - **Método (IQR):** O método do Intervalo Interquartil (IQR) é uma forma estatística robusta de identificar esses pontos.
#     - `IQR = Q3 (percentil 75) - Q1 (percentil 25)`
#     - Um valor é considerado outlier se estiver abaixo de `Q1 - 1.5 * IQR` ou acima de `Q3 + 1.5 * IQR`.
# - **Visualização:** O `boxplot` é a ferramenta visual perfeita para essa análise, pois ele desenha os "bigodes" exatamente nesses limites de 1.5 * IQR, mostrando os outliers como pontos individuais.
# - **Ação:** Novamente, a remoção é feita apenas no conjunto de calibração.

# %%
# Remover outliers dos atributos usando boxplot e IQR

dados_final = {}

for atributo in atributos:
    # Pega os dados já limpos de outliers espectrais
    d = dados_pca[atributo]
    X_clean = d['X']
    y_clean = d['y']
    indices_orig_clean = d['indices_orig']
    
    # Boxplot
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=y_clean)
    sns.stripplot(x=y_clean, color='red', alpha=0.6)
    plt.title(f'Boxplot com Dispersão - {atributo}')
    
    nome_arquivo = f'graficos_outliers_boxplot/boxplot_outliers_{atributo.replace(" ", "_").replace("(", "").replace(")", "").replace("/", "_")}.png'
    plt.savefig(nome_arquivo, dpi=300, bbox_inches='tight')
    plt.show()

    # Lógica de remoção de outliers dos atributos
    Q1 = np.percentile(y_clean, 25)
    Q3 = np.percentile(y_clean, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    keep_mask_attr = (y_clean >= lower_bound) & (y_clean <= upper_bound)
    
    # Identifica e informa os outliers removidos
    outliers_attr_indices = indices_orig_clean[~keep_mask_attr]
    print(f'{atributo}: {len(outliers_attr_indices)} outliers de atributo removidos.')
    if len(outliers_attr_indices) > 0:
        print(f'  Índices Originais Removidos: {outliers_attr_indices}')
    
    # Armazena os dados finais e limpos para modelagem
    dados_final[atributo] = {
        'X': X_clean[keep_mask_attr],
        'y': y_clean[keep_mask_attr]
    }
    
    print(f'  Dataset final para modelagem: {dados_final[atributo]["X"].shape[0]} amostras')
    print()

print("Remoção de outliers concluída!")
# Out:
# Firmness (N): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 57 amostras
# Dry Mass (%): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 57 amostras
# TSS (Brix): 4 outliers de atributo removidos.
#   Índices Originais Removidos: [10 11 12 41]
#   Dataset final para modelagem: 53 amostras
# TA (g/mL): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 57 amostras
# AA (mg/100g): 0 outliers de atributo removidos.
#   Dataset final para modelagem: 57 amostras
#
# Remoção de outliers concluída!

# %%
# --- Função para o Gráfico de CALIBRAÇÃO (Ref vs Predito vs CV) ---
def save_calibration_plot(y_cal, y_pred_cal, y_pred_cv, atributo, filtro, modelo, file_path):
    """
    Gera e salva um gráfico comparando predições de treino e de validação cruzada
    no conjunto de calibração.
    """
    try:
        # Garante que o diretório exista
        os.makedirs(os.path.dirname(file_path), exist_ok=True)

        # Métricas para Predição no Treino Completo
        slope_pred, offset_pred = np.polyfit(y_cal, y_pred_cal, 1)
        rmse_pred = np.sqrt(mean_squared_error(y_cal, y_pred_cal))
        r2_pred = r2_score(y_cal, y_pred_cal)

        # Métricas para Predição da Validação Cruzada
        slope_cv, offset_cv = np.polyfit(y_cal, y_pred_cv, 1)
        rmse_cv = np.sqrt(mean_squared_error(y_cal, y_pred_cv))
        r2_cv = r2_score(y_cal, y_pred_cv)

        plt.figure(figsize=(10, 8))
        plt.scatter(y_cal, y_pred_cal, color='blue', marker='o', alpha=0.6, label=f'Predição no Treino (R²={r2_pred:.3f})')
        plt.scatter(y_cal, y_pred_cv, color='red', marker='x', alpha=0.7, label=f'Predição CV (R²={r2_cv:.3f})')
        
        # Linha ideal 1:1
        min_val = min(min(y_cal), min(y_pred_cal), min(y_pred_cv))
        max_val = max(max(y_cal), max(y_pred_cal), max(y_pred_cv))
        plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='Linha Ideal (1:1)')

        plt.xlabel("Valores Reais (Calibração)")
        plt.ylabel("Valores Preditos")
        plt.title(f'Desempenho na Calibração: {atributo} | {modelo} | {filtro}')
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.legend(loc='lower right')
        
        # Adiciona texto com métricas
        stats_text = (
            f'Treino - RMSE: {rmse_pred:.3f}, Slope: {slope_pred:.3f}, Offset: {offset_pred:.3f}\n'
            f'CV     - RMSE: {rmse_cv:.3f}, Slope: {slope_cv:.3f}, Offset: {offset_cv:.3f}'
        )
        plt.text(0.05, 0.95, stats_text, transform=plt.gca().transAxes, fontsize=10,
                 verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5))

        plt.savefig(file_path, format='png', dpi=200, bbox_inches='tight')
        plt.close()

    except Exception as e:
        print(f"Erro ao gerar gráfico de calibração para {modelo} com {filtro}: {e}")
        plt.close()


# --- Função para o Gráfico de VALIDAÇÃO (Predito vs Real) ---
def save_validation_plot(y_val, y_pred_val, atributo, filtro, modelo, file_path):
    """
    Gera e salva o gráfico de predições no conjunto de validação (teste).
    """
    try:
        # Garante que o diretório exista
        os.makedirs(os.path.dirname(file_path), exist_ok=True)
        
        # Métricas
        r2 = r2_score(y_val, y_pred_val)
        rmse = np.sqrt(mean_squared_error(y_val, y_pred_val))
        slope, offset = np.polyfit(y_val, y_pred_val, 1)

        plt.figure(figsize=(8, 8))
        plt.scatter(y_val, y_pred_val, alpha=0.7, edgecolors='k', label='Dados de Validação')
        
        # Linha ideal 1:1
        min_val = min(min(y_val), min(y_pred_val))
        max_val = max(max(y_val), max(y_pred_val))
        plt.plot([min_val, max_val], [min_val, max_val], 'r--', lw=2, label='Linha Ideal (1:1)')

        plt.xlabel('Valores Reais (Validação)')
        plt.ylabel('Valores Preditos')
        plt.title(f'Desempenho na Validação: {atributo} | {modelo} | {filtro}')
        plt.grid(True, linestyle='--', alpha=0.6)
        
        stats_text = f'R² = {r2:.4f}\nRMSE = {rmse:.4f}\nSlope = {slope:.4f}'
        plt.text(0.05, 0.95, stats_text, transform=plt.gca().transAxes, fontsize=12,
                 verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='lightblue', alpha=0.5))
        
        plt.legend()
        plt.savefig(file_path, format='png', dpi=200, bbox_inches='tight')
        plt.close()

    except Exception as e:
        print(f"Erro ao gerar gráfico de validação para {modelo} com {filtro}: {e}")
        plt.close()

# %% [markdown]
# ## 6. Avaliação dos Filtros e Seleção dos Melhores Modelos com Validação Cruzada

# %% [markdown]
# Nesta etapa crucial, construímos e avaliamos os modelos de regressão. Em vez de testar cada modelo separadamente, criamos um fluxo automatizado e exaustivo para garantir que encontremos a melhor performance possível.
# - **Estratégia:**
#     1. **Iteração por Atributo:** Um loop externo passa por cada variável alvo (AT, PH, etc.).
#     2. **Iteração por Modelo:** Para cada atributo, testamos uma lista de modelos quimiométricos:
#         - `PLSR`: Padrão da área, lida bem com multicolinearidade.
#         - `PCR`: Alternativa que primeiro reduz a dimensionalidade.
#         - `RFR` (Random Forest): Modelo não-linear, robusto e poderoso.
#         - `SVMR` (Support Vector Machine): Eficaz em espaços de alta dimensão.
#     3. **Iteração por Filtro:** Para cada modelo, aplicamos **todos os 16 filtros** de pré-processamento definidos na seção anterior.
#     4. **Otimização (GridSearchCV):** Para cada combinação `(atributo, modelo, filtro)`, usamos `GridSearchCV` com validação cruzada (10-fold) para encontrar os melhores hiperparâmetros do modelo (ex: número de componentes para PLS, parâmetros C e gamma para SVM).
# - **Avaliação:** O desempenho de cada combinação é medido pelo R² da validação cruzada. O melhor modelo é então treinado com todos os dados de calibração e sua performance final é avaliada no conjunto de validação, que foi mantido separado durante todo o processo.
# - **Saídas:** Ao final, teremos os resultados de centenas de modelos, permitindo uma comparação justa e a seleção do campeão para cada atributo. Todos os gráficos de predição e as métricas são salvos automaticamente.

# %%
def save_calibration_plot_cv(y_true, y_pred_cv, atributo, filtro, modelo, file_path):
 
    try:
        # Garante que o diretório exista
        os.makedirs(os.path.dirname(file_path), exist_ok=True)

        # Métricas para Predição da Validação Cruzada
        slope_cv, offset_cv = np.polyfit(y_true, y_pred_cv, 1)
        rmse_cv = np.sqrt(mean_squared_error(y_true, y_pred_cv))
        r2_cv = r2_score(y_true, y_pred_cv)

        plt.figure(figsize=(10, 8))
        plt.scatter(y_true, y_pred_cv, color='blue', marker='o', alpha=0.7, label=f'Cross-Validation (R²={r2_cv:.3f})')
        
        # Linha ideal 1:1
        min_val = min(min(y_true), min(y_pred_cv))
        max_val = max(max(y_true), max(y_pred_cv))
        plt.plot([min_val, max_val], [min_val, max_val], 'k--', label='Linha Ideal (1:1)')

        plt.xlabel("Valores Reais")
        plt.ylabel("Valores Preditos (CV)")
        plt.title(f'Cross-Validation: {atributo} | {modelo} | {filtro}')
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.legend(loc='lower right')
        
        # Adiciona texto com métricas
        stats_text = f'CV - R²: {r2_cv:.3f}, RMSE: {rmse_cv:.3f}, Slope: {slope_cv:.3f}, Offset: {offset_cv:.3f}'
        plt.text(0.05, 0.95, stats_text, transform=plt.gca().transAxes, fontsize=10,
                 verticalalignment='top', bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5))

        plt.savefig(file_path, format='png', dpi=200, bbox_inches='tight')
        plt.close()

    except Exception as e:
        print(f"Erro ao gerar gráfico de CV para {modelo} com {filtro}: {e}")
        plt.close()

# %% [markdown]
# ### 6.1 Modelos e Grids de Parâmetros

# %%
import re


modelos = {
    'PLSR': {
        'estimador': PLSRegression(),
        'params': {'n_components': [5, 10, 15, 20]}
    },
    'PCR': {
        'estimador': Pipeline([('pca', PCA()), ('regressor', LinearRegression())]),
        'params': {'pca__n_components': [5, 10, 15, 20]}
    },
    'SVMR': {
    'estimador': SVR(),
    'params': {
        'C': [0.1, 1, 10, 100],
        'gamma': ['scale', 'auto', 0.001, 0.01, 0.1],
        'kernel': ['rbf', 'linear'],
        'epsilon': [0.1, 0.2, 0.5, 1.0]
    }
    },
     'RFR': {
        'estimador': RandomForestRegressor(random_state=42),
        'params': {
            'n_estimators': [100, 150, 200, 250, 300],
            'max_depth': [10, 20, 30, None],
            'min_samples_split': [2, 5, 10],
            'min_samples_leaf': [1, 2, 4],
            'warm_start': [True, False],
            'bootstrap': [True, False]
        }
     }

}

# Combina todos os filtros
todos_filtros = {**filtros_independentes, **filtros_dependentes}

# Lista para armazenar todos os resultados
lista_resultados_finais = []

#AQUI COMEÇA O CROSS VALIDATION -- PRINCIPAIS ALTERAÇÕES DO CÓDIGO DE ANDRESSA

cv_folds = 10  # Número de folds para cross-validation
kf = KFold(n_splits=cv_folds, shuffle=True, random_state=42)

for atributo in atributos: #apenas para Firmness (N) e com RFR e SVMR grids menores
    print(f'\n{"="*30}')
    print(f'INICIANDO MODELAGEM PARA: {atributo}')
    print(f'{"="*30}')

    melhor_r2_atributo = -999  # Inicia com um valor muito baixo
    melhor_combinacao_info = {}  # Dicionário para guardar as infos do melhor
    
    # Dicionário para armazenar as 5 melhores combinações por modelo
    melhores_por_modelo = {nome: [] for nome in modelos.keys()}

    dados = dados_final[atributo]
    X_full, y_full = dados['X'], dados['y']

    for nome_modelo, info_modelo in modelos.items():
        print(f'\n--- Modelo: {nome_modelo} ---')
        
        combinacoes_deste_modelo = [] # Lista temporária para este modelo

        for nome_filtro, funcao_filtro in todos_filtros.items():
            start_time = time.time()
            print(f'  Testando filtro: {nome_filtro}...', end='')

            if nome_filtro in filtros_independentes:
                X_filtered = funcao_filtro(X_full)
                tipo_filtro = 'independente'
            else:  # Filtro dependente de Y
                X_filtered = funcao_filtro(X_full, y_full)
                tipo_filtro = 'dependente'
            
            grid = GridSearchCV(
                info_modelo['estimador'], 
                info_modelo['params'], 
                cv=kf,  # Usa o mesmo KFold para consistência
                scoring='r2', 
                n_jobs=-1
            )
            grid.fit(X_filtered, y_full)
            
            melhor_modelo = grid.best_estimator_
            
            cv_scores = cross_val_score(melhor_modelo, X_filtered, y_full, cv=kf, scoring='r2')
            cv_r2_mean = cv_scores.mean()
            cv_r2_std = cv_scores.std()
            
            # Predições de cross-validation para plotagem
            y_pred_cv = cross_val_predict(melhor_modelo, X_filtered, y_full, cv=kf)
            cv_rmse = np.sqrt(mean_squared_error(y_full, y_pred_cv))
            
            end_time = time.time()
            print(f' CV R²: {cv_r2_mean:.4f} (±{cv_r2_std:.4f}) | Concluído em {end_time - start_time:.2f}s')

            # Salvar o resultado da combinação atual
            resultados_atuais = {
                'Atributo': atributo,
                'Modelo': nome_modelo,
                'Filtro': nome_filtro,
                'Tipo_Filtro': tipo_filtro,
                'CV_R2_Mean': cv_r2_mean,
                'CV_R2_Std': cv_r2_std,
                'CV_RMSE': cv_rmse,
                'Grid_Best_Score': grid.best_score_,
                'Melhores_Params': str(grid.best_params_),
                'Tempo_s': end_time - start_time,
                'objeto_modelo': melhor_modelo 
            }
            
            lista_resultados_finais.append(resultados_atuais)
            combinacoes_deste_modelo.append(resultados_atuais)

            # Lógica para salvar o melhor modelo geral
            if cv_r2_mean > melhor_r2_atributo:
                melhor_r2_atributo = cv_r2_mean
                melhor_combinacao_info = {
                    'objeto_modelo': melhor_modelo,
                    'nome_modelo': nome_modelo,
                    'nome_filtro': nome_filtro,
                    'parametros': grid.best_params_
                }
            atributo_limpo = re.sub(r"[ \/\[\]\(\)]", "_", atributo)
            path_cv = f'graficos_modelos/cross_validation/{atributo_limpo}_{nome_modelo}_{nome_filtro}.png'
            os.makedirs('graficos_modelos/cross_validation', exist_ok=True)
            save_calibration_plot_cv(y_full, y_pred_cv, atributo, nome_filtro, nome_modelo, path_cv)

        # Ordenar e salvar as 5 melhores para este modelo
        combinacoes_deste_modelo.sort(key=lambda x: x['CV_R2_Mean'], reverse=True)
        melhores_por_modelo[nome_modelo] = combinacoes_deste_modelo[:5]
        atributo_limpo = re.sub(r"[ \/\[\]\(\)]", "_", atributo)

    if melhor_combinacao_info:  # Garante que encontrou pelo menos um modelo
        melhor_obj = melhor_combinacao_info['objeto_modelo']
        nome_arquivo_modelo = f"modelos_salvos/melhor_modelo_{atributo_limpo}.joblib"
        
        joblib.dump(melhor_obj, nome_arquivo_modelo)
        
        print(f"\n 🏆 MELHOR COMBINAÇÃO GERAL PARA '{atributo}' FOI SALVA!")
        print(f"   - Arquivo: {nome_arquivo_modelo}")
        print(f"   - Modelo: {melhor_combinacao_info['nome_modelo']}")
        print(f"   - Filtro: {melhor_combinacao_info['nome_filtro']}")
        print(f"   - Melhor R² CV: {melhor_r2_atributo:.4f}")
        print(f"   - Melhores Parâmetros: {melhor_combinacao_info['parametros']}")
    
    # Salvar os 5 melhores modelos para cada tipo
    print(f"\n--- Salvando os 5 melhores modelos para {atributo} ---")
    for nome_modelo, lista_combinacoes in melhores_por_modelo.items():
        for i, combinacao in enumerate(lista_combinacoes):
            nome_arquivo = f"modelos_salvos_top5/top_{i+1}_{atributo_limpo}_{combinacao['Modelo']}_{combinacao['Filtro']}.joblib"
            os.makedirs('modelos_salvos_top5', exist_ok=True)
            joblib.dump(combinacao['objeto_modelo'], nome_arquivo)
            print(f"  - Top {i+1} do modelo {nome_modelo} salvo em: {nome_arquivo}")

print('\n\n ✅ Modelagem exaustiva com Cross-Validation!')

df_completo = pd.DataFrame(lista_resultados_finais)
df_completo_ordenado = df_completo.sort_values(by=['Atributo', 'CV_R2_Mean'], ascending=[True, False])
df_completo_ordenado.to_excel('analise_completa_resultados_cv.xlsx', index=False)
print('  ✅Resultados salvos em "analise_completa_resultados_cv.xlsx"')

print("\n--- Melhores Resultados por Atributo (Cross-Validation) ---")
melhores_resultados = df_completo_ordenado.groupby('Atributo').first().reset_index()

# Arredondar colunas numéricas para melhor visualização
colunas_numericas_para_arredondar = ['CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE', 'Grid_Best_Score']
melhores_resultados[colunas_numericas_para_arredondar] = melhores_resultados[colunas_numericas_para_arredondar].round(4)

# Selecionar e exibir as colunas mais importantes
colunas_para_exibir = ['Atributo', 'Modelo', 'Filtro', 'CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE', 'Melhores_Params']
print(melhores_resultados[colunas_para_exibir].to_string(index=False))
# Out:
# ==============================
# INICIANDO MODELAGEM PARA: Firmness (N)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.9080 (±0.0762) | Concluído em 0.12s
#   Testando filtro: MSC... CV R²: 0.9144 (±0.0622) | Concluído em 0.12s
#   Testando filtro: SNV... CV R²: 0.9102 (±0.0664) | Concluído em 0.12s
#   Testando filtro: SG_D1... CV R²: 0.9015 (±0.0479) | Concluído em 0.10s
#   Testando filtro: SG_D2... CV R²: 0.9029 (±0.0400) | Concluído em 0.09s
#   Testando filtro: Detrend... CV R²: 0.9108 (±0.0506) | Concluído em 0.12s
#   Testando filtro: Normalize... CV R²: 0.9104 (±0.0573) | Concluído em 0.10s
#   Testando filtro: EMSC... CV R²: 0.9144 (±0.0622) | Concluído em 0.12s
#   Testando filtro: Continuum_Removal... CV R²: 0.8929 (±0.0491) | Concluído em 0.26s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.9069 (±0.0771) | Concluído em 0.13s
#   Testando filtro: OSC_1... CV R²: 0.9089 (±0.0636) | Concluído em 0.12s
#   Testando filtro: OSC_2... CV R²: 0.9083 (±0.0609) | Concluído em 0.11s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.9098 (±0.0568) | Concluído em 0.09s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.9107 (±0.0563) | Concluído em 0.09s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.8506 (±0.1011) | Concluído em 0.09s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.9090 (±0.0485) | Concluído em 0.11s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.8657 (±0.0535) | Concluído em 0.18s
#   Testando filtro: MSC... CV R²: 0.9135 (±0.0743) | Concluído em 0.17s
#   Testando filtro: SNV... CV R²: 0.8793 (±0.0759) | Concluído em 0.16s
#   Testando filtro: SG_D1... CV R²: 0.8956 (±0.0835) | Concluído em 0.13s
#   Testando filtro: SG_D2... CV R²: 0.6917 (±0.2196) | Concluído em 0.17s
#   Testando filtro: Detrend... CV R²: 0.9069 (±0.0808) | Concluído em 0.17s
#   Testando filtro: Normalize... CV R²: 0.8908 (±0.0795) | Concluído em 0.17s
#   Testando filtro: EMSC... CV R²: 0.9136 (±0.0742) | Concluído em 0.19s
#   Testando filtro: Continuum_Removal... CV R²: 0.9012 (±0.0452) | Concluído em 0.30s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.8657 (±0.0535) | Concluído em 0.14s
#   Testando filtro: OSC_1... CV R²: 0.8714 (±0.0795) | Concluído em 0.17s
#   Testando filtro: OSC_2... CV R²: 0.9124 (±0.0560) | Concluído em 0.18s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.9095 (±0.0590) | Concluído em 0.18s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.9097 (±0.0591) | Concluído em 0.18s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.8814 (±0.0746) | Concluído em 0.17s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.8998 (±0.0614) | Concluído em 0.17s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.8677 (±0.0572) | Concluído em 0.61s
#   Testando filtro: MSC... CV R²: 0.8543 (±0.0952) | Concluído em 0.59s
#   Testando filtro: SNV... CV R²: 0.9139 (±0.0688) | Concluído em 0.63s
#   Testando filtro: SG_D1... CV R²: 0.5222 (±0.3356) | Concluído em 0.59s
#   Testando filtro: SG_D2... CV R²: 0.6327 (±0.2327) | Concluído em 0.59s
#   Testando filtro: Detrend... CV R²: 0.8631 (±0.0799) | Concluído em 0.60s
#   Testando filtro: Normalize... CV R²: 0.8298 (±0.1098) | Concluído em 0.60s
#   Testando filtro: EMSC... CV R²: 0.8543 (±0.0952) | Concluído em 0.60s
#   Testando filtro: Continuum_Removal... CV R²: 0.8446 (±0.0729) | Concluído em 0.73s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.8673 (±0.0572) | Concluído em 0.61s
#   Testando filtro: OSC_1... CV R²: 0.8736 (±0.0770) | Concluído em 0.59s
#   Testando filtro: OSC_2... CV R²: 0.9279 (±0.0278) | Concluído em 0.60s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.8370 (±0.1739) | Concluído em 0.60s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.8321 (±0.1818) | Concluído em 0.59s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.9187 (±0.0618) | Concluído em 0.60s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.5667 (±0.3304) | Concluído em 0.59s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.9435 (±0.0608) | Concluído em 1129.53s
#   Testando filtro: MSC... CV R²: 0.6696 (±0.3678) | Concluído em 1125.88s
#   Testando filtro: SNV... CV R²: 0.6618 (±0.3185) | Concluído em 1143.39s
#   Testando filtro: SG_D1... CV R²: 0.9276 (±0.0989) | Concluído em 1147.90s
#   Testando filtro: SG_D2... CV R²: 0.7659 (±0.1666) | Concluído em 1164.83s
#   Testando filtro: Detrend... CV R²: 0.9452 (±0.0572) | Concluído em 1123.04s
#   Testando filtro: Normalize... CV R²: 0.8081 (±0.2438) | Concluído em 1135.68s
#   Testando filtro: EMSC... CV R²: 0.6696 (±0.3678) | Concluído em 1126.76s
#   Testando filtro: Continuum_Removal... CV R²: 0.9543 (±0.0357) | Concluído em 1118.89s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.9422 (±0.0646) | Concluído em 1082.05s
#   Testando filtro: OSC_1... CV R²: 0.9498 (±0.0375) | Concluído em 1125.75s
#   Testando filtro: OSC_2... CV R²: 0.9466 (±0.0408) | Concluído em 1108.43s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.8860 (±0.0948) | Concluído em 1079.49s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.8878 (±0.0953) | Concluído em 1073.49s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.9265 (±0.0707) | Concluído em 1123.74s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.9213 (±0.0912) | Concluído em 1178.14s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Firmness (N)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Firmness__N_.joblib
#    - Modelo: RFR
#    - Filtro: Continuum_Removal
#    - Melhor R² CV: 0.9543
#    - Melhores Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300, 'warm_start': True}
#
# --- Salvando os 5 melhores modelos para Firmness (N) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Firmness__N__PLSR_MSC.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Firmness__N__PLSR_EMSC.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Firmness__N__PLSR_Detrend.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Firmness__N__PLSR_OPLS1_SNV_SG_D1.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Firmness__N__PLSR_Normalize.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Firmness__N__PCR_EMSC.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Firmness__N__PCR_MSC.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Firmness__N__PCR_OSC_2.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Firmness__N__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Firmness__N__PCR_MSC_SG_OSC.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Firmness__N__SVMR_OSC_2.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Firmness__N__SVMR_OPLS2_SNV_SG_D1.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Firmness__N__SVMR_SNV.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Firmness__N__SVMR_OSC_1.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Firmness__N__SVMR_Raw.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Firmness__N__RFR_Continuum_Removal.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Firmness__N__RFR_OSC_1.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Firmness__N__RFR_OSC_2.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Firmness__N__RFR_Detrend.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Firmness__N__RFR_Raw.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: Dry Mass (%)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.1201 (±0.5808) | Concluído em 0.09s
#   Testando filtro: MSC... CV R²: 0.1794 (±0.3994) | Concluído em 0.09s
#   Testando filtro: SNV... CV R²: 0.2016 (±0.4034) | Concluído em 0.09s
#   Testando filtro: SG_D1... CV R²: 0.0735 (±0.6772) | Concluído em 0.09s
#   Testando filtro: SG_D2... CV R²: 0.1381 (±0.4099) | Concluído em 0.09s
#   Testando filtro: Detrend... CV R²: 0.1651 (±0.4416) | Concluído em 0.09s
#   Testando filtro: Normalize... CV R²: 0.0894 (±0.4669) | Concluído em 0.09s
#   Testando filtro: EMSC... CV R²: 0.1794 (±0.3994) | Concluído em 0.09s
#   Testando filtro: Continuum_Removal... CV R²: 0.2112 (±0.5476) | Concluído em 0.21s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.1201 (±0.5809) | Concluído em 0.09s
#   Testando filtro: OSC_1... CV R²: 0.2464 (±0.1969) | Concluído em 0.08s
#   Testando filtro: OSC_2... CV R²: 0.2176 (±0.3498) | Concluído em 0.09s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.1224 (±0.4772) | Concluído em 0.09s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.1169 (±0.5004) | Concluído em 0.09s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.0345 (±0.6573) | Concluído em 0.09s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.0407 (±0.5841) | Concluído em 0.23s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.2189 (±0.2402) | Concluído em 0.15s
#   Testando filtro: MSC... CV R²: 0.2705 (±0.3415) | Concluído em 0.17s
#   Testando filtro: SNV... CV R²: 0.2335 (±0.2161) | Concluído em 0.14s
#   Testando filtro: SG_D1... CV R²: 0.4006 (±0.2352) | Concluído em 0.15s
#   Testando filtro: SG_D2... CV R²: -0.0314 (±0.5004) | Concluído em 0.15s
#   Testando filtro: Detrend... CV R²: 0.2535 (±0.3836) | Concluído em 0.17s
#   Testando filtro: Normalize... CV R²: 0.2276 (±0.2679) | Concluído em 0.13s
#   Testando filtro: EMSC... CV R²: 0.2701 (±0.3422) | Concluído em 0.17s
#   Testando filtro: Continuum_Removal... CV R²: 0.2034 (±0.4556) | Concluído em 0.29s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.2198 (±0.2396) | Concluído em 0.15s
#   Testando filtro: OSC_1... CV R²: 0.2793 (±0.2098) | Concluído em 0.13s
#   Testando filtro: OSC_2... CV R²: 0.2597 (±0.3531) | Concluído em 0.15s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.3536 (±0.3507) | Concluído em 0.15s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.3533 (±0.3505) | Concluído em 0.15s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.3011 (±0.3700) | Concluído em 0.15s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.3557 (±0.3180) | Concluído em 0.17s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.3262 (±0.1833) | Concluído em 0.69s
#   Testando filtro: MSC... CV R²: 0.3874 (±0.1691) | Concluído em 0.61s
#   Testando filtro: SNV... CV R²: 0.3928 (±0.2616) | Concluído em 0.64s
#   Testando filtro: SG_D1... CV R²: 0.3857 (±0.1744) | Concluído em 0.60s
#   Testando filtro: SG_D2... CV R²: 0.0968 (±0.5406) | Concluído em 0.60s
#   Testando filtro: Detrend... CV R²: 0.3478 (±0.1585) | Concluído em 0.61s
#   Testando filtro: Normalize... CV R²: 0.3923 (±0.2278) | Concluído em 0.62s
#   Testando filtro: EMSC... CV R²: 0.3874 (±0.1691) | Concluído em 0.60s
#   Testando filtro: Continuum_Removal... CV R²: 0.2905 (±0.3515) | Concluído em 0.72s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.3184 (±0.1883) | Concluído em 0.70s
#   Testando filtro: OSC_1... CV R²: 0.3691 (±0.1695) | Concluído em 0.88s
#   Testando filtro: OSC_2... CV R²: 0.3195 (±0.2911) | Concluído em 0.59s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.3282 (±0.4358) | Concluído em 0.59s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.3132 (±0.4454) | Concluído em 0.60s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.2788 (±0.3534) | Concluído em 0.59s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.4073 (±0.2096) | Concluído em 0.60s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.1085 (±0.2636) | Concluído em 1177.47s
#   Testando filtro: MSC... CV R²: 0.2206 (±0.2143) | Concluído em 1155.89s
#   Testando filtro: SNV... CV R²: 0.2016 (±0.3056) | Concluído em 1085.89s
#   Testando filtro: SG_D1... CV R²: 0.3220 (±0.3281) | Concluído em 1073.35s
#   Testando filtro: SG_D2... CV R²: 0.2984 (±0.5044) | Concluído em 1083.98s
#   Testando filtro: Detrend... CV R²: 0.0533 (±0.3475) | Concluído em 1122.49s
#   Testando filtro: Normalize... CV R²: 0.0998 (±0.2841) | Concluído em 1125.71s
#   Testando filtro: EMSC... CV R²: 0.2206 (±0.2143) | Concluído em 1158.62s
#   Testando filtro: Continuum_Removal... CV R²: 0.2226 (±0.3798) | Concluído em 1080.37s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.1208 (±0.2664) | Concluído em 1101.42s
#   Testando filtro: OSC_1... CV R²: 0.2893 (±0.3163) | Concluído em 1195.96s
#   Testando filtro: OSC_2... CV R²: 0.2586 (±0.5083) | Concluído em 1062.48s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.3073 (±0.3151) | Concluído em 1105.26s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.2863 (±0.2985) | Concluído em 1095.74s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.2993 (±0.6433) | Concluído em 1037.61s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.3377 (±0.3548) | Concluído em 1173.67s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'Dry Mass (%)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_Dry_Mass__%_.joblib
#    - Modelo: SVMR
#    - Filtro: SNV_Detrend_SG_D1
#    - Melhor R² CV: 0.4073
#    - Melhores Parâmetros: {'C': 100, 'epsilon': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
#
# --- Salvando os 5 melhores modelos para Dry Mass (%) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_Dry_Mass__%__PLSR_OSC_1.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_Dry_Mass__%__PLSR_OSC_2.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_Dry_Mass__%__PLSR_Continuum_Removal.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_Dry_Mass__%__PLSR_SNV.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_Dry_Mass__%__PLSR_EMSC.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_Dry_Mass__%__PCR_SG_D1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_Dry_Mass__%__PCR_SNV_Detrend_SG_D1.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_Dry_Mass__%__PCR_MSC_SG_OSC.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_Dry_Mass__%__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_Dry_Mass__%__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_Dry_Mass__%__SVMR_SNV_Detrend_SG_D1.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_Dry_Mass__%__SVMR_SNV.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_Dry_Mass__%__SVMR_Normalize.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_Dry_Mass__%__SVMR_EMSC.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_Dry_Mass__%__SVMR_MSC.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_Dry_Mass__%__RFR_SNV_Detrend_SG_D1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_Dry_Mass__%__RFR_SG_D1.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_Dry_Mass__%__RFR_MSC_SG_OSC.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_Dry_Mass__%__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_Dry_Mass__%__RFR_SG_D2.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: TSS (Brix)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: -0.2736 (±1.6955) | Concluído em 0.08s
#   Testando filtro: MSC... CV R²: -0.4887 (±1.9110) | Concluído em 0.08s
#   Testando filtro: SNV... CV R²: -0.5012 (±1.8721) | Concluído em 0.07s
#   Testando filtro: SG_D1... CV R²: -0.5955 (±1.7494) | Concluído em 0.08s
#   Testando filtro: SG_D2... CV R²: -0.0309 (±0.6540) | Concluído em 0.08s
#   Testando filtro: Detrend... CV R²: -0.2402 (±1.5971) | Concluído em 0.07s
#   Testando filtro: Normalize... CV R²: -0.4406 (±1.7840) | Concluído em 0.08s
#   Testando filtro: EMSC... CV R²: -0.4887 (±1.9110) | Concluído em 0.07s
#   Testando filtro: Continuum_Removal... CV R²: -0.5871 (±1.6783) | Concluído em 0.19s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.2736 (±1.6955) | Concluído em 0.08s
#   Testando filtro: OSC_1... CV R²: -0.4949 (±1.9100) | Concluído em 0.08s
#   Testando filtro: OSC_2... CV R²: -0.5330 (±1.7343) | Concluído em 0.08s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.5283 (±1.5932) | Concluído em 0.08s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.6356 (±1.7110) | Concluído em 0.08s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.7738 (±1.7372) | Concluído em 0.08s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: -0.6197 (±1.4131) | Concluído em 0.09s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: -0.2261 (±1.6733) | Concluído em 0.12s
#   Testando filtro: MSC... CV R²: -0.3456 (±1.2376) | Concluído em 0.15s
#   Testando filtro: SNV... CV R²: -0.4073 (±1.2414) | Concluído em 0.16s
#   Testando filtro: SG_D1... CV R²: -0.0550 (±1.4014) | Concluído em 0.13s
#   Testando filtro: SG_D2... CV R²: -0.1311 (±0.5837) | Concluído em 0.15s
#   Testando filtro: Detrend... CV R²: -0.2026 (±1.5480) | Concluído em 0.12s
#   Testando filtro: Normalize... CV R²: -0.3973 (±1.3532) | Concluído em 0.16s
#   Testando filtro: EMSC... CV R²: -0.3456 (±1.2384) | Concluído em 0.16s
#   Testando filtro: Continuum_Removal... CV R²: -0.4234 (±1.3386) | Concluído em 0.26s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.2261 (±1.6734) | Concluído em 0.11s
#   Testando filtro: OSC_1... CV R²: -0.2354 (±1.0397) | Concluído em 0.15s
#   Testando filtro: OSC_2... CV R²: -0.1978 (±1.0877) | Concluído em 0.16s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.0866 (±1.0906) | Concluído em 0.13s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.0897 (±1.0762) | Concluído em 0.12s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.0350 (±0.9638) | Concluído em 0.33s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.0399 (±1.2523) | Concluído em 0.13s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.1066 (±0.5551) | Concluído em 0.50s
#   Testando filtro: MSC... CV R²: -0.0077 (±0.7079) | Concluído em 0.50s
#   Testando filtro: SNV... CV R²: 0.0267 (±0.6991) | Concluído em 0.52s
#   Testando filtro: SG_D1... CV R²: 0.0740 (±0.7388) | Concluído em 0.50s
#   Testando filtro: SG_D2... CV R²: 0.1425 (±0.5115) | Concluído em 0.50s
#   Testando filtro: Detrend... CV R²: 0.0216 (±0.6657) | Concluído em 0.49s
#   Testando filtro: Normalize... CV R²: -0.0772 (±1.1522) | Concluído em 0.49s
#   Testando filtro: EMSC... CV R²: -0.0077 (±0.7079) | Concluído em 0.49s
#   Testando filtro: Continuum_Removal... CV R²: -0.0663 (±0.6846) | Concluído em 0.63s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.1067 (±0.5551) | Concluído em 0.53s
#   Testando filtro: OSC_1... CV R²: -0.0587 (±0.7665) | Concluído em 0.52s
#   Testando filtro: OSC_2... CV R²: -0.0439 (±1.1172) | Concluído em 0.55s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.0355 (±1.0664) | Concluído em 0.50s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.0832 (±0.9642) | Concluído em 0.49s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.0271 (±0.9537) | Concluído em 0.51s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.0181 (±1.0678) | Concluído em 0.52s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: -0.0303 (±0.6748) | Concluído em 980.67s
#   Testando filtro: MSC... CV R²: 0.0296 (±0.6763) | Concluído em 985.04s
#   Testando filtro: SNV... CV R²: -0.0226 (±0.8757) | Concluído em 1030.10s
#   Testando filtro: SG_D1... CV R²: 0.1002 (±0.5637) | Concluído em 949.41s
#   Testando filtro: SG_D2... CV R²: 0.1451 (±0.4499) | Concluído em 959.36s
#   Testando filtro: Detrend... CV R²: 0.0741 (±0.7891) | Concluído em 970.62s
#   Testando filtro: Normalize... CV R²: -0.0413 (±0.7150) | Concluído em 1017.94s
#   Testando filtro: EMSC... CV R²: 0.0296 (±0.6763) | Concluído em 984.92s
#   Testando filtro: Continuum_Removal... CV R²: -0.1765 (±0.7593) | Concluído em 988.82s
#   Testando filtro: Wavelet_Denoising... CV R²: -0.0285 (±0.6743) | Concluído em 986.20s
#   Testando filtro: OSC_1... CV R²: -0.2568 (±1.0098) | Concluído em 1103.54s
#   Testando filtro: OSC_2... CV R²: -0.1693 (±1.2865) | Concluído em 953.29s
#   Testando filtro: MSC_SG_OSC... CV R²: -0.0300 (±0.5943) | Concluído em 990.65s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: -0.0690 (±0.5465) | Concluído em 1009.74s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: -0.0620 (±1.0097) | Concluído em 945.89s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.1372 (±0.3995) | Concluído em 963.95s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'TSS (Brix)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_TSS__Brix_.joblib
#    - Modelo: RFR
#    - Filtro: SG_D2
#    - Melhor R² CV: 0.1451
#    - Melhores Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200, 'warm_start': True}
#
# --- Salvando os 5 melhores modelos para TSS (Brix) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_TSS__Brix__PLSR_SG_D2.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_TSS__Brix__PLSR_Detrend.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_TSS__Brix__PLSR_Raw.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_TSS__Brix__PLSR_Wavelet_Denoising.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_TSS__Brix__PLSR_Normalize.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_TSS__Brix__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_TSS__Brix__PCR_MSC_SG_OSC.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_TSS__Brix__PCR_SNV_Detrend_SG_D1.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_TSS__Brix__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_TSS__Brix__PCR_SG_D1.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_TSS__Brix__SVMR_SG_D2.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_TSS__Brix__SVMR_Wavelet_Denoising.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_TSS__Brix__SVMR_Raw.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_TSS__Brix__SVMR_SG_D1.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_TSS__Brix__SVMR_SNV.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_TSS__Brix__RFR_SG_D2.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_TSS__Brix__RFR_SNV_Detrend_SG_D1.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_TSS__Brix__RFR_SG_D1.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_TSS__Brix__RFR_Detrend.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_TSS__Brix__RFR_MSC.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: TA (g/mL)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.1303 (±1.3016) | Concluído em 0.10s
#   Testando filtro: MSC... CV R²: 0.2163 (±1.0263) | Concluído em 0.09s
#   Testando filtro: SNV... CV R²: 0.2150 (±0.7954) | Concluído em 0.10s
#   Testando filtro: SG_D1... CV R²: 0.3931 (±0.6896) | Concluído em 0.09s
#   Testando filtro: SG_D2... CV R²: 0.4101 (±0.6622) | Concluído em 0.09s
#   Testando filtro: Detrend... CV R²: 0.2136 (±1.1386) | Concluído em 0.09s
#   Testando filtro: Normalize... CV R²: 0.0970 (±1.3238) | Concluído em 0.09s
#   Testando filtro: EMSC... CV R²: 0.2163 (±1.0263) | Concluído em 0.09s
#   Testando filtro: Continuum_Removal... CV R²: 0.1233 (±1.4022) | Concluído em 0.21s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.1284 (±1.3049) | Concluído em 0.11s
#   Testando filtro: OSC_1... CV R²: 0.1869 (±1.0045) | Concluído em 0.12s
#   Testando filtro: OSC_2... CV R²: 0.1490 (±1.0471) | Concluído em 0.12s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.4607 (±0.7058) | Concluído em 0.09s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.4473 (±0.7051) | Concluído em 0.09s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.0989 (±1.1134) | Concluído em 0.09s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.4134 (±0.7070) | Concluído em 0.09s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.2783 (±1.0830) | Concluído em 0.13s
#   Testando filtro: MSC... CV R²: 0.3597 (±0.8342) | Concluído em 0.17s
#   Testando filtro: SNV... CV R²: 0.3324 (±0.6141) | Concluído em 0.13s
#   Testando filtro: SG_D1... CV R²: 0.3719 (±0.6222) | Concluído em 0.14s
#   Testando filtro: SG_D2... CV R²: 0.5190 (±0.4387) | Concluído em 0.15s
#   Testando filtro: Detrend... CV R²: 0.3514 (±0.8333) | Concluído em 0.17s
#   Testando filtro: Normalize... CV R²: 0.3623 (±0.5715) | Concluído em 0.13s
#   Testando filtro: EMSC... CV R²: 0.3602 (±0.8339) | Concluído em 0.17s
#   Testando filtro: Continuum_Removal... CV R²: 0.1493 (±1.4193) | Concluído em 0.26s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.2783 (±1.0830) | Concluído em 0.13s
#   Testando filtro: OSC_1... CV R²: 0.2785 (±0.9225) | Concluído em 0.13s
#   Testando filtro: OSC_2... CV R²: 0.1903 (±1.3425) | Concluído em 0.17s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.4777 (±0.6625) | Concluído em 0.18s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.4787 (±0.6619) | Concluído em 0.17s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.3765 (±0.7165) | Concluído em 0.13s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.4273 (±0.6660) | Concluído em 0.14s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.3862 (±0.5086) | Concluído em 0.51s
#   Testando filtro: MSC... CV R²: 0.4177 (±0.2789) | Concluído em 0.50s
#   Testando filtro: SNV... CV R²: 0.3962 (±0.3081) | Concluído em 0.50s
#   Testando filtro: SG_D1... CV R²: 0.4095 (±0.5041) | Concluído em 0.52s
#   Testando filtro: SG_D2... CV R²: 0.3640 (±0.5274) | Concluído em 0.53s
#   Testando filtro: Detrend... CV R²: 0.3795 (±0.3762) | Concluído em 0.51s
#   Testando filtro: Normalize... CV R²: 0.4315 (±0.2768) | Concluído em 0.50s
#   Testando filtro: EMSC... CV R²: 0.4177 (±0.2789) | Concluído em 0.50s
#   Testando filtro: Continuum_Removal... CV R²: 0.3632 (±0.5299) | Concluído em 0.63s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.3861 (±0.5086) | Concluído em 0.54s
#   Testando filtro: OSC_1... CV R²: 0.4116 (±0.5133) | Concluído em 0.53s
#   Testando filtro: OSC_2... CV R²: 0.4157 (±0.5314) | Concluído em 0.50s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.4699 (±0.3155) | Concluído em 0.51s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.4773 (±0.4839) | Concluído em 0.50s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.4797 (±0.5018) | Concluído em 0.52s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.4084 (±0.4904) | Concluído em 0.50s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.3409 (±0.8369) | Concluído em 1065.52s
#   Testando filtro: MSC... CV R²: 0.3851 (±0.6279) | Concluído em 1037.92s
#   Testando filtro: SNV... CV R²: 0.4107 (±0.4870) | Concluído em 1039.10s
#   Testando filtro: SG_D1... CV R²: 0.4354 (±0.5827) | Concluído em 1074.87s
#   Testando filtro: SG_D2... CV R²: 0.5391 (±0.3493) | Concluído em 1080.62s
#   Testando filtro: Detrend... CV R²: 0.3967 (±0.7499) | Concluído em 1091.03s
#   Testando filtro: Normalize... CV R²: 0.3927 (±0.6743) | Concluído em 1014.24s
#   Testando filtro: EMSC... CV R²: 0.3851 (±0.6279) | Concluído em 1037.56s
#   Testando filtro: Continuum_Removal... CV R²: 0.3081 (±0.8201) | Concluído em 990.26s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.3399 (±0.8369) | Concluído em 1065.75s
#   Testando filtro: OSC_1... CV R²: 0.3426 (±0.9225) | Concluído em 1034.21s
#   Testando filtro: OSC_2... CV R²: 0.4135 (±0.9319) | Concluído em 1008.22s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.5459 (±0.3600) | Concluído em 1038.55s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.5513 (±0.3288) | Concluído em 1061.93s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.5320 (±0.5780) | Concluído em 1071.04s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.3509 (±0.6916) | Concluído em 1051.35s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'TA (g/mL)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_TA__g_mL_.joblib
#    - Modelo: RFR
#    - Filtro: OPLS1_SNV_SG_D1
#    - Melhor R² CV: 0.5513
#    - Melhores Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300, 'warm_start': True}
#
# --- Salvando os 5 melhores modelos para TA (g/mL) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_TA__g_mL__PLSR_MSC_SG_OSC.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_TA__g_mL__PLSR_OPLS1_SNV_SG_D1.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_TA__g_mL__PLSR_SNV_Detrend_SG_D1.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_TA__g_mL__PLSR_SG_D2.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_TA__g_mL__PLSR_SG_D1.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_TA__g_mL__PCR_SG_D2.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_TA__g_mL__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_TA__g_mL__PCR_MSC_SG_OSC.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_TA__g_mL__PCR_SNV_Detrend_SG_D1.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_TA__g_mL__PCR_OPLS2_SNV_SG_D1.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_TA__g_mL__SVMR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_TA__g_mL__SVMR_OPLS1_SNV_SG_D1.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_TA__g_mL__SVMR_MSC_SG_OSC.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_TA__g_mL__SVMR_Normalize.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_TA__g_mL__SVMR_MSC.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_TA__g_mL__RFR_OPLS1_SNV_SG_D1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_TA__g_mL__RFR_MSC_SG_OSC.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_TA__g_mL__RFR_SG_D2.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_TA__g_mL__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_TA__g_mL__RFR_SG_D1.joblib
#
# ==============================
# INICIANDO MODELAGEM PARA: AA (mg/100g)
# ==============================
#
# --- Modelo: PLSR ---
#   Testando filtro: Raw... CV R²: 0.3912 (±0.4303) | Concluído em 0.09s
#   Testando filtro: MSC... CV R²: 0.3494 (±0.6804) | Concluído em 0.14s
#   Testando filtro: SNV... CV R²: 0.3035 (±0.5115) | Concluído em 0.11s
#   Testando filtro: SG_D1... CV R²: 0.4210 (±0.4800) | Concluído em 0.14s
#   Testando filtro: SG_D2... CV R²: 0.4339 (±0.2882) | Concluído em 0.09s
#   Testando filtro: Detrend... CV R²: 0.3923 (±0.4487) | Concluído em 0.10s
#   Testando filtro: Normalize... CV R²: 0.4255 (±0.4615) | Concluído em 0.10s
#   Testando filtro: EMSC... CV R²: 0.3494 (±0.6804) | Concluído em 0.14s
#   Testando filtro: Continuum_Removal... CV R²: 0.2720 (±0.4893) | Concluído em 0.21s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.3911 (±0.4299) | Concluído em 0.11s
#   Testando filtro: OSC_1... CV R²: 0.3223 (±0.5099) | Concluído em 0.10s
#   Testando filtro: OSC_2... CV R²: 0.3848 (±0.6532) | Concluído em 0.14s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.4622 (±0.4365) | Concluído em 0.09s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.4650 (±0.4328) | Concluído em 0.09s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.3901 (±0.4284) | Concluído em 0.11s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.4393 (±0.4626) | Concluído em 0.12s
#
# --- Modelo: PCR ---
#   Testando filtro: Raw... CV R²: 0.3897 (±0.5332) | Concluído em 0.17s
#   Testando filtro: MSC... CV R²: 0.4307 (±0.5587) | Concluído em 0.17s
#   Testando filtro: SNV... CV R²: 0.4891 (±0.5282) | Concluído em 0.17s
#   Testando filtro: SG_D1... CV R²: 0.3692 (±0.5014) | Concluído em 0.13s
#   Testando filtro: SG_D2... CV R²: -0.0653 (±0.7128) | Concluído em 0.15s
#   Testando filtro: Detrend... CV R²: 0.4135 (±0.5631) | Concluído em 0.17s
#   Testando filtro: Normalize... CV R²: 0.4014 (±0.6071) | Concluído em 0.17s
#   Testando filtro: EMSC... CV R²: 0.4312 (±0.5579) | Concluído em 0.17s
#   Testando filtro: Continuum_Removal... CV R²: 0.4921 (±0.3165) | Concluído em 0.29s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.3886 (±0.5338) | Concluído em 0.17s
#   Testando filtro: OSC_1... CV R²: 0.4895 (±0.4082) | Concluído em 0.17s
#   Testando filtro: OSC_2... CV R²: 0.4620 (±0.4717) | Concluído em 0.15s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.4419 (±0.4543) | Concluído em 0.14s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.4428 (±0.4559) | Concluído em 0.14s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.4206 (±0.4175) | Concluído em 0.17s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.3772 (±0.4477) | Concluído em 0.13s
#
# --- Modelo: SVMR ---
#   Testando filtro: Raw... CV R²: 0.4478 (±0.3812) | Concluído em 0.61s
#   Testando filtro: MSC... CV R²: 0.3216 (±0.5768) | Concluído em 0.62s
#   Testando filtro: SNV... CV R²: 0.3749 (±0.5226) | Concluído em 0.63s
#   Testando filtro: SG_D1... CV R²: 0.4147 (±0.1483) | Concluído em 0.62s
#   Testando filtro: SG_D2... CV R²: 0.0564 (±0.2520) | Concluído em 0.61s
#   Testando filtro: Detrend... CV R²: 0.4204 (±0.4190) | Concluído em 0.61s
#   Testando filtro: Normalize... CV R²: 0.3183 (±0.5731) | Concluído em 0.62s
#   Testando filtro: EMSC... CV R²: 0.3216 (±0.5768) | Concluído em 0.60s
#   Testando filtro: Continuum_Removal... CV R²: 0.5590 (±0.2386) | Concluído em 0.76s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.4476 (±0.3823) | Concluído em 0.63s
#   Testando filtro: OSC_1... CV R²: 0.4740 (±0.2787) | Concluído em 0.61s
#   Testando filtro: OSC_2... CV R²: 0.5075 (±0.2561) | Concluído em 0.63s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.4140 (±0.3901) | Concluído em 0.62s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.4165 (±0.3864) | Concluído em 0.61s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.6270 (±0.3103) | Concluído em 0.61s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.3786 (±0.2217) | Concluído em 0.61s
#
# --- Modelo: RFR ---
#   Testando filtro: Raw... CV R²: 0.2128 (±0.4520) | Concluído em 1148.88s
#   Testando filtro: MSC... CV R²: 0.0906 (±1.0886) | Concluído em 1163.25s
#   Testando filtro: SNV... CV R²: 0.1296 (±1.0795) | Concluído em 1120.63s
#   Testando filtro: SG_D1... CV R²: 0.5344 (±0.3446) | Concluído em 1239.71s
#   Testando filtro: SG_D2... CV R²: 0.5456 (±0.2930) | Concluído em 1162.73s
#   Testando filtro: Detrend... CV R²: 0.4163 (±0.4057) | Concluído em 1233.83s
#   Testando filtro: Normalize... CV R²: 0.3732 (±0.3613) | Concluído em 1127.08s
#   Testando filtro: EMSC... CV R²: 0.0906 (±1.0886) | Concluído em 1161.32s
#   Testando filtro: Continuum_Removal... CV R²: 0.2696 (±0.4706) | Concluído em 1116.57s
#   Testando filtro: Wavelet_Denoising... CV R²: 0.2106 (±0.4500) | Concluído em 1147.41s
#   Testando filtro: OSC_1... CV R²: 0.4175 (±0.3840) | Concluído em 1201.20s
#   Testando filtro: OSC_2... CV R²: 0.3729 (±0.5869) | Concluído em 1154.45s
#   Testando filtro: MSC_SG_OSC... CV R²: 0.4624 (±0.3595) | Concluído em 1196.44s
#   Testando filtro: OPLS1_SNV_SG_D1... CV R²: 0.4704 (±0.3932) | Concluído em 1154.45s
#   Testando filtro: OPLS2_SNV_SG_D1... CV R²: 0.6756 (±0.2320) | Concluído em 1226.18s
#   Testando filtro: SNV_Detrend_SG_D1... CV R²: 0.4918 (±0.4121) | Concluído em 1229.81s
#
#  🏆 MELHOR COMBINAÇÃO GERAL PARA 'AA (mg/100g)' FOI SALVA!
#    - Arquivo: modelos_salvos/melhor_modelo_AA__mg_100g_.joblib
#    - Modelo: RFR
#    - Filtro: OPLS2_SNV_SG_D1
#    - Melhor R² CV: 0.6756
#    - Melhores Parâmetros: {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300, 'warm_start': True}
#
# --- Salvando os 5 melhores modelos para AA (mg/100g) ---
#   - Top 1 do modelo PLSR salvo em: modelos_salvos_top5/top_1_AA__mg_100g__PLSR_OPLS1_SNV_SG_D1.joblib
#   - Top 2 do modelo PLSR salvo em: modelos_salvos_top5/top_2_AA__mg_100g__PLSR_MSC_SG_OSC.joblib
#   - Top 3 do modelo PLSR salvo em: modelos_salvos_top5/top_3_AA__mg_100g__PLSR_SNV_Detrend_SG_D1.joblib
#   - Top 4 do modelo PLSR salvo em: modelos_salvos_top5/top_4_AA__mg_100g__PLSR_SG_D2.joblib
#   - Top 5 do modelo PLSR salvo em: modelos_salvos_top5/top_5_AA__mg_100g__PLSR_Normalize.joblib
#   - Top 1 do modelo PCR salvo em: modelos_salvos_top5/top_1_AA__mg_100g__PCR_Continuum_Removal.joblib
#   - Top 2 do modelo PCR salvo em: modelos_salvos_top5/top_2_AA__mg_100g__PCR_OSC_1.joblib
#   - Top 3 do modelo PCR salvo em: modelos_salvos_top5/top_3_AA__mg_100g__PCR_SNV.joblib
#   - Top 4 do modelo PCR salvo em: modelos_salvos_top5/top_4_AA__mg_100g__PCR_OSC_2.joblib
#   - Top 5 do modelo PCR salvo em: modelos_salvos_top5/top_5_AA__mg_100g__PCR_OPLS1_SNV_SG_D1.joblib
#   - Top 1 do modelo SVMR salvo em: modelos_salvos_top5/top_1_AA__mg_100g__SVMR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo SVMR salvo em: modelos_salvos_top5/top_2_AA__mg_100g__SVMR_Continuum_Removal.joblib
#   - Top 3 do modelo SVMR salvo em: modelos_salvos_top5/top_3_AA__mg_100g__SVMR_OSC_2.joblib
#   - Top 4 do modelo SVMR salvo em: modelos_salvos_top5/top_4_AA__mg_100g__SVMR_OSC_1.joblib
#   - Top 5 do modelo SVMR salvo em: modelos_salvos_top5/top_5_AA__mg_100g__SVMR_Raw.joblib
#   - Top 1 do modelo RFR salvo em: modelos_salvos_top5/top_1_AA__mg_100g__RFR_OPLS2_SNV_SG_D1.joblib
#   - Top 2 do modelo RFR salvo em: modelos_salvos_top5/top_2_AA__mg_100g__RFR_SG_D2.joblib
#   - Top 3 do modelo RFR salvo em: modelos_salvos_top5/top_3_AA__mg_100g__RFR_SG_D1.joblib
#   - Top 4 do modelo RFR salvo em: modelos_salvos_top5/top_4_AA__mg_100g__RFR_SNV_Detrend_SG_D1.joblib
#   - Top 5 do modelo RFR salvo em: modelos_salvos_top5/top_5_AA__mg_100g__RFR_OPLS1_SNV_SG_D1.joblib
#
#
#  ✅ Modelagem exaustiva com Cross-Validation!
#   ✅Resultados salvos em "analise_completa_resultados_cv.xlsx"
#
# --- Melhores Resultados por Atributo (Cross-Validation) ---
#     Atributo Modelo            Filtro  CV_R2_Mean  CV_R2_Std  CV_RMSE                                                                                                              Melhores_Params
# AA (mg/100g)    RFR   OPLS2_SNV_SG_D1      0.6756     0.2320   2.9038 {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300, 'warm_start': True}
# Dry Mass (%)   SVMR SNV_Detrend_SG_D1      0.4073     0.2096   1.0652                                                                {'C': 100, 'epsilon': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# Firmness (N)    RFR Continuum_Removal      0.9543     0.0357  10.1460 {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 300, 'warm_start': True}
#    TA (g/mL)    RFR   OPLS1_SNV_SG_D1      0.5513     0.3288   0.0911 {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300, 'warm_start': True}
#   TSS (Brix)    RFR             SG_D2      0.1451     0.4499   1.1917 {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200, 'warm_start': True}

# %% [markdown]
# ## 7. Análise Comparativa dos Resultados

# %%
import pandas as pd
import numpy as np

# Carregar os resultados salvos para análise
df_analise = pd.read_excel('analise_completa_resultados_cv.xlsx')

idx = df_analise.groupby(['Atributo', 'Modelo'])['CV_R2_Mean'].transform(max) == df_analise['CV_R2_Mean']
df_melhores_por_modelo = df_analise[idx]

print("--- Tabela Comparativa dos Melhores Resultados por Modelo (Cross-Validation) ---")
print(df_melhores_por_modelo[['Atributo', 'Modelo', 'Filtro', 'CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE']].round(4))

print("\n--- Melhores Modelos Gerais por Atributo (baseado no R² de Cross-Validation) ---")
idx_geral = df_melhores_por_modelo.groupby(['Atributo'])['CV_R2_Mean'].transform(max) == df_melhores_por_modelo['CV_R2_Mean']
df_melhores_gerais = df_melhores_por_modelo[idx_geral]
print(df_melhores_gerais[['Atributo', 'Modelo', 'Filtro', 'CV_R2_Mean', 'CV_R2_Std', 'CV_RMSE']].round(4))

# Análise estatística adicional
print("\n--- Análise Estatística dos Resultados ---")
print(f"Número total de combinações testadas: {len(df_analise)}")
print(f"Número de atributos analisados: {df_analise['Atributo'].nunique()}")
print(f"Número de modelos testados: {df_analise['Modelo'].nunique()}")
print(f"Número de filtros testados: {df_analise['Filtro'].nunique()}")

print(f"\nEstatísticas do R² de Cross-Validation:")
print(f"  Média geral: {df_analise['CV_R2_Mean'].mean():.4f}")
print(f"  Desvio padrão: {df_analise['CV_R2_Mean'].std():.4f}")
print(f"  Melhor resultado: {df_analise['CV_R2_Mean'].max():.4f}")
print(f"  Pior resultado: {df_analise['CV_R2_Mean'].min():.4f}")

# Análise por modelo
print(f"\n--- Desempenho Médio por Modelo ---")
desempenho_por_modelo = df_analise.groupby('Modelo')['CV_R2_Mean'].agg(['mean', 'std', 'max', 'min']).round(4)
print(desempenho_por_modelo)

# Análise por filtro
print(f"\n--- Top 10 Filtros com Melhor Desempenho Médio ---")
desempenho_por_filtro = df_analise.groupby('Filtro')['CV_R2_Mean'].agg(['mean', 'std', 'count']).round(4)
desempenho_por_filtro = desempenho_por_filtro.sort_values('mean', ascending=False)
print(desempenho_por_filtro.head(10))

print("\n✅ Análise de resultados concluída!")
# Out:
# --- Tabela Comparativa dos Melhores Resultados por Modelo (Cross-Validation) ---
#          Atributo Modelo             Filtro  CV_R2_Mean  CV_R2_Std  CV_RMSE
# 0    AA (mg/100g)    RFR    OPLS2_SNV_SG_D1      0.6756     0.2320   2.9038
# 1    AA (mg/100g)   SVMR    OPLS2_SNV_SG_D1      0.6270     0.3103   2.7776
# 6    AA (mg/100g)    PCR  Continuum_Removal      0.4921     0.3165   3.3556
# 12   AA (mg/100g)   PLSR    OPLS1_SNV_SG_D1      0.4650     0.4328   3.3661
# 64   Dry Mass (%)   SVMR  SNV_Detrend_SG_D1      0.4073     0.2096   1.0652
# 65   Dry Mass (%)    PCR              SG_D1      0.4006     0.2352   1.0837
# 76   Dry Mass (%)    RFR  SNV_Detrend_SG_D1      0.3377     0.3548   1.0664
# 97   Dry Mass (%)   PLSR              OSC_1      0.2464     0.1969   1.2453
# 128  Firmness (N)    RFR  Continuum_Removal      0.9543     0.0357  10.1460
# 134  Firmness (N)   SVMR              OSC_2      0.9279     0.0278  12.5188
# 139  Firmness (N)   PLSR                MSC      0.9144     0.0622  13.5518
# 142  Firmness (N)    PCR               EMSC      0.9136     0.0742  13.5464
# 192     TA (g/mL)    RFR    OPLS1_SNV_SG_D1      0.5513     0.3288   0.0911
# 196     TA (g/mL)    PCR              SG_D2      0.5190     0.4387   0.0938
# 197     TA (g/mL)   SVMR    OPLS2_SNV_SG_D1      0.4797     0.5018   0.0949
# 202     TA (g/mL)   PLSR         MSC_SG_OSC      0.4607     0.7058   0.0960
# 256    TSS (Brix)    RFR              SG_D2      0.1451     0.4499   1.1917
# 257    TSS (Brix)   SVMR              SG_D2      0.1425     0.5115   1.1052
# 262    TSS (Brix)    PCR    OPLS1_SNV_SG_D1      0.0897     1.0762   1.0490
# 280    TSS (Brix)   PLSR              SG_D2     -0.0309     0.6540   1.1476
#
# --- Melhores Modelos Gerais por Atributo (baseado no R² de Cross-Validation) ---
#          Atributo Modelo             Filtro  CV_R2_Mean  CV_R2_Std  CV_RMSE
# 0    AA (mg/100g)    RFR    OPLS2_SNV_SG_D1      0.6756     0.2320   2.9038
# 64   Dry Mass (%)   SVMR  SNV_Detrend_SG_D1      0.4073     0.2096   1.0652
# 128  Firmness (N)    RFR  Continuum_Removal      0.9543     0.0357  10.1460
# 192     TA (g/mL)    RFR    OPLS1_SNV_SG_D1      0.5513     0.3288   0.0911
# 256    TSS (Brix)    RFR              SG_D2      0.1451     0.4499   1.1917
#
# --- Análise Estatística dos Resultados ---
# Número total de combinações testadas: 320
# Número de atributos analisados: 5
# Número de modelos testados: 4
# Número de filtros testados: 16
#
# Estatísticas do R² de Cross-Validation:
#   Média geral: 0.3363
#   Desvio padrão: 0.3612
#   Melhor resultado: 0.9543
#   Pior resultado: -0.7738
#
# --- Desempenho Médio por Modelo ---
#           mean     std     max     min
# Modelo
# PCR     0.3413  0.3612  0.9136 -0.4234
# PLSR    0.2406  0.4573  0.9144 -0.7738
# RFR     0.3689  0.3136  0.9543 -0.2568
# SVMR    0.3944  0.2741  0.9279 -0.0832
#
# --- Top 10 Filtros com Melhor Desempenho Médio ---
#                      mean     std  count
# Filtro
# MSC_SG_OSC         0.3941  0.3568     20
# OPLS1_SNV_SG_D1    0.3831  0.3779     20
# SG_D1              0.3651  0.3475     20
# SNV_Detrend_SG_D1  0.3650  0.3493     20
# OPLS2_SNV_SG_D1    0.3597  0.4181     20
# Detrend            0.3541  0.3440     20
# OSC_2              0.3351  0.3951     20
# OSC_1              0.3332  0.3907     20
# Raw                0.3256  0.3499     20
# Wavelet_Denoising  0.3255  0.3492     20
#
# ✅ Análise de resultados concluída!

# %% [markdown]
# ## Testes

# %%
## Linha de teste
